# %%
# !pip install rasterio h5py
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (3.12.1)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio) (2025.1.31)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio) (8.1.8)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.11/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.11/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from rasterio) (3.2.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24->rasterio) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.24->rasterio) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.24->rasterio) (2024.2.0)
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 81.8 MB/s eta 0:00:00
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.4.3

# %%
import os
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
import rasterio
import matplotlib.pyplot as plt
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.losses import Huber
print(tf.__version__)
# Out:
# 2025-05-03 09:09:47.474301: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746263387.684573      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746263387.742655      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2.18.0

# %%
DATA_PATH = "/kaggle/input/data-rain-v2/DATA_RAIN_V2"
# ERA5_ATTRIBUTES = ["CAPE", "CIN", "EWSS", "IE", "ISOR", "KX", "PEV", "R250", "R500", "R850", "SLHF", "SLOR", "SSHF","TCLW","TCW","TCWV", "U250", "U850","V250", "V850"]
# HIMA_BANDS = ["B09B", "B10B", "B11B","B12B", "B14B", "B16B", "IRB", "I2B", "I4B", "WVB"]

ERA5_ATTRIBUTES = ["CAPE", "CIN", "R500", "TCLW","TCW","TCWV", "V250", "V850"]
HIMA_BANDS = ["B09B", "B11B","B12B", "B16B", "I4B", "WVB"]
print(len(ERA5_ATTRIBUTES ))
print(len(HIMA_BANDS))
# Out:
# 8
# 6

# %% [markdown]
# # 1. Load dữ liệu

# %% [markdown]
# ## 1.1. Hàm lấy file

# %%
def convert_time_to_strings(year, month, day, hour):
    year_str = str(year)
    month_str = f"{int(month):02d}"
    day_str = f"{int(day):02d}"
    hour_str = f"{int(hour):02d}"
    return year_str, month_str, day_str, hour_str

def get_era5_file_path(attribute, year, month, day, hour):
    year, month, day, hour = convert_time_to_strings(year, month, day, hour)
    file_name = f"ERA5_{attribute}_{year}_{month}_{day}_{hour}.tif"
    file_path = os.path.join(DATA_PATH, year, month, day, hour, "ERA5", file_name)
    return file_path


def get_hima_file_path(band, year, month, day, hour):
    year, month, day, hour = convert_time_to_strings(year, month, day, hour)
    file_name = f"Hima_{band}_{year}_{month}_{day}_{hour}.tif"
    file_path = os.path.join(DATA_PATH, year, month, day, hour, "Hima", file_name)
    return file_path

def get_radar_file_path(year, month, day, hour):
    year, month, day, hour = convert_time_to_strings(year, month, day, hour)
    file_name = f"Radar_{year}_{month}_{day}_{hour}.tif"
    file_path = os.path.join(DATA_PATH, year, month, day, hour, "Radar", file_name)
    return file_path

# %% [markdown]
# ## 1.2. Load file

# %%
def load_era5_attributes(year, month, day, hour):
    era5_imgs= []
    for attribute in ERA5_ATTRIBUTES:
        file_path = get_era5_file_path(attribute, year, month, day, hour)
        try:
            with rasterio.open(file_path) as src:
                era5_imgs.append(src.read(1)) 
        except Exception as e:
            print(f"Failed to load {attribute} for {year}-{month}-{day} {hour}:00:00 {e}")
    era5_data = np.stack(era5_imgs, axis=-1)  
    return era5_data

def load_hima_bands(year, month, day, hour):
    hima_imgs = []
    for band in HIMA_BANDS:
        file_path = get_hima_file_path(band, year, month, day, hour)
        try:
            with rasterio.open(file_path) as src:
                hima_imgs.append(src.read(1))
        except Exception as e:
                print(f"Failed to load {band} for {year}-{month}-{day} {hour}:00:00 {e}")
    hima_data = np.stack(hima_imgs, axis = -1)
    return hima_data

def load_radar(year, month, day, hour):
    radar_img = None
    file_path = get_radar_file_path(year, month, day, hour)
    try: 
        with rasterio.open(file_path) as src:
            radar_img = src.read(1)
    except Exception as e:
        print(f"Failed to load radar for {year}-{month}-{day} {hour}:00:00 {e}")
    return radar_img

# %%
def load_data_for_timestamp(year, month, day, hour, use_era5 = True):
    try:
        era5_data = None
        if use_era5:
            era5_data = load_era5_attributes(year, month, day, hour)

        hima_data = load_hima_bands(year, month, day, hour)
        radar_data = load_radar(year, month, day, hour)
        if use_era5:
            input_images = np.concatenate((hima_data, era5_data), axis = -1) #shape (90, 250, hima + era5)
        else:
            input_images = hima_data

        return input_images, radar_data

    except Exception as e:
        print(f"Failed to load data for {year}-{month}-{day} {hour}:00:00 {e}")
        return None, None

# %%
def load_dataset(timestamps_df, use_era5 = True):
    X = []
    y = []
    timestamps_tuples = list(timestamps_df[['year', 'month', 'day', 'hour']].itertuples(index=False, name=None))
    for year, month, day, hour in tqdm(timestamps_tuples):
        input_images, radar_image = load_data_for_timestamp(year, month, day, hour, use_era5)
        if input_images is not None and radar_image is not None:
            X.append(input_images)
            y.append(radar_image)
    
    X = np.array(X)
    y = np.array(y)
    y = y[..., np.newaxis] #(90, 250, 1)
    return X, y

# %% [markdown]
# ## 1.3. Chia dữ liệu

# %%
rain_df = pd.read_csv("/kaggle/input/valid-time-rain/final_rain_timestamps.csv", index_col=None)
rain_df.drop(columns = ['Unnamed: 0'], inplace = True)
train_df, tmp_df = train_test_split(
    rain_df, test_size = 0.3, stratify=rain_df["radar_mean_class"], random_state = 42
)

val_df, test_df = train_test_split(
    tmp_df, test_size=0.5, stratify=tmp_df["radar_mean_class"], random_state=42
)

# %% [markdown]
# ## USE_ERA5

# %%
USE_ERA5 = True

# %% [markdown]
# ## 1.4. Scale dữ liệu

# %%
X_train, y_train = load_dataset(train_df, USE_ERA5)
X_val, y_val = load_dataset(val_df, USE_ERA5)
X_test, y_test = load_dataset(test_df, USE_ERA5)
# Out:
# 100%|██████████| 1562/1562 [04:04<00:00,  6.40it/s]
# 100%|██████████| 335/335 [00:50<00:00,  6.61it/s]
# 100%|██████████| 335/335 [00:50<00:00,  6.70it/s]

# %%
# np.savez_compressed('/kaggle/working/raindataset.npz', X_train=X_train, y_train=y_train, X_val = X_val, y_val = y_val, X_test = X_test, y_test = y_test)

# %%
y_train.max()
# Out:
# 260.0

# %%
y_val.max()
# Out:
# 231.0

# %%
y_test.max()
# Out:
# 234.71875

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_X = MinMaxScaler()

X_train_reshaped = X_train.reshape(-1, X_train.shape[-1]) #(num_sample * 250 * 90, hima + era5)
scaler_X.fit(X_train_reshaped)

X_train_scaled = scaler_X.transform(X_train_reshaped).reshape(X_train.shape)
X_val_scaled = scaler_X.transform(X_val.reshape(-1, X_val.shape[-1])).reshape(X_val.shape)
X_test_scaled = scaler_X.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

# %% [markdown]
# # Xử lý -inf

# %%
y_train = np.where(y_train < 0, -1, y_train)
y_val = np.where(y_val < 0, -1, y_val)
y_test = np.where(y_test < 0, -1, y_test)

# %% [markdown]
# # 2. Train

# %% [markdown]
# ## 2.1. Tham số mô hình

# %%
BATCH_SIZE = 32
NUM_FILTERS = [64, 128, 256, 512]
BOTTLENECK_FILTER = 1024
EPOCHS = 100

# %% [markdown]
# ## 2.2. Tạo mô hình

# %%
def inception_block(x, num_filters):
    config = {
        "conv1x1": num_filters // 8,
        "conv3x3_reduce": num_filters // 2,
        "conv3x3": num_filters // 2,
        "conv5x5_reduce": num_filters // 4,
        "conv5x5": num_filters // 4,
        "conv7x7_reduce": num_filters // 8,
        "conv7x7": num_filters // 8
    }
    
    # Branch 1: 1x1 conv
    branch1 = Conv2D(config["conv1x1"], kernel_size=1, padding='same')(x)
    branch1 = BatchNormalization()(branch1)
    branch1 = LeakyReLU(alpha=0.1)(branch1)

    # Branch 2: 1x1 conv -> 3x3 conv
    branch2 = Conv2D(config["conv3x3_reduce"], kernel_size=1, padding='same')(x)
    branch2 = LeakyReLU(alpha=0.1)(branch2)
    branch2 = Conv2D(config["conv3x3"], kernel_size=3, padding='same')(branch2)
    branch2 = BatchNormalization()(branch2)
    branch2 = LeakyReLU(alpha=0.1)(branch2)

    # Branch 3: 1x1 conv -> 5x5 conv
    branch3 = Conv2D(config["conv5x5_reduce"], kernel_size=1, padding='same')(x)
    branch3 = BatchNormalization()(branch3)
    branch3 = LeakyReLU(alpha=0.1)(branch3)
    branch3 = Conv2D(config["conv5x5"], kernel_size=5, padding='same')(branch3)
    branch3 = BatchNormalization()(branch3)
    branch3 = LeakyReLU(alpha=0.1)(branch3)

    # Branch 4: 1x1 conv -> 7x7 conv
    branch4 = Conv2D(config["conv7x7_reduce"], kernel_size=1, padding='same')(x)
    branch4 = BatchNormalization()(branch4)
    branch4 = LeakyReLU(alpha=0.1)(branch4)
    branch4 = Conv2D(config["conv7x7"], kernel_size=7, padding='same')(branch4)
    branch4 = BatchNormalization()(branch4)
    branch4 = LeakyReLU(alpha=0.1)(branch4)
    
    # Concatenate all branches
    output = Concatenate()([branch1, branch2, branch3, branch4])
    return output

# Encoder Block with Inception Block
def encoder_block(inputs, num_filters):
    x = inception_block(inputs, num_filters)
    p = MaxPooling2D(pool_size=(2, 2))(x)
    return x, p


def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, kernel_size=3, strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = inception_block(x, num_filters)
    return x

# %%
def InceptionUnet(input_shape):
    inputs = Input(shape=input_shape, name="input")
    x = ZeroPadding2D(padding=((3, 3), (3, 3)))(inputs)  # Padding for even dimensions
    skip_connections = []
    

    for num_filters in NUM_FILTERS:
        skip, x = encoder_block(x, num_filters)
        skip_connections.append(skip)


    x = inception_block(x, BOTTLENECK_FILTER)


    skip_connections = skip_connections[::-1]
    for num_filters, skip in zip(NUM_FILTERS[::-1], skip_connections):
        x = decoder_block(x, skip, num_filters)


    x = Cropping2D(cropping=((3, 3), (3, 3)))(x)  # Crop padding
    outputs = Conv2D(1, kernel_size=1, padding='same', activation='relu')(x)
    

    model = Model(inputs, outputs)
    return model

# %%
channel = None
if USE_ERA5:
    channel = len(HIMA_BANDS) + len(ERA5_ATTRIBUTES)
else:
    channel = len(HIMA_BANDS)
    
input_shape = (90, 250, channel)
model = InceptionUnet(input_shape)
model.summary()
# Out:
# I0000 00:00:1746263757.587236      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)        │ (None, 90, 250, 14)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ zero_padding2d            │ (None, 96, 256, 14)    │              0 │ input[0][0]            │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 96, 256, 16)    │            240 │ zero_padding2d[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 96, 256, 8)     │            120 │ zero_padding2d[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 96, 256, 32)    │            480 │ zero_padding2d[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 96, 256, 16)    │             64 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 96, 256, 8)     │             32 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU) │ (None, 96, 256, 32)    │              0 │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU) │ (None, 96, 256, 16)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_5 (LeakyReLU) │ (None, 96, 256, 8)     │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 96, 256, 8)     │            120 │ zero_padding2d[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 96, 256, 32)    │          9,248 │ leaky_re_lu_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 96, 256, 16)    │          6,416 │ leaky_re_lu_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 96, 256, 8)     │          3,144 │ leaky_re_lu_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 96, 256, 8)     │             32 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 96, 256, 32)    │            128 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 96, 256, 16)    │             64 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 96, 256, 8)     │             32 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu (LeakyReLU)   │ (None, 96, 256, 8)     │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_2 (LeakyReLU) │ (None, 96, 256, 32)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_4 (LeakyReLU) │ (None, 96, 256, 16)    │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_6 (LeakyReLU) │ (None, 96, 256, 8)     │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 96, 256, 64)    │              0 │ leaky_re_lu[0][0],     │
# │                           │                        │                │ leaky_re_lu_2[0][0],   │
# │                           │                        │                │ leaky_re_lu_4[0][0],   │
# │                           │                        │                │ leaky_re_lu_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 48, 128, 64)    │              0 │ concatenate[0][0]      │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 48, 128, 32)    │          2,080 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 48, 128, 16)    │          1,040 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 48, 128, 64)    │          4,160 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 48, 128, 32)    │            128 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 48, 128, 16)    │             64 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_8 (LeakyReLU) │ (None, 48, 128, 64)    │              0 │ conv2d_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_10            │ (None, 48, 128, 32)    │              0 │ batch_normalization_8… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_12            │ (None, 48, 128, 16)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 48, 128, 16)    │          1,040 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 48, 128, 64)    │         36,928 │ leaky_re_lu_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 48, 128, 32)    │         25,632 │ leaky_re_lu_10[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 48, 128, 16)    │         12,560 │ leaky_re_lu_12[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 48, 128, 16)    │             64 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 48, 128, 64)    │            256 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 48, 128, 32)    │            128 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 48, 128, 16)    │             64 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_7 (LeakyReLU) │ (None, 48, 128, 16)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_9 (LeakyReLU) │ (None, 48, 128, 64)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_11            │ (None, 48, 128, 32)    │              0 │ batch_normalization_9… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_13            │ (None, 48, 128, 16)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 48, 128, 128)   │              0 │ leaky_re_lu_7[0][0],   │
# │ (Concatenate)             │                        │                │ leaky_re_lu_9[0][0],   │
# │                           │                        │                │ leaky_re_lu_11[0][0],  │
# │                           │                        │                │ leaky_re_lu_13[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 24, 64, 128)    │              0 │ concatenate_1[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 24, 64, 64)     │          8,256 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_19 (Conv2D)        │ (None, 24, 64, 32)     │          4,128 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 24, 64, 128)    │         16,512 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 24, 64, 64)     │            256 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 24, 64, 32)     │            128 │ conv2d_19[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_15            │ (None, 24, 64, 128)    │              0 │ conv2d_15[0][0]        │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_17            │ (None, 24, 64, 64)     │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_19            │ (None, 24, 64, 32)     │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 24, 64, 32)     │          4,128 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 24, 64, 128)    │        147,584 │ leaky_re_lu_15[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 24, 64, 64)     │        102,464 │ leaky_re_lu_17[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_20 (Conv2D)        │ (None, 24, 64, 32)     │         50,208 │ leaky_re_lu_19[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 24, 64, 32)     │            128 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 24, 64, 128)    │            512 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 24, 64, 64)     │            256 │ conv2d_18[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 24, 64, 32)     │            128 │ conv2d_20[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_14            │ (None, 24, 64, 32)     │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_16            │ (None, 24, 64, 128)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_18            │ (None, 24, 64, 64)     │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_20            │ (None, 24, 64, 32)     │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 24, 64, 256)    │              0 │ leaky_re_lu_14[0][0],  │
# │ (Concatenate)             │                        │                │ leaky_re_lu_16[0][0],  │
# │                           │                        │                │ leaky_re_lu_18[0][0],  │
# │                           │                        │                │ leaky_re_lu_20[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 12, 32, 256)    │              0 │ concatenate_2[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_24 (Conv2D)        │ (None, 12, 32, 128)    │         32,896 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_26 (Conv2D)        │ (None, 12, 32, 64)     │         16,448 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_22 (Conv2D)        │ (None, 12, 32, 256)    │         65,792 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_20    │ (None, 12, 32, 128)    │            512 │ conv2d_24[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_22    │ (None, 12, 32, 64)     │            256 │ conv2d_26[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_22            │ (None, 12, 32, 256)    │              0 │ conv2d_22[0][0]        │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_24            │ (None, 12, 32, 128)    │              0 │ batch_normalization_2… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_26            │ (None, 12, 32, 64)     │              0 │ batch_normalization_2… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_21 (Conv2D)        │ (None, 12, 32, 64)     │         16,448 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_23 (Conv2D)        │ (None, 12, 32, 256)    │        590,080 │ leaky_re_lu_22[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_25 (Conv2D)        │ (None, 12, 32, 128)    │        409,728 │ leaky_re_lu_24[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_27 (Conv2D)        │ (None, 12, 32, 64)     │        200,768 │ leaky_re_lu_26[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 12, 32, 64)     │            256 │ conv2d_21[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_19    │ (None, 12, 32, 256)    │          1,024 │ conv2d_23[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_21    │ (None, 12, 32, 128)    │            512 │ conv2d_25[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_23    │ (None, 12, 32, 64)     │            256 │ conv2d_27[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_21            │ (None, 12, 32, 64)     │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_23            │ (None, 12, 32, 256)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_25            │ (None, 12, 32, 128)    │              0 │ batch_normalization_2… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_27            │ (None, 12, 32, 64)     │              0 │ batch_normalization_2… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 12, 32, 512)    │              0 │ leaky_re_lu_21[0][0],  │
# │ (Concatenate)             │                        │                │ leaky_re_lu_23[0][0],  │
# │                           │                        │                │ leaky_re_lu_25[0][0],  │
# │                           │                        │                │ leaky_re_lu_27[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 6, 16, 512)     │              0 │ concatenate_3[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_31 (Conv2D)        │ (None, 6, 16, 256)     │        131,328 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_33 (Conv2D)        │ (None, 6, 16, 128)     │         65,664 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_29 (Conv2D)        │ (None, 6, 16, 512)     │        262,656 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_26    │ (None, 6, 16, 256)     │          1,024 │ conv2d_31[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_28    │ (None, 6, 16, 128)     │            512 │ conv2d_33[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_29            │ (None, 6, 16, 512)     │              0 │ conv2d_29[0][0]        │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_31            │ (None, 6, 16, 256)     │              0 │ batch_normalization_2… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_33            │ (None, 6, 16, 128)     │              0 │ batch_normalization_2… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_28 (Conv2D)        │ (None, 6, 16, 128)     │         65,664 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_30 (Conv2D)        │ (None, 6, 16, 512)     │      2,359,808 │ leaky_re_lu_29[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_32 (Conv2D)        │ (None, 6, 16, 256)     │      1,638,656 │ leaky_re_lu_31[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_34 (Conv2D)        │ (None, 6, 16, 128)     │        802,944 │ leaky_re_lu_33[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_24    │ (None, 6, 16, 128)     │            512 │ conv2d_28[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_25    │ (None, 6, 16, 512)     │          2,048 │ conv2d_30[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_27    │ (None, 6, 16, 256)     │          1,024 │ conv2d_32[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_29    │ (None, 6, 16, 128)     │            512 │ conv2d_34[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_28            │ (None, 6, 16, 128)     │              0 │ batch_normalization_2… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_30            │ (None, 6, 16, 512)     │              0 │ batch_normalization_2… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_32            │ (None, 6, 16, 256)     │              0 │ batch_normalization_2… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_34            │ (None, 6, 16, 128)     │              0 │ batch_normalization_2… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 6, 16, 1024)    │              0 │ leaky_re_lu_28[0][0],  │
# │ (Concatenate)             │                        │                │ leaky_re_lu_30[0][0],  │
# │                           │                        │                │ leaky_re_lu_32[0][0],  │
# │                           │                        │                │ leaky_re_lu_34[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 12, 32, 512)    │      4,719,104 │ concatenate_4[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_5             │ (None, 12, 32, 1024)   │              0 │ conv2d_transpose[0][0… │
# │ (Concatenate)             │                        │                │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_38 (Conv2D)        │ (None, 12, 32, 128)    │        131,200 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_40 (Conv2D)        │ (None, 12, 32, 64)     │         65,600 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_36 (Conv2D)        │ (None, 12, 32, 256)    │        262,400 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_32    │ (None, 12, 32, 128)    │            512 │ conv2d_38[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_34    │ (None, 12, 32, 64)     │            256 │ conv2d_40[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_36            │ (None, 12, 32, 256)    │              0 │ conv2d_36[0][0]        │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_38            │ (None, 12, 32, 128)    │              0 │ batch_normalization_3… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_40            │ (None, 12, 32, 64)     │              0 │ batch_normalization_3… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_35 (Conv2D)        │ (None, 12, 32, 64)     │         65,600 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_37 (Conv2D)        │ (None, 12, 32, 256)    │        590,080 │ leaky_re_lu_36[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_39 (Conv2D)        │ (None, 12, 32, 128)    │        409,728 │ leaky_re_lu_38[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_41 (Conv2D)        │ (None, 12, 32, 64)     │        200,768 │ leaky_re_lu_40[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_30    │ (None, 12, 32, 64)     │            256 │ conv2d_35[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_31    │ (None, 12, 32, 256)    │          1,024 │ conv2d_37[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_33    │ (None, 12, 32, 128)    │            512 │ conv2d_39[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_35    │ (None, 12, 32, 64)     │            256 │ conv2d_41[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_35            │ (None, 12, 32, 64)     │              0 │ batch_normalization_3… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_37            │ (None, 12, 32, 256)    │              0 │ batch_normalization_3… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_39            │ (None, 12, 32, 128)    │              0 │ batch_normalization_3… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_41            │ (None, 12, 32, 64)     │              0 │ batch_normalization_3… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_6             │ (None, 12, 32, 512)    │              0 │ leaky_re_lu_35[0][0],  │
# │ (Concatenate)             │                        │                │ leaky_re_lu_37[0][0],  │
# │                           │                        │                │ leaky_re_lu_39[0][0],  │
# │                           │                        │                │ leaky_re_lu_41[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 24, 64, 256)    │      1,179,904 │ concatenate_6[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_7             │ (None, 24, 64, 512)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_45 (Conv2D)        │ (None, 24, 64, 64)     │         32,832 │ concatenate_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_47 (Conv2D)        │ (None, 24, 64, 32)     │         16,416 │ concatenate_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_43 (Conv2D)        │ (None, 24, 64, 128)    │         65,664 │ concatenate_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_38    │ (None, 24, 64, 64)     │            256 │ conv2d_45[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_40    │ (None, 24, 64, 32)     │            128 │ conv2d_47[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_43            │ (None, 24, 64, 128)    │              0 │ conv2d_43[0][0]        │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_45            │ (None, 24, 64, 64)     │              0 │ batch_normalization_3… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_47            │ (None, 24, 64, 32)     │              0 │ batch_normalization_4… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_42 (Conv2D)        │ (None, 24, 64, 32)     │         16,416 │ concatenate_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_44 (Conv2D)        │ (None, 24, 64, 128)    │        147,584 │ leaky_re_lu_43[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_46 (Conv2D)        │ (None, 24, 64, 64)     │        102,464 │ leaky_re_lu_45[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_48 (Conv2D)        │ (None, 24, 64, 32)     │         50,208 │ leaky_re_lu_47[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_36    │ (None, 24, 64, 32)     │            128 │ conv2d_42[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_37    │ (None, 24, 64, 128)    │            512 │ conv2d_44[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_39    │ (None, 24, 64, 64)     │            256 │ conv2d_46[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_41    │ (None, 24, 64, 32)     │            128 │ conv2d_48[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_42            │ (None, 24, 64, 32)     │              0 │ batch_normalization_3… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_44            │ (None, 24, 64, 128)    │              0 │ batch_normalization_3… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_46            │ (None, 24, 64, 64)     │              0 │ batch_normalization_3… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_48            │ (None, 24, 64, 32)     │              0 │ batch_normalization_4… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_8             │ (None, 24, 64, 256)    │              0 │ leaky_re_lu_42[0][0],  │
# │ (Concatenate)             │                        │                │ leaky_re_lu_44[0][0],  │
# │                           │                        │                │ leaky_re_lu_46[0][0],  │
# │                           │                        │                │ leaky_re_lu_48[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 48, 128, 128)   │        295,040 │ concatenate_8[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_9             │ (None, 48, 128, 256)   │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_52 (Conv2D)        │ (None, 48, 128, 32)    │          8,224 │ concatenate_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_54 (Conv2D)        │ (None, 48, 128, 16)    │          4,112 │ concatenate_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_50 (Conv2D)        │ (None, 48, 128, 64)    │         16,448 │ concatenate_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_44    │ (None, 48, 128, 32)    │            128 │ conv2d_52[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_46    │ (None, 48, 128, 16)    │             64 │ conv2d_54[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_50            │ (None, 48, 128, 64)    │              0 │ conv2d_50[0][0]        │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_52            │ (None, 48, 128, 32)    │              0 │ batch_normalization_4… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_54            │ (None, 48, 128, 16)    │              0 │ batch_normalization_4… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_49 (Conv2D)        │ (None, 48, 128, 16)    │          4,112 │ concatenate_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_51 (Conv2D)        │ (None, 48, 128, 64)    │         36,928 │ leaky_re_lu_50[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_53 (Conv2D)        │ (None, 48, 128, 32)    │         25,632 │ leaky_re_lu_52[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_55 (Conv2D)        │ (None, 48, 128, 16)    │         12,560 │ leaky_re_lu_54[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_42    │ (None, 48, 128, 16)    │             64 │ conv2d_49[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_43    │ (None, 48, 128, 64)    │            256 │ conv2d_51[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_45    │ (None, 48, 128, 32)    │            128 │ conv2d_53[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_47    │ (None, 48, 128, 16)    │             64 │ conv2d_55[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_49            │ (None, 48, 128, 16)    │              0 │ batch_normalization_4… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_51            │ (None, 48, 128, 64)    │              0 │ batch_normalization_4… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_53            │ (None, 48, 128, 32)    │              0 │ batch_normalization_4… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_55            │ (None, 48, 128, 16)    │              0 │ batch_normalization_4… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_10            │ (None, 48, 128, 128)   │              0 │ leaky_re_lu_49[0][0],  │
# │ (Concatenate)             │                        │                │ leaky_re_lu_51[0][0],  │
# │                           │                        │                │ leaky_re_lu_53[0][0],  │
# │                           │                        │                │ leaky_re_lu_55[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 96, 256, 64)    │         73,792 │ concatenate_10[0][0]   │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_11            │ (None, 96, 256, 128)   │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_59 (Conv2D)        │ (None, 96, 256, 16)    │          2,064 │ concatenate_11[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_61 (Conv2D)        │ (None, 96, 256, 8)     │          1,032 │ concatenate_11[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_57 (Conv2D)        │ (None, 96, 256, 32)    │          4,128 │ concatenate_11[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_50    │ (None, 96, 256, 16)    │             64 │ conv2d_59[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_52    │ (None, 96, 256, 8)     │             32 │ conv2d_61[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_57            │ (None, 96, 256, 32)    │              0 │ conv2d_57[0][0]        │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_59            │ (None, 96, 256, 16)    │              0 │ batch_normalization_5… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_61            │ (None, 96, 256, 8)     │              0 │ batch_normalization_5… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_56 (Conv2D)        │ (None, 96, 256, 8)     │          1,032 │ concatenate_11[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_58 (Conv2D)        │ (None, 96, 256, 32)    │          9,248 │ leaky_re_lu_57[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_60 (Conv2D)        │ (None, 96, 256, 16)    │          6,416 │ leaky_re_lu_59[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_62 (Conv2D)        │ (None, 96, 256, 8)     │          3,144 │ leaky_re_lu_61[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_48    │ (None, 96, 256, 8)     │             32 │ conv2d_56[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_49    │ (None, 96, 256, 32)    │            128 │ conv2d_58[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_51    │ (None, 96, 256, 16)    │             64 │ conv2d_60[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_53    │ (None, 96, 256, 8)     │             32 │ conv2d_62[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_56            │ (None, 96, 256, 8)     │              0 │ batch_normalization_4… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_58            │ (None, 96, 256, 32)    │              0 │ batch_normalization_4… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_60            │ (None, 96, 256, 16)    │              0 │ batch_normalization_5… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_62            │ (None, 96, 256, 8)     │              0 │ batch_normalization_5… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_12            │ (None, 96, 256, 64)    │              0 │ leaky_re_lu_56[0][0],  │
# │ (Concatenate)             │                        │                │ leaky_re_lu_58[0][0],  │
# │                           │                        │                │ leaky_re_lu_60[0][0],  │
# │                           │                        │                │ leaky_re_lu_62[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ cropping2d (Cropping2D)   │ (None, 90, 250, 64)    │              0 │ concatenate_12[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_63 (Conv2D)        │ (None, 90, 250, 1)     │             65 │ cropping2d[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 15,671,505 (59.78 MB)
#  Trainable params: 15,663,409 (59.75 MB)
#  Non-trainable params: 8,096 (31.62 KB)

# %% [markdown]
# ## Train

# %% [markdown]
# ## Metric Regression

# %%
from tensorflow.keras import backend as K

@tf.keras.utils.register_keras_serializable()
def create_non_negative_mask(y_true):
    return K.cast(K.greater_equal(y_true, 0), K.floatx())  # Mask where y_true >= 0


@tf.keras.utils.register_keras_serializable()    
def CC(y_true, y_pred):
    mask = create_non_negative_mask(y_true)
    y_true_masked = y_true * mask
    y_pred_masked = y_pred * mask
    return K.mean((y_true_masked - K.mean(y_true_masked)) * 
                  (y_pred_masked - K.mean(y_pred_masked)) / 
                  (K.std(y_true_masked) * K.std(y_pred_masked) + K.epsilon()))
    
@tf.keras.utils.register_keras_serializable()
def R2(y_true, y_pred):
    mask = create_non_negative_mask(y_true)
    y_true_masked = y_true * mask
    y_pred_masked = y_pred * mask
    ss_total = K.sum(K.square(y_true_masked - K.mean(y_true_masked)))
    ss_residual = K.sum(K.square(y_true_masked - y_pred_masked))
    return 1 - (ss_residual / (ss_total + K.epsilon()))
    
@tf.keras.utils.register_keras_serializable()
def custom_mse_loss(y_true, y_pred):
    mask = create_non_negative_mask(y_true)
    y_true_masked = y_true * mask
    y_pred_masked = y_pred * mask
    squared_error = K.square(y_true_masked - y_pred_masked)
    return K.sum(squared_error) / (K.sum(mask) + K.epsilon())

@tf.keras.utils.register_keras_serializable()
def RMSE(y_true, y_pred):
    mask = create_non_negative_mask(y_true)
    y_true_masked = y_true * mask
    y_pred_masked = y_pred * mask
    squared_error = K.square(y_true_masked - y_pred_masked)
    mse = K.sum(squared_error) / (K.sum(mask) + K.epsilon())
    return K.sqrt(mse)

@tf.keras.utils.register_keras_serializable()
def weighted_sigmoid_mse(y_true, y_pred):
    scaling_factor=1
    threshold=0.05
    mask = create_non_negative_mask(y_true)
    y_norm = y_true / 260.0  # max y_train = 260
    weights = K.sigmoid(scaling_factor * (y_norm - threshold))  # Compute the weights using sigmoid
    weights_masked = weights * mask  
    y_true_masked = y_true * mask 
    y_pred_masked = y_pred * mask  
    squared_error = K.square(y_true_masked - y_pred_masked)  
    weighted_error = weights_masked * squared_error  # Apply weights
    return K.sum(weighted_error) / (K.sum(weights_masked) + K.epsilon())  # Normalize

# %% [markdown]
# ## Metric classification

# %%
@tf.keras.utils.register_keras_serializable()
def create_missing_data_mask(y):
    return K.cast(K.less(y, 0), K.floatx()) # Mask where y == -1 (missing data)

# Mask for classifying values greater than or equal to 0.5
@tf.keras.utils.register_keras_serializable()
def create_class_mask(y):
    return K.cast(K.greater_equal(y, 0.5), K.floatx())

@tf.keras.utils.register_keras_serializable()
def FAR(y_true, y_pred):
    missing_mask = create_missing_data_mask(y_true)  # 1 where missing
    valid_mask = 1.0 - missing_mask  # 1 where valid

    y_true_class = create_class_mask(y_true)
    y_pred_class = create_class_mask(y_pred)

    # Only consider positions where valid_mask == 1
    FP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 0), K.floatx()) * valid_mask)
    TP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 1), K.floatx()) * valid_mask)

    far = FP / (TP + FP + K.epsilon())
    return far

@tf.keras.utils.register_keras_serializable()
def POD(y_true, y_pred):
    # Mask for missing data and valid values
    missing_mask = create_missing_data_mask(y_true)
    valid_mask = 1.0 - missing_mask

    # Convert to binary class masks
    y_true_class = create_class_mask(y_true)
    y_pred_class = create_class_mask(y_pred)


    TP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 1), K.floatx()) * valid_mask)
    FN = K.sum(K.cast((y_pred_class == 0) & (y_true_class == 1), K.floatx()) * valid_mask)

    pod = TP / (TP + FN + K.epsilon())
    return pod

@tf.keras.utils.register_keras_serializable()
def CSI(y_true, y_pred):
    # Create the missing data mask
    missing_mask = create_missing_data_mask(y_true)
    valid_mask = 1.0 - missing_mask

    # Convert to binary class masks
    y_true_class = create_class_mask(y_true)
    y_pred_class = create_class_mask(y_pred)

    # TP, FP, FN (only on valid data)
    TP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 1), K.floatx()) * valid_mask)
    FP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 0), K.floatx()) * valid_mask)
    FN = K.sum(K.cast((y_pred_class == 0) & (y_true_class == 1), K.floatx()) * valid_mask)

    csi = TP / (TP + FP + FN + K.epsilon())
    return csi

# %% [markdown]
# ## Train .fit

# %%
optimizer = Adam(learning_rate=0.001)

# Callbacks
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True, mode='min', verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)

# Compile Model
model.compile(optimizer=optimizer, 
              loss=weighted_sigmoid_mse, 
              metrics=[RMSE, CC, R2, POD, FAR, CSI])

# Train Model
history = model.fit(X_train_scaled, y_train,
                    batch_size=32,
                    epochs=80,
                    verbose=1,
                    validation_data=(X_val_scaled, y_val),
                    callbacks=[checkpoint, reduce_lr, early_stopping])
# Out:
# Epoch 1/80
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746263815.831563      64 service.cc:148] XLA service 0x7b49b4002180 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746263815.832183      64 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1746263820.173842      64 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1746263865.121814      64 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - cc: 0.2527 - csi: 0.1837 - far: 0.7720 - loss: 5.2815 - pod: 0.5107 - r2: 0.0456 - rmse: 1.8081
# Epoch 1: val_loss improved from inf to 2.38857, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 174s 2s/step - cc: 0.2540 - csi: 0.1845 - far: 0.7708 - loss: 5.2656 - pod: 0.5111 - r2: 0.0464 - rmse: 1.8053 - val_cc: 0.1456 - val_csi: 0.0014 - val_far: 0.3993 - val_loss: 2.3886 - val_pod: 0.0014 - val_r2: 0.0033 - val_rmse: 1.4128 - learning_rate: 0.0010
# Epoch 2/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.3167 - csi: 0.2513 - far: 0.6829 - loss: 4.6170 - pod: 0.5504 - r2: 0.0957 - rmse: 1.6938
# Epoch 2: val_loss did not improve from 2.38857
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 342ms/step - cc: 0.3170 - csi: 0.2513 - far: 0.6828 - loss: 4.6127 - pod: 0.5502 - r2: 0.0956 - rmse: 1.6932 - val_cc: -0.0116 - val_csi: 0.0147 - val_far: 0.9824 - val_loss: 2.7542 - val_pod: 0.0827 - val_r2: -0.2243 - val_rmse: 1.5447 - learning_rate: 0.0010
# Epoch 3/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.3486 - csi: 0.2525 - far: 0.6700 - loss: 4.3020 - pod: 0.5269 - r2: 0.1158 - rmse: 1.6753
# Epoch 3: val_loss did not improve from 2.38857
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 341ms/step - cc: 0.3488 - csi: 0.2524 - far: 0.6701 - loss: 4.3032 - pod: 0.5266 - r2: 0.1158 - rmse: 1.6743 - val_cc: -0.0121 - val_csi: 0.0195 - val_far: 0.9750 - val_loss: 5.3076 - val_pod: 0.0862 - val_r2: -2.3242 - val_rmse: 2.2710 - learning_rate: 0.0010
# Epoch 4/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - cc: 0.3844 - csi: 0.2567 - far: 0.6815 - loss: 3.8462 - pod: 0.5716 - r2: 0.1309 - rmse: 1.5988
# Epoch 4: val_loss did not improve from 2.38857
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 342ms/step - cc: 0.3844 - csi: 0.2566 - far: 0.6815 - loss: 3.8556 - pod: 0.5713 - r2: 0.1309 - rmse: 1.5993 - val_cc: 8.6131e-04 - val_csi: 0.0509 - val_far: 0.9339 - val_loss: 7.0145 - val_pod: 0.1833 - val_r2: -2.9585 - val_rmse: 2.6106 - learning_rate: 0.0010
# Epoch 5/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - cc: 0.4122 - csi: 0.2766 - far: 0.6227 - loss: 3.0230 - pod: 0.5335 - r2: 0.1575 - rmse: 1.4222
# Epoch 5: val_loss did not improve from 2.38857
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - cc: 0.4117 - csi: 0.2766 - far: 0.6230 - loss: 3.0487 - pod: 0.5337 - r2: 0.1570 - rmse: 1.4256 - val_cc: 0.0815 - val_csi: 0.0761 - val_far: 0.9125 - val_loss: 2.7010 - val_pod: 0.3747 - val_r2: -0.2083 - val_rmse: 1.5305 - learning_rate: 0.0010
# Epoch 6/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.3911 - csi: 0.2421 - far: 0.6973 - loss: 4.3191 - pod: 0.5663 - r2: 0.1415 - rmse: 1.6281
# Epoch 6: val_loss did not improve from 2.38857
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 341ms/step - cc: 0.3910 - csi: 0.2424 - far: 0.6967 - loss: 4.3185 - pod: 0.5657 - r2: 0.1415 - rmse: 1.6283 - val_cc: 0.2297 - val_csi: 0.0755 - val_far: 0.9237 - val_loss: 4.6023 - val_pod: 0.8782 - val_r2: -1.4406 - val_rmse: 2.0869 - learning_rate: 0.0010
# Epoch 7/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.4286 - csi: 0.2703 - far: 0.6712 - loss: 3.2464 - pod: 0.6300 - r2: 0.1754 - rmse: 1.4911
# Epoch 7: val_loss did not improve from 2.38857
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.4285 - csi: 0.2703 - far: 0.6709 - loss: 3.2653 - pod: 0.6290 - r2: 0.1753 - rmse: 1.4931 - val_cc: 0.1071 - val_csi: 0.0502 - val_far: 0.9430 - val_loss: 3.1330 - val_pod: 0.3038 - val_r2: -0.4998 - val_rmse: 1.6785 - learning_rate: 5.0000e-04
# Epoch 8/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.4160 - csi: 0.2656 - far: 0.6646 - loss: 3.3965 - pod: 0.5628 - r2: 0.1796 - rmse: 1.5353
# Epoch 8: val_loss improved from 2.38857 to 2.08968, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 372ms/step - cc: 0.4162 - csi: 0.2658 - far: 0.6644 - loss: 3.4106 - pod: 0.5631 - r2: 0.1796 - rmse: 1.5371 - val_cc: 0.3550 - val_csi: 0.2036 - val_far: 0.7408 - val_loss: 2.0897 - val_pod: 0.4896 - val_r2: 0.1236 - val_rmse: 1.3208 - learning_rate: 5.0000e-04
# Epoch 9/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - cc: 0.4192 - csi: 0.2843 - far: 0.6267 - loss: 4.4123 - pod: 0.5558 - r2: 0.1786 - rmse: 1.6614
# Epoch 9: val_loss did not improve from 2.08968
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - cc: 0.4194 - csi: 0.2841 - far: 0.6269 - loss: 4.4065 - pod: 0.5559 - r2: 0.1784 - rmse: 1.6603 - val_cc: 0.2277 - val_csi: 0.1382 - val_far: 0.8493 - val_loss: 2.5469 - val_pod: 0.6328 - val_r2: -0.1682 - val_rmse: 1.4918 - learning_rate: 5.0000e-04
# Epoch 10/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - cc: 0.4305 - csi: 0.2729 - far: 0.6650 - loss: 3.7204 - pod: 0.6048 - r2: 0.1819 - rmse: 1.5732
# Epoch 10: val_loss improved from 2.08968 to 1.97308, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 370ms/step - cc: 0.4306 - csi: 0.2730 - far: 0.6646 - loss: 3.7278 - pod: 0.6041 - r2: 0.1819 - rmse: 1.5740 - val_cc: 0.4256 - val_csi: 0.2904 - val_far: 0.6150 - val_loss: 1.9731 - val_pod: 0.5412 - val_r2: 0.1746 - val_rmse: 1.2814 - learning_rate: 5.0000e-04
# Epoch 11/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.4562 - csi: 0.2946 - far: 0.6409 - loss: 3.5714 - pod: 0.6200 - r2: 0.2000 - rmse: 1.4920
# Epoch 11: val_loss did not improve from 1.97308
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 341ms/step - cc: 0.4560 - csi: 0.2944 - far: 0.6411 - loss: 3.5812 - pod: 0.6196 - r2: 0.1999 - rmse: 1.4938 - val_cc: 0.3862 - val_csi: 0.2301 - val_far: 0.7065 - val_loss: 2.0473 - val_pod: 0.5212 - val_r2: 0.1343 - val_rmse: 1.3098 - learning_rate: 5.0000e-04
# Epoch 12/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - cc: 0.4242 - csi: 0.2919 - far: 0.6459 - loss: 4.8016 - pod: 0.6256 - r2: 0.1827 - rmse: 1.7640
# Epoch 12: val_loss did not improve from 1.97308
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - cc: 0.4246 - csi: 0.2918 - far: 0.6459 - loss: 4.7859 - pod: 0.6252 - r2: 0.1828 - rmse: 1.7604 - val_cc: 0.3887 - val_csi: 0.1964 - val_far: 0.7779 - val_loss: 2.0616 - val_pod: 0.6315 - val_r2: 0.1248 - val_rmse: 1.3152 - learning_rate: 5.0000e-04
# Epoch 13/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.4845 - csi: 0.2893 - far: 0.6498 - loss: 3.2385 - pod: 0.6333 - r2: 0.2323 - rmse: 1.4741
# Epoch 13: val_loss did not improve from 1.97308
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.4840 - csi: 0.2893 - far: 0.6495 - loss: 3.2541 - pod: 0.6326 - r2: 0.2314 - rmse: 1.4765 - val_cc: 0.3433 - val_csi: 0.2158 - val_far: 0.7477 - val_loss: 2.2551 - val_pod: 0.5999 - val_r2: 0.0121 - val_rmse: 1.3845 - learning_rate: 5.0000e-04
# Epoch 14/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - cc: 0.4102 - csi: 0.2867 - far: 0.6483 - loss: 5.5389 - pod: 0.6171 - r2: 0.1439 - rmse: 1.8455
# Epoch 14: val_loss did not improve from 1.97308
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - cc: 0.4110 - csi: 0.2867 - far: 0.6482 - loss: 5.5087 - pod: 0.6169 - r2: 0.1450 - rmse: 1.8400 - val_cc: 0.3603 - val_csi: 0.1983 - val_far: 0.7669 - val_loss: 2.4356 - val_pod: 0.5758 - val_r2: -0.0737 - val_rmse: 1.4454 - learning_rate: 5.0000e-04
# Epoch 15/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.4593 - csi: 0.2915 - far: 0.6329 - loss: 3.8241 - pod: 0.5886 - r2: 0.1950 - rmse: 1.5737
# Epoch 15: val_loss improved from 1.97308 to 1.95960, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 373ms/step - cc: 0.4594 - csi: 0.2913 - far: 0.6331 - loss: 3.8256 - pod: 0.5888 - r2: 0.1951 - rmse: 1.5741 - val_cc: 0.4294 - val_csi: 0.2724 - val_far: 0.6544 - val_loss: 1.9596 - val_pod: 0.5627 - val_r2: 0.1785 - val_rmse: 1.2763 - learning_rate: 5.0000e-04
# Epoch 16/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - cc: 0.4473 - csi: 0.2771 - far: 0.6433 - loss: 3.6846 - pod: 0.5704 - r2: 0.1706 - rmse: 1.5232
# Epoch 16: val_loss did not improve from 1.95960
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - cc: 0.4471 - csi: 0.2772 - far: 0.6430 - loss: 3.6910 - pod: 0.5702 - r2: 0.1706 - rmse: 1.5245 - val_cc: 0.4040 - val_csi: 0.2927 - val_far: 0.6002 - val_loss: 2.0198 - val_pod: 0.5210 - val_r2: 0.1536 - val_rmse: 1.2970 - learning_rate: 5.0000e-04
# Epoch 17/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.4497 - csi: 0.2721 - far: 0.6533 - loss: 3.9996 - pod: 0.6063 - r2: 0.1734 - rmse: 1.5664
# Epoch 17: val_loss did not improve from 1.95960
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.4495 - csi: 0.2721 - far: 0.6531 - loss: 4.0010 - pod: 0.6058 - r2: 0.1732 - rmse: 1.5671 - val_cc: 0.4269 - val_csi: 0.2731 - val_far: 0.6549 - val_loss: 1.9739 - val_pod: 0.5699 - val_r2: 0.1580 - val_rmse: 1.2871 - learning_rate: 5.0000e-04
# Epoch 18/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.4625 - csi: 0.2757 - far: 0.6573 - loss: 4.9859 - pod: 0.5897 - r2: 0.2023 - rmse: 1.7495
# Epoch 18: val_loss did not improve from 1.95960
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.4629 - csi: 0.2760 - far: 0.6569 - loss: 4.9656 - pod: 0.5898 - r2: 0.2025 - rmse: 1.7460 - val_cc: 0.4325 - val_csi: 0.2262 - val_far: 0.7421 - val_loss: 2.2380 - val_pod: 0.6487 - val_r2: 0.0324 - val_rmse: 1.3788 - learning_rate: 5.0000e-04
# Epoch 19/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.4975 - csi: 0.2959 - far: 0.6265 - loss: 3.1256 - pod: 0.5992 - r2: 0.2239 - rmse: 1.4709
# Epoch 19: val_loss did not improve from 1.95960
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 341ms/step - cc: 0.4972 - csi: 0.2960 - far: 0.6264 - loss: 3.1419 - pod: 0.5994 - r2: 0.2234 - rmse: 1.4727 - val_cc: 0.4231 - val_csi: 0.2348 - val_far: 0.7282 - val_loss: 2.0894 - val_pod: 0.6364 - val_r2: 0.1092 - val_rmse: 1.3228 - learning_rate: 5.0000e-04
# Epoch 20/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.4552 - csi: 0.2758 - far: 0.6568 - loss: 5.6993 - pod: 0.5913 - r2: 0.2040 - rmse: 1.7753
# Epoch 20: val_loss did not improve from 1.95960
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 341ms/step - cc: 0.4559 - csi: 0.2762 - far: 0.6560 - loss: 5.6636 - pod: 0.5912 - r2: 0.2041 - rmse: 1.7712 - val_cc: 0.3911 - val_csi: 0.2496 - val_far: 0.7004 - val_loss: 2.0312 - val_pod: 0.6010 - val_r2: 0.1377 - val_rmse: 1.3049 - learning_rate: 5.0000e-04
# Epoch 21/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.4855 - csi: 0.3106 - far: 0.6131 - loss: 3.9248 - pod: 0.6106 - r2: 0.2445 - rmse: 1.5218
# Epoch 21: val_loss did not improve from 1.95960
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 341ms/step - cc: 0.4855 - csi: 0.3104 - far: 0.6132 - loss: 3.9223 - pod: 0.6103 - r2: 0.2443 - rmse: 1.5219 - val_cc: 0.4279 - val_csi: 0.2393 - val_far: 0.7308 - val_loss: 1.9688 - val_pod: 0.6838 - val_r2: 0.1644 - val_rmse: 1.2837 - learning_rate: 2.5000e-04
# Epoch 22/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.4830 - csi: 0.2896 - far: 0.6445 - loss: 3.5536 - pod: 0.6028 - r2: 0.2073 - rmse: 1.5131
# Epoch 22: val_loss did not improve from 1.95960
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 341ms/step - cc: 0.4831 - csi: 0.2898 - far: 0.6443 - loss: 3.5581 - pod: 0.6030 - r2: 0.2076 - rmse: 1.5136 - val_cc: 0.4358 - val_csi: 0.2683 - val_far: 0.6848 - val_loss: 1.9602 - val_pod: 0.6442 - val_r2: 0.1763 - val_rmse: 1.2766 - learning_rate: 2.5000e-04
# Epoch 23/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.5071 - csi: 0.3022 - far: 0.6180 - loss: 2.6977 - pod: 0.5963 - r2: 0.2492 - rmse: 1.3233
# Epoch 23: val_loss improved from 1.95960 to 1.93612, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 371ms/step - cc: 0.5068 - csi: 0.3023 - far: 0.6180 - loss: 2.7198 - pod: 0.5964 - r2: 0.2490 - rmse: 1.3270 - val_cc: 0.4395 - val_csi: 0.2845 - val_far: 0.6249 - val_loss: 1.9361 - val_pod: 0.5421 - val_r2: 0.1826 - val_rmse: 1.2712 - learning_rate: 2.5000e-04
# Epoch 24/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.5000 - csi: 0.3089 - far: 0.6083 - loss: 3.0169 - pod: 0.5989 - r2: 0.2131 - rmse: 1.4201
# Epoch 24: val_loss did not improve from 1.93612
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.4999 - csi: 0.3088 - far: 0.6086 - loss: 3.0314 - pod: 0.5991 - r2: 0.2129 - rmse: 1.4227 - val_cc: 0.4409 - val_csi: 0.2748 - val_far: 0.6736 - val_loss: 2.0324 - val_pod: 0.6363 - val_r2: 0.1131 - val_rmse: 1.3148 - learning_rate: 2.5000e-04
# Epoch 25/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.5171 - csi: 0.2990 - far: 0.6294 - loss: 3.2311 - pod: 0.6077 - r2: 0.2164 - rmse: 1.4291
# Epoch 25: val_loss improved from 1.93612 to 1.92177, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 372ms/step - cc: 0.5170 - csi: 0.2991 - far: 0.6293 - loss: 3.2399 - pod: 0.6078 - r2: 0.2160 - rmse: 1.4305 - val_cc: 0.4482 - val_csi: 0.2912 - val_far: 0.6329 - val_loss: 1.9218 - val_pod: 0.5865 - val_r2: 0.1858 - val_rmse: 1.2671 - learning_rate: 2.5000e-04
# Epoch 26/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.5166 - csi: 0.3138 - far: 0.6049 - loss: 2.8834 - pod: 0.6009 - r2: 0.2669 - rmse: 1.4269
# Epoch 26: val_loss did not improve from 1.92177
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - cc: 0.5167 - csi: 0.3138 - far: 0.6049 - loss: 2.8982 - pod: 0.6009 - r2: 0.2666 - rmse: 1.4285 - val_cc: 0.4363 - val_csi: 0.2435 - val_far: 0.7198 - val_loss: 1.9821 - val_pod: 0.6512 - val_r2: 0.1548 - val_rmse: 1.2910 - learning_rate: 2.5000e-04
# Epoch 27/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.5105 - csi: 0.3001 - far: 0.6280 - loss: 3.7999 - pod: 0.5997 - r2: 0.2166 - rmse: 1.5898
# Epoch 27: val_loss did not improve from 1.92177
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - cc: 0.5107 - csi: 0.3002 - far: 0.6279 - loss: 3.7975 - pod: 0.5995 - r2: 0.2172 - rmse: 1.5884 - val_cc: 0.4308 - val_csi: 0.2882 - val_far: 0.5886 - val_loss: 1.9589 - val_pod: 0.4906 - val_r2: 0.1803 - val_rmse: 1.2767 - learning_rate: 2.5000e-04
# Epoch 28/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.5319 - csi: 0.3023 - far: 0.6112 - loss: 3.2058 - pod: 0.5917 - r2: 0.2481 - rmse: 1.4530
# Epoch 28: val_loss improved from 1.92177 to 1.91818, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 371ms/step - cc: 0.5313 - csi: 0.3021 - far: 0.6117 - loss: 3.2184 - pod: 0.5921 - r2: 0.2474 - rmse: 1.4551 - val_cc: 0.4496 - val_csi: 0.2987 - val_far: 0.5792 - val_loss: 1.9182 - val_pod: 0.5072 - val_r2: 0.1965 - val_rmse: 1.2624 - learning_rate: 2.5000e-04
# Epoch 29/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - cc: 0.4924 - csi: 0.3070 - far: 0.5896 - loss: 4.9972 - pod: 0.5510 - r2: 0.2283 - rmse: 1.7050
# Epoch 29: val_loss improved from 1.91818 to 1.88743, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 369ms/step - cc: 0.4929 - csi: 0.3071 - far: 0.5898 - loss: 4.9678 - pod: 0.5515 - r2: 0.2288 - rmse: 1.7010 - val_cc: 0.4552 - val_csi: 0.2779 - val_far: 0.6661 - val_loss: 1.8874 - val_pod: 0.6234 - val_r2: 0.2048 - val_rmse: 1.2533 - learning_rate: 2.5000e-04
# Epoch 30/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.5599 - csi: 0.3065 - far: 0.6178 - loss: 3.5229 - pod: 0.6124 - r2: 0.2933 - rmse: 1.5310
# Epoch 30: val_loss did not improve from 1.88743
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - cc: 0.5590 - csi: 0.3065 - far: 0.6176 - loss: 3.5213 - pod: 0.6123 - r2: 0.2925 - rmse: 1.5300 - val_cc: 0.4416 - val_csi: 0.2930 - val_far: 0.5721 - val_loss: 1.9302 - val_pod: 0.4802 - val_r2: 0.1908 - val_rmse: 1.2670 - learning_rate: 2.5000e-04
# Epoch 31/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.5504 - csi: 0.2984 - far: 0.5955 - loss: 3.5820 - pod: 0.5309 - r2: 0.2955 - rmse: 1.4841
# Epoch 31: val_loss did not improve from 1.88743
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.5497 - csi: 0.2983 - far: 0.5958 - loss: 3.5810 - pod: 0.5315 - r2: 0.2943 - rmse: 1.4848 - val_cc: 0.3716 - val_csi: 0.2740 - val_far: 0.6637 - val_loss: 2.1293 - val_pod: 0.5979 - val_r2: 0.1070 - val_rmse: 1.3313 - learning_rate: 2.5000e-04
# Epoch 32/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.4673 - csi: 0.2994 - far: 0.6328 - loss: 2.9107 - pod: 0.6230 - r2: 0.2067 - rmse: 1.4216
# Epoch 32: val_loss did not improve from 1.88743
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.4676 - csi: 0.2994 - far: 0.6326 - loss: 2.9289 - pod: 0.6224 - r2: 0.2070 - rmse: 1.4242 - val_cc: 0.4192 - val_csi: 0.2742 - val_far: 0.6159 - val_loss: 1.9538 - val_pod: 0.4899 - val_r2: 0.1764 - val_rmse: 1.2769 - learning_rate: 2.5000e-04
# Epoch 33/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - cc: 0.4949 - csi: 0.3090 - far: 0.5938 - loss: 3.7480 - pod: 0.5679 - r2: 0.1967 - rmse: 1.5819
# Epoch 33: val_loss did not improve from 1.88743
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.4953 - csi: 0.3089 - far: 0.5941 - loss: 3.7433 - pod: 0.5682 - r2: 0.1975 - rmse: 1.5801 - val_cc: 0.4317 - val_csi: 0.2581 - val_far: 0.6923 - val_loss: 1.9492 - val_pod: 0.6162 - val_r2: 0.1816 - val_rmse: 1.2729 - learning_rate: 2.5000e-04
# Epoch 34/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.5497 - csi: 0.3221 - far: 0.5909 - loss: 3.1653 - pod: 0.6046 - r2: 0.2963 - rmse: 1.4270
# Epoch 34: val_loss did not improve from 1.88743
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.5492 - csi: 0.3218 - far: 0.5913 - loss: 3.1718 - pod: 0.6044 - r2: 0.2957 - rmse: 1.4283 - val_cc: 0.4202 - val_csi: 0.2972 - val_far: 0.5577 - val_loss: 1.9566 - val_pod: 0.4739 - val_r2: 0.1744 - val_rmse: 1.2786 - learning_rate: 2.5000e-04
# Epoch 35/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.5561 - csi: 0.3070 - far: 0.6092 - loss: 2.2042 - pod: 0.5855 - r2: 0.2943 - rmse: 1.2890
# Epoch 35: val_loss did not improve from 1.88743
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 342ms/step - cc: 0.5559 - csi: 0.3071 - far: 0.6088 - loss: 2.2268 - pod: 0.5853 - r2: 0.2942 - rmse: 1.2923 - val_cc: 0.4550 - val_csi: 0.3065 - val_far: 0.5751 - val_loss: 1.8936 - val_pod: 0.5238 - val_r2: 0.2033 - val_rmse: 1.2553 - learning_rate: 1.2500e-04
# Epoch 36/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.5484 - csi: 0.3024 - far: 0.6104 - loss: 2.8218 - pod: 0.5820 - r2: 0.3064 - rmse: 1.3117
# Epoch 36: val_loss did not improve from 1.88743
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 341ms/step - cc: 0.5483 - csi: 0.3026 - far: 0.6101 - loss: 2.8291 - pod: 0.5820 - r2: 0.3063 - rmse: 1.3140 - val_cc: 0.4597 - val_csi: 0.3036 - val_far: 0.5969 - val_loss: 1.8886 - val_pod: 0.5509 - val_r2: 0.2048 - val_rmse: 1.2542 - learning_rate: 1.2500e-04
# Epoch 37/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.5383 - csi: 0.3242 - far: 0.5905 - loss: 5.9166 - pod: 0.6094 - r2: 0.3027 - rmse: 1.7883
# Epoch 37: val_loss did not improve from 1.88743
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.5389 - csi: 0.3240 - far: 0.5906 - loss: 5.8610 - pod: 0.6090 - r2: 0.3031 - rmse: 1.7806 - val_cc: 0.4584 - val_csi: 0.2970 - val_far: 0.6150 - val_loss: 1.8935 - val_pod: 0.5652 - val_r2: 0.2057 - val_rmse: 1.2543 - learning_rate: 1.2500e-04
# Epoch 38/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.5519 - csi: 0.3134 - far: 0.5883 - loss: 2.5100 - pod: 0.5669 - r2: 0.3174 - rmse: 1.3235
# Epoch 38: val_loss improved from 1.88743 to 1.88059, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 373ms/step - cc: 0.5519 - csi: 0.3134 - far: 0.5885 - loss: 2.5225 - pod: 0.5672 - r2: 0.3172 - rmse: 1.3251 - val_cc: 0.4635 - val_csi: 0.3069 - val_far: 0.5900 - val_loss: 1.8806 - val_pod: 0.5492 - val_r2: 0.2074 - val_rmse: 1.2515 - learning_rate: 1.2500e-04
# Epoch 39/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.5518 - csi: 0.3141 - far: 0.5876 - loss: 3.4520 - pod: 0.5580 - r2: 0.3224 - rmse: 1.3866
# Epoch 39: val_loss improved from 1.88059 to 1.87118, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 372ms/step - cc: 0.5517 - csi: 0.3141 - far: 0.5878 - loss: 3.4447 - pod: 0.5583 - r2: 0.3220 - rmse: 1.3868 - val_cc: 0.4616 - val_csi: 0.2968 - val_far: 0.6089 - val_loss: 1.8712 - val_pod: 0.5522 - val_r2: 0.2106 - val_rmse: 1.2482 - learning_rate: 1.2500e-04
# Epoch 40/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.5562 - csi: 0.3067 - far: 0.5961 - loss: 2.3290 - pod: 0.5607 - r2: 0.3169 - rmse: 1.2608
# Epoch 40: val_loss did not improve from 1.87118
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 341ms/step - cc: 0.5565 - csi: 0.3069 - far: 0.5960 - loss: 2.3432 - pod: 0.5611 - r2: 0.3175 - rmse: 1.2641 - val_cc: 0.4710 - val_csi: 0.2933 - val_far: 0.6359 - val_loss: 1.8795 - val_pod: 0.6032 - val_r2: 0.2099 - val_rmse: 1.2500 - learning_rate: 1.2500e-04
# Epoch 41/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.5524 - csi: 0.3138 - far: 0.5958 - loss: 2.1947 - pod: 0.5858 - r2: 0.3177 - rmse: 1.2709
# Epoch 41: val_loss did not improve from 1.87118
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 341ms/step - cc: 0.5523 - csi: 0.3138 - far: 0.5959 - loss: 2.2114 - pod: 0.5859 - r2: 0.3176 - rmse: 1.2734 - val_cc: 0.4643 - val_csi: 0.2962 - val_far: 0.6250 - val_loss: 1.9342 - val_pod: 0.5866 - val_r2: 0.1785 - val_rmse: 1.2717 - learning_rate: 1.2500e-04
# Epoch 42/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.5739 - csi: 0.3115 - far: 0.5901 - loss: 3.4244 - pod: 0.5715 - r2: 0.3354 - rmse: 1.4894
# Epoch 42: val_loss improved from 1.87118 to 1.86922, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 372ms/step - cc: 0.5737 - csi: 0.3116 - far: 0.5900 - loss: 3.4160 - pod: 0.5715 - r2: 0.3352 - rmse: 1.4877 - val_cc: 0.4653 - val_csi: 0.2938 - val_far: 0.6264 - val_loss: 1.8692 - val_pod: 0.5815 - val_r2: 0.2160 - val_rmse: 1.2455 - learning_rate: 1.2500e-04
# Epoch 43/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.5719 - csi: 0.3056 - far: 0.6016 - loss: 4.2061 - pod: 0.5668 - r2: 0.3555 - rmse: 1.5471
# Epoch 43: val_loss did not improve from 1.86922
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.5722 - csi: 0.3058 - far: 0.6014 - loss: 4.1811 - pod: 0.5671 - r2: 0.3556 - rmse: 1.5438 - val_cc: 0.4720 - val_csi: 0.2989 - val_far: 0.6235 - val_loss: 1.8718 - val_pod: 0.5931 - val_r2: 0.2136 - val_rmse: 1.2471 - learning_rate: 1.2500e-04
# Epoch 44/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.6030 - csi: 0.3127 - far: 0.5966 - loss: 2.3457 - pod: 0.5892 - r2: 0.3715 - rmse: 1.2467
# Epoch 44: val_loss improved from 1.86922 to 1.85880, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 370ms/step - cc: 0.6027 - csi: 0.3127 - far: 0.5965 - loss: 2.3588 - pod: 0.5891 - r2: 0.3710 - rmse: 1.2496 - val_cc: 0.4767 - val_csi: 0.3002 - val_far: 0.6231 - val_loss: 1.8588 - val_pod: 0.5964 - val_r2: 0.2224 - val_rmse: 1.2412 - learning_rate: 1.2500e-04
# Epoch 45/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.5386 - csi: 0.2952 - far: 0.6196 - loss: 3.3003 - pod: 0.5715 - r2: 0.3021 - rmse: 1.5022
# Epoch 45: val_loss did not improve from 1.85880
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - cc: 0.5389 - csi: 0.2956 - far: 0.6191 - loss: 3.2956 - pod: 0.5717 - r2: 0.3024 - rmse: 1.5003 - val_cc: 0.4679 - val_csi: 0.2981 - val_far: 0.6123 - val_loss: 1.8760 - val_pod: 0.5657 - val_r2: 0.2164 - val_rmse: 1.2459 - learning_rate: 1.2500e-04
# Epoch 46/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.5512 - csi: 0.3172 - far: 0.6001 - loss: 3.8458 - pod: 0.6104 - r2: 0.3131 - rmse: 1.4884
# Epoch 46: val_loss did not improve from 1.85880
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.5515 - csi: 0.3171 - far: 0.6000 - loss: 3.8291 - pod: 0.6101 - r2: 0.3134 - rmse: 1.4863 - val_cc: 0.4660 - val_csi: 0.3104 - val_far: 0.5857 - val_loss: 1.9037 - val_pod: 0.5548 - val_r2: 0.1986 - val_rmse: 1.2585 - learning_rate: 1.2500e-04
# Epoch 47/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.5872 - csi: 0.3274 - far: 0.5710 - loss: 2.8464 - pod: 0.5787 - r2: 0.3685 - rmse: 1.4271
# Epoch 47: val_loss improved from 1.85880 to 1.84400, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 370ms/step - cc: 0.5869 - csi: 0.3273 - far: 0.5712 - loss: 2.8479 - pod: 0.5788 - r2: 0.3680 - rmse: 1.4263 - val_cc: 0.4811 - val_csi: 0.3010 - val_far: 0.6146 - val_loss: 1.8440 - val_pod: 0.5799 - val_r2: 0.2280 - val_rmse: 1.2361 - learning_rate: 1.2500e-04
# Epoch 48/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.5707 - csi: 0.3159 - far: 0.5968 - loss: 2.4320 - pod: 0.5885 - r2: 0.3301 - rmse: 1.2685
# Epoch 48: val_loss did not improve from 1.84400
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.5706 - csi: 0.3158 - far: 0.5969 - loss: 2.4421 - pod: 0.5884 - r2: 0.3298 - rmse: 1.2704 - val_cc: 0.4819 - val_csi: 0.2951 - val_far: 0.6292 - val_loss: 1.8848 - val_pod: 0.5919 - val_r2: 0.2070 - val_rmse: 1.2520 - learning_rate: 1.2500e-04
# Epoch 49/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.5902 - csi: 0.3196 - far: 0.5850 - loss: 2.8245 - pod: 0.5825 - r2: 0.3656 - rmse: 1.3790
# Epoch 49: val_loss did not improve from 1.84400
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - cc: 0.5901 - csi: 0.3196 - far: 0.5850 - loss: 2.8261 - pod: 0.5824 - r2: 0.3654 - rmse: 1.3793 - val_cc: 0.4766 - val_csi: 0.2760 - val_far: 0.6735 - val_loss: 1.8812 - val_pod: 0.6418 - val_r2: 0.2108 - val_rmse: 1.2503 - learning_rate: 1.2500e-04
# Epoch 50/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.5989 - csi: 0.3247 - far: 0.5782 - loss: 2.2798 - pod: 0.5797 - r2: 0.3726 - rmse: 1.2554
# Epoch 50: val_loss did not improve from 1.84400
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.5986 - csi: 0.3246 - far: 0.5783 - loss: 2.2916 - pod: 0.5798 - r2: 0.3723 - rmse: 1.2578 - val_cc: 0.4744 - val_csi: 0.2693 - val_far: 0.6847 - val_loss: 1.8944 - val_pod: 0.6486 - val_r2: 0.2041 - val_rmse: 1.2555 - learning_rate: 1.2500e-04
# Epoch 51/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.5884 - csi: 0.3227 - far: 0.5898 - loss: 3.2852 - pod: 0.6080 - r2: 0.3571 - rmse: 1.4333
# Epoch 51: val_loss did not improve from 1.84400
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.5882 - csi: 0.3226 - far: 0.5898 - loss: 3.2768 - pod: 0.6076 - r2: 0.3569 - rmse: 1.4321 - val_cc: 0.4723 - val_csi: 0.3148 - val_far: 0.5766 - val_loss: 1.9007 - val_pod: 0.5520 - val_r2: 0.2088 - val_rmse: 1.2545 - learning_rate: 1.2500e-04
# Epoch 52/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.6018 - csi: 0.3148 - far: 0.6060 - loss: 3.2655 - pod: 0.6118 - r2: 0.3835 - rmse: 1.4853
# Epoch 52: val_loss did not improve from 1.84400
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.6016 - csi: 0.3149 - far: 0.6057 - loss: 3.2580 - pod: 0.6113 - r2: 0.3831 - rmse: 1.4831 - val_cc: 0.4717 - val_csi: 0.3098 - val_far: 0.5910 - val_loss: 1.9662 - val_pod: 0.5605 - val_r2: 0.1795 - val_rmse: 1.2787 - learning_rate: 1.2500e-04
# Epoch 53/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.5845 - csi: 0.3353 - far: 0.5691 - loss: 2.1804 - pod: 0.6024 - r2: 0.3505 - rmse: 1.2736
# Epoch 53: val_loss did not improve from 1.84400
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.5848 - csi: 0.3351 - far: 0.5693 - loss: 2.1936 - pod: 0.6024 - r2: 0.3511 - rmse: 1.2752 - val_cc: 0.4863 - val_csi: 0.3185 - val_far: 0.5575 - val_loss: 1.8440 - val_pod: 0.5325 - val_r2: 0.2318 - val_rmse: 1.2352 - learning_rate: 6.2500e-05
# Epoch 54/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.6182 - csi: 0.3226 - far: 0.5851 - loss: 3.7009 - pod: 0.5911 - r2: 0.3891 - rmse: 1.3817
# Epoch 54: val_loss improved from 1.84400 to 1.84219, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 372ms/step - cc: 0.6178 - csi: 0.3225 - far: 0.5852 - loss: 3.6830 - pod: 0.5909 - r2: 0.3888 - rmse: 1.3807 - val_cc: 0.4806 - val_csi: 0.2837 - val_far: 0.6419 - val_loss: 1.8422 - val_pod: 0.5777 - val_r2: 0.2312 - val_rmse: 1.2349 - learning_rate: 6.2500e-05
# Epoch 55/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.6322 - csi: 0.3236 - far: 0.5835 - loss: 4.6080 - pod: 0.5950 - r2: 0.4097 - rmse: 1.5544
# Epoch 55: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 341ms/step - cc: 0.6320 - csi: 0.3236 - far: 0.5836 - loss: 4.5714 - pod: 0.5950 - r2: 0.4093 - rmse: 1.5499 - val_cc: 0.4847 - val_csi: 0.2914 - val_far: 0.6229 - val_loss: 1.8527 - val_pod: 0.5628 - val_r2: 0.2291 - val_rmse: 1.2376 - learning_rate: 6.2500e-05
# Epoch 56/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.5952 - csi: 0.3065 - far: 0.6010 - loss: 2.3802 - pod: 0.5658 - r2: 0.3638 - rmse: 1.2497
# Epoch 56: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.5952 - csi: 0.3066 - far: 0.6009 - loss: 2.3886 - pod: 0.5661 - r2: 0.3639 - rmse: 1.2513 - val_cc: 0.4849 - val_csi: 0.2959 - val_far: 0.6253 - val_loss: 1.8613 - val_pod: 0.5842 - val_r2: 0.2226 - val_rmse: 1.2425 - learning_rate: 6.2500e-05
# Epoch 57/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.5838 - csi: 0.3113 - far: 0.6006 - loss: 3.7483 - pod: 0.5819 - r2: 0.3676 - rmse: 1.4629
# Epoch 57: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 341ms/step - cc: 0.5842 - csi: 0.3114 - far: 0.6004 - loss: 3.7288 - pod: 0.5820 - r2: 0.3680 - rmse: 1.4603 - val_cc: 0.4838 - val_csi: 0.2855 - val_far: 0.6427 - val_loss: 1.8710 - val_pod: 0.5869 - val_r2: 0.2182 - val_rmse: 1.2459 - learning_rate: 6.2500e-05
# Epoch 58/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.6183 - csi: 0.3251 - far: 0.5823 - loss: 2.1820 - pod: 0.5929 - r2: 0.3911 - rmse: 1.2089
# Epoch 58: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.6181 - csi: 0.3250 - far: 0.5824 - loss: 2.1937 - pod: 0.5928 - r2: 0.3910 - rmse: 1.2115 - val_cc: 0.4848 - val_csi: 0.2918 - val_far: 0.6307 - val_loss: 1.8737 - val_pod: 0.5815 - val_r2: 0.2173 - val_rmse: 1.2468 - learning_rate: 6.2500e-05
# Epoch 59/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.5977 - csi: 0.3035 - far: 0.6062 - loss: 2.7024 - pod: 0.5713 - r2: 0.3687 - rmse: 1.3638
# Epoch 59: val_loss did not improve from 1.84219
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 341ms/step - cc: 0.5979 - csi: 0.3038 - far: 0.6060 - loss: 2.7033 - pod: 0.5716 - r2: 0.3690 - rmse: 1.3630 - val_cc: 0.4857 - val_csi: 0.3127 - val_far: 0.5794 - val_loss: 1.8576 - val_pod: 0.5492 - val_r2: 0.2267 - val_rmse: 1.2400 - learning_rate: 6.2500e-05
# Epoch 60/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.6384 - csi: 0.3244 - far: 0.5713 - loss: 2.1427 - pod: 0.5749 - r2: 0.4211 - rmse: 1.2481
# Epoch 60: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - cc: 0.6379 - csi: 0.3244 - far: 0.5716 - loss: 2.1551 - pod: 0.5752 - r2: 0.4206 - rmse: 1.2493 - val_cc: 0.4865 - val_csi: 0.2945 - val_far: 0.6252 - val_loss: 1.8656 - val_pod: 0.5787 - val_r2: 0.2223 - val_rmse: 1.2434 - learning_rate: 3.1250e-05
# Epoch 61/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.5915 - csi: 0.3304 - far: 0.5687 - loss: 3.4294 - pod: 0.5839 - r2: 0.3693 - rmse: 1.5204
# Epoch 61: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 341ms/step - cc: 0.5920 - csi: 0.3302 - far: 0.5690 - loss: 3.4155 - pod: 0.5839 - r2: 0.3698 - rmse: 1.5169 - val_cc: 0.4872 - val_csi: 0.2981 - val_far: 0.6180 - val_loss: 1.8424 - val_pod: 0.5754 - val_r2: 0.2336 - val_rmse: 1.2342 - learning_rate: 3.1250e-05
# Epoch 62/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.6234 - csi: 0.3128 - far: 0.5965 - loss: 2.5534 - pod: 0.5801 - r2: 0.3996 - rmse: 1.3220
# Epoch 62: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.6234 - csi: 0.3129 - far: 0.5963 - loss: 2.5566 - pod: 0.5803 - r2: 0.3997 - rmse: 1.3222 - val_cc: 0.4870 - val_csi: 0.3034 - val_far: 0.6046 - val_loss: 1.8451 - val_pod: 0.5654 - val_r2: 0.2321 - val_rmse: 1.2354 - learning_rate: 3.1250e-05
# Epoch 63/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.6259 - csi: 0.3329 - far: 0.5699 - loss: 3.6240 - pod: 0.5939 - r2: 0.4059 - rmse: 1.4574
# Epoch 63: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.6258 - csi: 0.3328 - far: 0.5700 - loss: 3.6059 - pod: 0.5938 - r2: 0.4057 - rmse: 1.4542 - val_cc: 0.4816 - val_csi: 0.2889 - val_far: 0.6297 - val_loss: 1.8585 - val_pod: 0.5678 - val_r2: 0.2262 - val_rmse: 1.2404 - learning_rate: 3.1250e-05
# Epoch 64/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.6424 - csi: 0.3151 - far: 0.5941 - loss: 3.0255 - pod: 0.5850 - r2: 0.4234 - rmse: 1.3648
# Epoch 64: val_loss did not improve from 1.84219
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - cc: 0.6421 - csi: 0.3151 - far: 0.5941 - loss: 3.0193 - pod: 0.5851 - r2: 0.4231 - rmse: 1.3638 - val_cc: 0.4863 - val_csi: 0.3074 - val_far: 0.5930 - val_loss: 1.8503 - val_pod: 0.5561 - val_r2: 0.2295 - val_rmse: 1.2376 - learning_rate: 3.1250e-05
# Epoch 65/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.5762 - csi: 0.3162 - far: 0.5846 - loss: 3.3922 - pod: 0.5688 - r2: 0.3439 - rmse: 1.3494
# Epoch 65: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.5771 - csi: 0.3164 - far: 0.5844 - loss: 3.3782 - pod: 0.5689 - r2: 0.3449 - rmse: 1.3486 - val_cc: 0.4873 - val_csi: 0.3038 - val_far: 0.6039 - val_loss: 1.8512 - val_pod: 0.5652 - val_r2: 0.2285 - val_rmse: 1.2381 - learning_rate: 1.5625e-05
# Epoch 66/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.6293 - csi: 0.3283 - far: 0.5761 - loss: 2.1895 - pod: 0.5904 - r2: 0.4037 - rmse: 1.2309
# Epoch 66: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.6291 - csi: 0.3281 - far: 0.5763 - loss: 2.1996 - pod: 0.5903 - r2: 0.4035 - rmse: 1.2329 - val_cc: 0.4847 - val_csi: 0.2970 - val_far: 0.6158 - val_loss: 1.8549 - val_pod: 0.5662 - val_r2: 0.2265 - val_rmse: 1.2396 - learning_rate: 1.5625e-05
# Epoch 67/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.6506 - csi: 0.3199 - far: 0.5789 - loss: 2.4417 - pod: 0.5744 - r2: 0.4376 - rmse: 1.2911
# Epoch 67: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.6502 - csi: 0.3199 - far: 0.5790 - loss: 2.4466 - pod: 0.5746 - r2: 0.4370 - rmse: 1.2915 - val_cc: 0.4855 - val_csi: 0.2973 - val_far: 0.6183 - val_loss: 1.8642 - val_pod: 0.5728 - val_r2: 0.2225 - val_rmse: 1.2431 - learning_rate: 1.5625e-05
# Epoch 68/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.6120 - csi: 0.3232 - far: 0.5829 - loss: 2.6259 - pod: 0.5861 - r2: 0.3899 - rmse: 1.3193
# Epoch 68: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - cc: 0.6121 - csi: 0.3231 - far: 0.5829 - loss: 2.6268 - pod: 0.5860 - r2: 0.3899 - rmse: 1.3192 - val_cc: 0.4847 - val_csi: 0.2965 - val_far: 0.6195 - val_loss: 1.8775 - val_pod: 0.5724 - val_r2: 0.2177 - val_rmse: 1.2475 - learning_rate: 1.5625e-05
# Epoch 69/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.6102 - csi: 0.3200 - far: 0.5887 - loss: 3.0510 - pod: 0.5903 - r2: 0.3821 - rmse: 1.3337
# Epoch 69: val_loss did not improve from 1.84219
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.6107 - csi: 0.3201 - far: 0.5885 - loss: 3.0436 - pod: 0.5902 - r2: 0.3827 - rmse: 1.3331 - val_cc: 0.4846 - val_csi: 0.2990 - val_far: 0.6133 - val_loss: 1.8714 - val_pod: 0.5680 - val_r2: 0.2201 - val_rmse: 1.2453 - learning_rate: 1.5625e-05
# Epoch 70/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.6358 - csi: 0.3210 - far: 0.5877 - loss: 2.9453 - pod: 0.5914 - r2: 0.4179 - rmse: 1.3101
# Epoch 70: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.6356 - csi: 0.3209 - far: 0.5877 - loss: 2.9402 - pod: 0.5912 - r2: 0.4176 - rmse: 1.3099 - val_cc: 0.4845 - val_csi: 0.3025 - val_far: 0.6035 - val_loss: 1.8653 - val_pod: 0.5598 - val_r2: 0.2230 - val_rmse: 1.2430 - learning_rate: 7.8125e-06
# Epoch 71/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.6433 - csi: 0.3193 - far: 0.5842 - loss: 2.0687 - pod: 0.5773 - r2: 0.4254 - rmse: 1.2417
# Epoch 71: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - cc: 0.6429 - csi: 0.3193 - far: 0.5843 - loss: 2.0808 - pod: 0.5775 - r2: 0.4250 - rmse: 1.2434 - val_cc: 0.4844 - val_csi: 0.3022 - val_far: 0.6046 - val_loss: 1.8662 - val_pod: 0.5613 - val_r2: 0.2224 - val_rmse: 1.2434 - learning_rate: 7.8125e-06
# Epoch 72/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.6517 - csi: 0.3300 - far: 0.5668 - loss: 3.0531 - pod: 0.5924 - r2: 0.4347 - rmse: 1.4128
# Epoch 72: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.6513 - csi: 0.3298 - far: 0.5671 - loss: 3.0455 - pod: 0.5923 - r2: 0.4342 - rmse: 1.4107 - val_cc: 0.4851 - val_csi: 0.3028 - val_far: 0.6038 - val_loss: 1.8640 - val_pod: 0.5616 - val_r2: 0.2232 - val_rmse: 1.2427 - learning_rate: 7.8125e-06
# Epoch 73/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.6261 - csi: 0.3270 - far: 0.5775 - loss: 2.5533 - pod: 0.5893 - r2: 0.4044 - rmse: 1.2555
# Epoch 73: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.6260 - csi: 0.3270 - far: 0.5775 - loss: 2.5555 - pod: 0.5890 - r2: 0.4043 - rmse: 1.2567 - val_cc: 0.4843 - val_csi: 0.3024 - val_far: 0.6043 - val_loss: 1.8647 - val_pod: 0.5612 - val_r2: 0.2228 - val_rmse: 1.2430 - learning_rate: 7.8125e-06
# Epoch 74/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.6422 - csi: 0.3231 - far: 0.5831 - loss: 1.9961 - pod: 0.5904 - r2: 0.4201 - rmse: 1.2148
# Epoch 74: val_loss did not improve from 1.84219
#
# Epoch 74: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.6418 - csi: 0.3232 - far: 0.5830 - loss: 2.0095 - pod: 0.5903 - r2: 0.4197 - rmse: 1.2170 - val_cc: 0.4835 - val_csi: 0.2996 - val_far: 0.6116 - val_loss: 1.8654 - val_pod: 0.5665 - val_r2: 0.2222 - val_rmse: 1.2434 - learning_rate: 7.8125e-06
# Epoch 75/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.5979 - csi: 0.3159 - far: 0.5842 - loss: 3.4868 - pod: 0.5655 - r2: 0.3747 - rmse: 1.3868
# Epoch 75: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - cc: 0.5983 - csi: 0.3160 - far: 0.5842 - loss: 3.4706 - pod: 0.5659 - r2: 0.3751 - rmse: 1.3847 - val_cc: 0.4835 - val_csi: 0.3005 - val_far: 0.6085 - val_loss: 1.8611 - val_pod: 0.5631 - val_r2: 0.2243 - val_rmse: 1.2416 - learning_rate: 3.9063e-06
# Epoch 76/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.6507 - csi: 0.3212 - far: 0.5871 - loss: 2.2863 - pod: 0.5886 - r2: 0.4314 - rmse: 1.2424
# Epoch 76: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.6502 - csi: 0.3210 - far: 0.5872 - loss: 2.2938 - pod: 0.5883 - r2: 0.4310 - rmse: 1.2440 - val_cc: 0.4837 - val_csi: 0.3020 - val_far: 0.6037 - val_loss: 1.8600 - val_pod: 0.5586 - val_r2: 0.2248 - val_rmse: 1.2412 - learning_rate: 3.9063e-06
# Epoch 77/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.6452 - csi: 0.3344 - far: 0.5679 - loss: 3.3000 - pod: 0.5957 - r2: 0.4310 - rmse: 1.3982
# Epoch 77: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.6449 - csi: 0.3342 - far: 0.5681 - loss: 3.2873 - pod: 0.5955 - r2: 0.4305 - rmse: 1.3966 - val_cc: 0.4839 - val_csi: 0.3021 - val_far: 0.6036 - val_loss: 1.8639 - val_pod: 0.5589 - val_r2: 0.2232 - val_rmse: 1.2426 - learning_rate: 3.9063e-06
# Epoch 78/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.5558 - csi: 0.3047 - far: 0.6056 - loss: 2.6289 - pod: 0.5685 - r2: 0.3309 - rmse: 1.2985
# Epoch 78: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - cc: 0.5570 - csi: 0.3051 - far: 0.6051 - loss: 2.6294 - pod: 0.5687 - r2: 0.3323 - rmse: 1.2986 - val_cc: 0.4845 - val_csi: 0.3030 - val_far: 0.6025 - val_loss: 1.8660 - val_pod: 0.5598 - val_r2: 0.2222 - val_rmse: 1.2435 - learning_rate: 3.9063e-06
# Epoch 79/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - cc: 0.6156 - csi: 0.3193 - far: 0.5875 - loss: 2.2045 - pod: 0.5803 - r2: 0.3889 - rmse: 1.2233
# Epoch 79: val_loss did not improve from 1.84219
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - cc: 0.6156 - csi: 0.3193 - far: 0.5874 - loss: 2.2141 - pod: 0.5803 - r2: 0.3889 - rmse: 1.2248 - val_cc: 0.4847 - val_csi: 0.3031 - val_far: 0.6019 - val_loss: 1.8673 - val_pod: 0.5589 - val_r2: 0.2219 - val_rmse: 1.2438 - learning_rate: 3.9063e-06
# Epoch 80/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - cc: 0.6309 - csi: 0.3207 - far: 0.5846 - loss: 2.4231 - pod: 0.5836 - r2: 0.4054 - rmse: 1.2848
# Epoch 80: val_loss did not improve from 1.84219
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 341ms/step - cc: 0.6306 - csi: 0.3207 - far: 0.5845 - loss: 2.4280 - pod: 0.5836 - r2: 0.4051 - rmse: 1.2852 - val_cc: 0.4844 - val_csi: 0.3026 - val_far: 0.6024 - val_loss: 1.8664 - val_pod: 0.5582 - val_r2: 0.2221 - val_rmse: 1.2436 - learning_rate: 1.9531e-06
# Restoring model weights from the end of the best epoch: 54.

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Metric valid set

# %%
best_epoch = np.argmin(history.history['val_loss'])

# Print all metrics for that epoch
print(f"Best Epoch: {best_epoch + 1}")
for metric in history.history.keys():
    print(f"{metric}: {history.history[metric][best_epoch]:.4f}")
# Out:
# Best Epoch: 54
# cc: 0.6018
# csi: 0.3180
# far: 0.5870
# loss: 2.8037
# pod: 0.5787
# r2: 0.3746
# rmse: 1.3335
# val_cc: 0.4806
# val_csi: 0.2837
# val_far: 0.6419
# val_loss: 1.8422
# val_pod: 0.5777
# val_r2: 0.2312
# val_rmse: 1.2349
# learning_rate: 0.0001

# %%
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix
from scipy.stats import pearsonr
from tensorflow.keras.models import load_model

# %% [markdown]
# ## Metric test set

# %%
best_model = load_model('/kaggle/working/best_model.keras')
y_test_pred = best_model.predict(X_test_scaled)
y_test_pred_flat = y_test_pred.flatten()
y_test_flat = y_test.flatten()

# Mask to exclude missing data 
mask = y_test_flat >= 0

# Apply mask to filter out missing data
y_test_flat_filtered = y_test_flat[mask]
y_test_pred_flat_filtered = y_test_pred_flat[mask]

mse = mean_squared_error(y_test_flat_filtered, y_test_pred_flat_filtered)
rmse = np.sqrt(mse)
cc, _ = pearsonr(y_test_flat_filtered, y_test_pred_flat_filtered)
r2 = r2_score(y_test_flat_filtered, y_test_pred_flat_filtered)

print("Test set")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"Correlation Coefficient (CC): {cc}")
print(f"R²: {r2}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 602ms/step
# Test set
# MSE: 1.9359917640686035
# RMSE: 1.3913992643356323
# Correlation Coefficient (CC): 0.47557932138442993
# R²: 0.22297031239363563

# %%
from sklearn.metrics import confusion_matrix
true_class_mask = y_test_flat >= 0.5
pred_class_mask = y_test_pred_flat >= 0.5


true_class_mask = np.where(mask, true_class_mask, -1)
pred_class_mask = np.where(mask, pred_class_mask, -1)

valid_mask = (true_class_mask != -1) & (pred_class_mask != -1)
true_class_mask_filtered = true_class_mask[valid_mask]
pred_class_mask_filtered = pred_class_mask[valid_mask]
cm = confusion_matrix(true_class_mask_filtered, pred_class_mask_filtered)

# If cm is a 2x2 matrix, unpack it
if cm.shape == (2, 2):
    tn, fp, fn, tp = cm.ravel()
else:
    # Handle cases where there's no confusion matrix (only one class present)
    tn = cm[0, 0] if cm.shape[0] > 1 else 1
    fp = cm[0, 1] if cm.shape[1] > 1 else 0
    fn = cm[1, 0] if cm.shape[0] > 1 else 0
    tp = cm[1, 1] if cm.shape[1] > 1 else 1

far = fp / (tp + fp) if (tp + fp) > 0 else 0.0

# Probability of Detection (POD) = TP / (TP + FN)
pod = tp / (tp + fn) if (tp + fn) > 0 else 0.0

# Critical Success Index (CSI) = TP / (TP + FP + FN)
csi = tp / (tp + fp + fn) if (tp + fp + fn) > 0 else 0.0

# Print the metrics
print(f"FAR: {far}")
print(f"POD: {pod}")
print(f"CSI: {csi}")
# Out:
# FAR: 0.6170725622969395
# POD: 0.6102295641012132
# CSI: 0.3076744747645496

# %% [markdown]
# ## Plot

# %%
num_examples = 16  # Number of examples to visualize
plt.figure(figsize=(20, 5 * num_examples))
random_indices = np.random.choice(len(y_test), size=num_examples, replace=False)
np.random.seed(42)
for i, index in enumerate(random_indices):
    
    predicted_image = y_test_pred[index]
    radar_image = y_test[index]
    
    mask = radar_image >= 0
    predicted_image[~mask] = -np.inf
    radar_image[~mask] = -np.inf
    vmin = 0
    vmax_true = np.max(radar_image)
    vmax_pred = np.max(predicted_image)
    vmax = np.max([vmax_true, vmax_pred])

    plt.subplot(num_examples, 2, i * 2 + 1)
    im1 = plt.imshow(radar_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Actual Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im1, fraction=0.046, pad=0.04)

    # Plot predicted image
    plt.subplot(num_examples, 2, i * 2 + 2)
    im2 = plt.imshow(predicted_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Predicted Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im2, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()

# %%
num_examples = len(random_indices)
cols = 4
rows = (num_examples + cols - 1) // cols

plt.figure(figsize=(cols * 5, rows * 4))  # Adjust size as needed

for i, index in enumerate(random_indices):
    predicted_image = y_test_pred[index]
    radar_image = y_test[index]
    
    # Mask invalid values
    mask = radar_image >= 0
    predicted_image = predicted_image[mask]
    radar_image = radar_image[mask]
    
    # Scatter plot
    plt.subplot(rows, cols, i + 1)
    plt.scatter(radar_image.flatten(), predicted_image.flatten(), alpha=0.6, s=10)
    plt.title(f'Image #{index}', fontsize=10)
    plt.xlabel('Actual', fontsize=8)
    plt.ylabel('Predicted', fontsize=8)
    plt.axis('equal')
    plt.xticks(fontsize=6)
    plt.yticks(fontsize=6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot val

# %%
y_val_pred = best_model.predict(X_val_scaled)

plt.figure(figsize=(20, 5 * num_examples))
for i, index in enumerate(random_indices):
    
    predicted_image = y_val_pred[index]
    radar_image = y_val[index]
    
    mask = radar_image >= 0
    predicted_image[~mask] = -np.inf
    radar_image[~mask] = -np.inf
    vmin = 0
    vmax_true = np.max(radar_image)
    vmax_pred = np.max(predicted_image)
    vmax = np.max([vmax_true, vmax_pred])

    plt.subplot(num_examples, 2, i * 2 + 1)
    im1 = plt.imshow(radar_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Actual Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im1, fraction=0.046, pad=0.04)

    # Plot predicted image
    plt.subplot(num_examples, 2, i * 2 + 2)
    im2 = plt.imshow(predicted_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Predicted Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im2, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step

# %%
plt.figure(figsize=(20, 5 * num_examples))
for i, index in enumerate(random_indices):
    
    predicted_image = y_val_pred[index]
    radar_image = y_val[index]
    
    mask = radar_image >= 0
    radar_image[~mask] = -np.inf
    vmin = 0
    vmax_true = np.max(radar_image)
    vmax_pred = np.max(predicted_image)
    vmax = np.max([vmax_true, vmax_pred])

    plt.subplot(num_examples, 2, i * 2 + 1)
    im1 = plt.imshow(radar_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Actual Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im1, fraction=0.046, pad=0.04)

    # Plot predicted image
    plt.subplot(num_examples, 2, i * 2 + 2)
    im2 = plt.imshow(predicted_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Predicted Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im2, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
