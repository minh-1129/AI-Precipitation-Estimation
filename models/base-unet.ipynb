# %%
# !pip install rasterio h5py
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (3.12.1)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio) (2025.1.31)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio) (8.1.8)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.11/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.11/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from rasterio) (3.2.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24->rasterio) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.24->rasterio) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.24->rasterio) (2024.2.0)
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 88.2 MB/s eta 0:00:00
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.4.3

# %%
import os
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
import rasterio
import matplotlib.pyplot as plt
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.losses import Huber
print(tf.__version__)
# Out:
# 2025-05-01 03:42:24.159920: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746070944.349657      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746070944.404144      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2.18.0

# %%
DATA_PATH = "/kaggle/input/data-rain-v2/DATA_RAIN_V2"
# ERA5_ATTRIBUTES = ["CAPE", "CIN", "EWSS", "IE", "ISOR", "KX", "PEV", "R250", "R500", "R850", "SLHF", "SLOR", "SSHF","TCLW","TCW","TCWV", "U250", "U850","V250", "V850"]
# HIMA_BANDS = ["B09B", "B10B", "B11B","B12B", "B14B", "B16B", "IRB", "I2B", "I4B", "WVB"]
ERA5_ATTRIBUTES = ["CAPE", "CIN", "EWSS", "IE", "ISOR", "KX", "PEV", "R250", "R500", "R850", "SLHF", "SLOR", "SSHF","TCLW","TCW","TCWV", "U250", "U850","V250", "V850"]
HIMA_BANDS = ["B09B", "B10B", "B11B","B12B", "B14B", "B16B", "IRB", "I2B", "I4B", "WVB"]
print(len(ERA5_ATTRIBUTES ))
print(len(HIMA_BANDS))
# Out:
# 20
# 10

# %% [markdown]
# # 1. Load dữ liệu

# %% [markdown]
# ## 1.1. Hàm lấy file

# %%
def convert_time_to_strings(year, month, day, hour):
    year_str = str(year)
    month_str = f"{int(month):02d}"
    day_str = f"{int(day):02d}"
    hour_str = f"{int(hour):02d}"
    return year_str, month_str, day_str, hour_str

def get_era5_file_path(attribute, year, month, day, hour):
    year, month, day, hour = convert_time_to_strings(year, month, day, hour)
    file_name = f"ERA5_{attribute}_{year}_{month}_{day}_{hour}.tif"
    file_path = os.path.join(DATA_PATH, year, month, day, hour, "ERA5", file_name)
    return file_path


def get_hima_file_path(band, year, month, day, hour):
    year, month, day, hour = convert_time_to_strings(year, month, day, hour)
    file_name = f"Hima_{band}_{year}_{month}_{day}_{hour}.tif"
    file_path = os.path.join(DATA_PATH, year, month, day, hour, "Hima", file_name)
    return file_path

def get_radar_file_path(year, month, day, hour):
    year, month, day, hour = convert_time_to_strings(year, month, day, hour)
    file_name = f"Radar_{year}_{month}_{day}_{hour}.tif"
    file_path = os.path.join(DATA_PATH, year, month, day, hour, "Radar", file_name)
    return file_path

# %% [markdown]
# ## 1.2. Load file

# %%
def load_era5_attributes(year, month, day, hour):
    era5_imgs= []
    for attribute in ERA5_ATTRIBUTES:
        file_path = get_era5_file_path(attribute, year, month, day, hour)
        try:
            with rasterio.open(file_path) as src:
                era5_imgs.append(src.read(1)) 
        except Exception as e:
            print(f"Failed to load {attribute} for {year}-{month}-{day} {hour}:00:00 {e}")
    era5_data = np.stack(era5_imgs, axis=-1)  
    return era5_data

def load_hima_bands(year, month, day, hour):
    hima_imgs = []
    for band in HIMA_BANDS:
        file_path = get_hima_file_path(band, year, month, day, hour)
        try:
            with rasterio.open(file_path) as src:
                hima_imgs.append(src.read(1))
        except Exception as e:
                print(f"Failed to load {band} for {year}-{month}-{day} {hour}:00:00 {e}")
    hima_data = np.stack(hima_imgs, axis = -1)
    return hima_data

def load_radar(year, month, day, hour):
    radar_img = None
    file_path = get_radar_file_path(year, month, day, hour)
    try: 
        with rasterio.open(file_path) as src:
            radar_img = src.read(1)
    except Exception as e:
        print(f"Failed to load radar for {year}-{month}-{day} {hour}:00:00 {e}")
    return radar_img

# %%
def load_data_for_timestamp(year, month, day, hour, use_era5 = True):
    try:
        era5_data = None
        if use_era5:
            era5_data = load_era5_attributes(year, month, day, hour)

        hima_data = load_hima_bands(year, month, day, hour)
        radar_data = load_radar(year, month, day, hour)
        if use_era5:
            input_images = np.concatenate((hima_data, era5_data), axis = -1) #shape (90, 250, hima + era5)
        else:
            input_images = hima_data

        return input_images, radar_data

    except Exception as e:
        print(f"Failed to load data for {year}-{month}-{day} {hour}:00:00 {e}")
        return None, None

# %%
def load_dataset(timestamps_df, use_era5 = True):
    X = []
    y = []
    timestamps_tuples = list(timestamps_df[['year', 'month', 'day', 'hour']].itertuples(index=False, name=None))
    for year, month, day, hour in tqdm(timestamps_tuples):
        input_images, radar_image = load_data_for_timestamp(year, month, day, hour, use_era5)
        if input_images is not None and radar_image is not None:
            X.append(input_images)
            y.append(radar_image)
    
    X = np.array(X)
    y = np.array(y)
    y = y[..., np.newaxis] #(90, 250, 1)
    return X, y

# %% [markdown]
# ## 1.3. Chia dữ liệu

# %%
rain_df = pd.read_csv("/kaggle/input/valid-time-rain/final_rain_timestamps.csv", index_col=None)
rain_df.drop(columns = ['Unnamed: 0'], inplace = True)
train_df, tmp_df = train_test_split(
    rain_df, test_size = 0.3, stratify=rain_df["radar_mean_class"], random_state = 42
)

val_df, test_df = train_test_split(
    tmp_df, test_size=0.5, stratify=tmp_df["radar_mean_class"], random_state=42
)

# %% [markdown]
# ## USE_ERA5

# %%
USE_ERA5 = False

# %% [markdown]
# ## 1.4. Scale dữ liệu

# %%
X_train, y_train = load_dataset(train_df, USE_ERA5)
X_val, y_val = load_dataset(val_df, USE_ERA5)
X_test, y_test = load_dataset(test_df, USE_ERA5)
# Out:
# 100%|██████████| 1562/1562 [03:01<00:00,  8.59it/s]
# 100%|██████████| 335/335 [00:38<00:00,  8.76it/s]
# 100%|██████████| 335/335 [00:40<00:00,  8.34it/s]

# %%
# np.savez_compressed('/kaggle/working/raindataset.npz', X_train=X_train, y_train=y_train, X_val = X_val, y_val = y_val, X_test = X_test, y_test = y_test)

# %%
y_train.max()
# Out:
# 260.0

# %%
y_val.max()
# Out:
# 231.0

# %%
y_test.max()
# Out:
# 234.71875

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_X = MinMaxScaler()

X_train_reshaped = X_train.reshape(-1, X_train.shape[-1]) #(num_sample * 250 * 90, hima + era5)
scaler_X.fit(X_train_reshaped)

X_train_scaled = scaler_X.transform(X_train_reshaped).reshape(X_train.shape)
X_val_scaled = scaler_X.transform(X_val.reshape(-1, X_val.shape[-1])).reshape(X_val.shape)
X_test_scaled = scaler_X.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

# %% [markdown]
# # Xử lý -inf

# %%
y_train = np.where(y_train < 0, -1, y_train)
y_val = np.where(y_val < 0, -1, y_val)
y_test = np.where(y_test < 0, -1, y_test)

# %% [markdown]
# # 2. Train

# %% [markdown]
# ## 2.1. Tham số mô hình

# %%
BATCH_SIZE = 32
NUM_FILTERS = [64, 128, 256, 512]
BOTTLENECK_FILTER = 1024
EPOCHS = 100

# %% [markdown]
# ## 2.2. Tạo mô hình

# %%
def conv_block(inputs, num_filters, kernel_size = 3):
    x = Conv2D(num_filters, kernel_size=kernel_size, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    x = conv_block(x, num_filters)
    p = MaxPooling2D(pool_size=(2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, kernel_size=3, strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    x = conv_block(x, num_filters)
    return x

# %%
def Unet(input_shape):
    inputs = Input(shape=input_shape, name="input")
    x = ZeroPadding2D(padding=((3, 3), (3, 3)))(inputs) #90 x 250 -> 96 x 256
    skip_connections = []
    #(96, 256) -> (48, 128) -> (24, 64) -> (12, 32) -> (6, 16)
    for num_filters in NUM_FILTERS:
        skip, x = encoder_block(x, num_filters)
        skip_connections.append(skip)

    x = conv_block(x, BOTTLENECK_FILTER)
    x = conv_block(x, BOTTLENECK_FILTER)

    skip_connections = skip_connections[::-1]
    
    for num_filters, skip in zip(NUM_FILTERS[::-1], skip_connections):
        x = decoder_block(x, skip, num_filters)
    

    x = Cropping2D(cropping=((3, 3), (3, 3)))(x)  # (96x256) → (90x250)
    outputs = Conv2D(1, kernel_size = 1, padding = 'same', activation='relu')(x)
    model = Model(inputs, outputs)
    return model

# %%
channel = None
if USE_ERA5:
    channel = len(HIMA_BANDS) + len(ERA5_ATTRIBUTES)
else:
    channel = len(HIMA_BANDS)
    
input_shape = (90, 250, channel)
model = Unet(input_shape)
model.summary()
# Out:
# I0000 00:00:1746071228.097103      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)        │ (None, 90, 250, 10)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ zero_padding2d            │ (None, 96, 256, 10)    │              0 │ input[0][0]            │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 96, 256, 64)    │          5,824 │ zero_padding2d[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 96, 256, 64)    │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu (ReLU)              │ (None, 96, 256, 64)    │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 96, 256, 64)    │         36,928 │ re_lu[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 96, 256, 64)    │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1 (ReLU)            │ (None, 96, 256, 64)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 48, 128, 64)    │              0 │ re_lu_1[0][0]          │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 48, 128, 128)   │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 48, 128, 128)   │            512 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_2 (ReLU)            │ (None, 48, 128, 128)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 48, 128, 128)   │        147,584 │ re_lu_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 48, 128, 128)   │            512 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_3 (ReLU)            │ (None, 48, 128, 128)   │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 24, 64, 128)    │              0 │ re_lu_3[0][0]          │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 24, 64, 256)    │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 24, 64, 256)    │          1,024 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_4 (ReLU)            │ (None, 24, 64, 256)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 24, 64, 256)    │        590,080 │ re_lu_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 24, 64, 256)    │          1,024 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_5 (ReLU)            │ (None, 24, 64, 256)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 12, 32, 256)    │              0 │ re_lu_5[0][0]          │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 12, 32, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 12, 32, 512)    │          2,048 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_6 (ReLU)            │ (None, 12, 32, 512)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 12, 32, 512)    │      2,359,808 │ re_lu_6[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 12, 32, 512)    │          2,048 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_7 (ReLU)            │ (None, 12, 32, 512)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 6, 16, 512)     │              0 │ re_lu_7[0][0]          │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 6, 16, 1024)    │      4,719,616 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 6, 16, 1024)    │          4,096 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_8 (ReLU)            │ (None, 6, 16, 1024)    │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 6, 16, 1024)    │      9,438,208 │ re_lu_8[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 6, 16, 1024)    │          4,096 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_9 (ReLU)            │ (None, 6, 16, 1024)    │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 12, 32, 512)    │      4,719,104 │ re_lu_9[0][0]          │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 12, 32, 1024)   │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ re_lu_7[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 12, 32, 512)    │      4,719,104 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 12, 32, 512)    │          2,048 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_10 (ReLU)           │ (None, 12, 32, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 12, 32, 512)    │      2,359,808 │ re_lu_10[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 12, 32, 512)    │          2,048 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_11 (ReLU)           │ (None, 12, 32, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 24, 64, 256)    │      1,179,904 │ re_lu_11[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 24, 64, 512)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ re_lu_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 24, 64, 256)    │      1,179,904 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 24, 64, 256)    │          1,024 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_12 (ReLU)           │ (None, 24, 64, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 24, 64, 256)    │        590,080 │ re_lu_12[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 24, 64, 256)    │          1,024 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_13 (ReLU)           │ (None, 24, 64, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 48, 128, 128)   │        295,040 │ re_lu_13[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 48, 128, 256)   │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ re_lu_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 48, 128, 128)   │        295,040 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 48, 128, 128)   │            512 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_14 (ReLU)           │ (None, 48, 128, 128)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 48, 128, 128)   │        147,584 │ re_lu_14[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 48, 128, 128)   │            512 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_15 (ReLU)           │ (None, 48, 128, 128)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 96, 256, 64)    │         73,792 │ re_lu_15[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 96, 256, 128)   │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ re_lu_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 96, 256, 64)    │         73,792 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 96, 256, 64)    │            256 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_16 (ReLU)           │ (None, 96, 256, 64)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 96, 256, 64)    │         36,928 │ re_lu_16[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 96, 256, 64)    │            256 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_17 (ReLU)           │ (None, 96, 256, 64)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ cropping2d (Cropping2D)   │ (None, 90, 250, 64)    │              0 │ re_lu_17[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 90, 250, 1)     │             65 │ cropping2d[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 34,540,929 (131.76 MB)
#  Trainable params: 34,529,153 (131.72 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %% [markdown]
# ## Train

# %% [markdown]
# ## Metric Regression

# %%
from tensorflow.keras import backend as K

@tf.keras.utils.register_keras_serializable()
def create_non_negative_mask(y_true):
    return K.cast(K.greater_equal(y_true, 0), K.floatx())  # Mask where y_true >= 0


@tf.keras.utils.register_keras_serializable()    
def CC(y_true, y_pred):
    mask = create_non_negative_mask(y_true)
    y_true_masked = y_true * mask
    y_pred_masked = y_pred * mask
    return K.mean((y_true_masked - K.mean(y_true_masked)) * 
                  (y_pred_masked - K.mean(y_pred_masked)) / 
                  (K.std(y_true_masked) * K.std(y_pred_masked) + K.epsilon()))
    
@tf.keras.utils.register_keras_serializable()
def R2(y_true, y_pred):
    mask = create_non_negative_mask(y_true)
    y_true_masked = y_true * mask
    y_pred_masked = y_pred * mask
    ss_total = K.sum(K.square(y_true_masked - K.mean(y_true_masked)))
    ss_residual = K.sum(K.square(y_true_masked - y_pred_masked))
    return 1 - (ss_residual / (ss_total + K.epsilon()))
    
@tf.keras.utils.register_keras_serializable()
def custom_mse_loss(y_true, y_pred):
    mask = create_non_negative_mask(y_true)
    y_true_masked = y_true * mask
    y_pred_masked = y_pred * mask
    squared_error = K.square(y_true_masked - y_pred_masked)
    return K.sum(squared_error) / (K.sum(mask) + K.epsilon())

@tf.keras.utils.register_keras_serializable()
def RMSE(y_true, y_pred):
    mask = create_non_negative_mask(y_true)
    y_true_masked = y_true * mask
    y_pred_masked = y_pred * mask
    squared_error = K.square(y_true_masked - y_pred_masked)
    mse = K.sum(squared_error) / (K.sum(mask) + K.epsilon())
    return K.sqrt(mse)

@tf.keras.utils.register_keras_serializable()
def weighted_sigmoid_mse(y_true, y_pred):
    scaling_factor=1
    threshold=0.1
    mask = create_non_negative_mask(y_true)
    y_norm = y_true / 260.0  # max y_train = 260
    weights = K.sigmoid(scaling_factor * (y_norm - threshold))  # Compute the weights using sigmoid
    weights_masked = weights * mask  
    y_true_masked = y_true * mask 
    y_pred_masked = y_pred * mask  
    squared_error = K.square(y_true_masked - y_pred_masked)  
    weighted_error = weights_masked * squared_error  # Apply weights
    return K.sum(weighted_error) / (K.sum(weights_masked) + K.epsilon())  # Normalize

# %% [markdown]
# ## Metric classification

# %%
@tf.keras.utils.register_keras_serializable()
def create_missing_data_mask(y):
    return K.cast(K.less(y, 0), K.floatx()) # Mask where y == -1 (missing data)

# Mask for classifying values greater than or equal to 0.5
@tf.keras.utils.register_keras_serializable()
def create_class_mask(y):
    return K.cast(K.greater_equal(y, 0.5), K.floatx())

@tf.keras.utils.register_keras_serializable()
def FAR(y_true, y_pred):
    missing_mask = create_missing_data_mask(y_true)  # 1 where missing
    valid_mask = 1.0 - missing_mask  # 1 where valid

    y_true_class = create_class_mask(y_true)
    y_pred_class = create_class_mask(y_pred)

    # Only consider positions where valid_mask == 1
    FP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 0), K.floatx()) * valid_mask)
    TP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 1), K.floatx()) * valid_mask)

    far = FP / (TP + FP + K.epsilon())
    return far

@tf.keras.utils.register_keras_serializable()
def POD(y_true, y_pred):
    # Mask for missing data and valid values
    missing_mask = create_missing_data_mask(y_true)
    valid_mask = 1.0 - missing_mask

    # Convert to binary class masks
    y_true_class = create_class_mask(y_true)
    y_pred_class = create_class_mask(y_pred)


    TP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 1), K.floatx()) * valid_mask)
    FN = K.sum(K.cast((y_pred_class == 0) & (y_true_class == 1), K.floatx()) * valid_mask)

    pod = TP / (TP + FN + K.epsilon())
    return pod

@tf.keras.utils.register_keras_serializable()
def CSI(y_true, y_pred):
    # Create the missing data mask
    missing_mask = create_missing_data_mask(y_true)
    valid_mask = 1.0 - missing_mask

    # Convert to binary class masks
    y_true_class = create_class_mask(y_true)
    y_pred_class = create_class_mask(y_pred)

    # TP, FP, FN (only on valid data)
    TP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 1), K.floatx()) * valid_mask)
    FP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 0), K.floatx()) * valid_mask)
    FN = K.sum(K.cast((y_pred_class == 0) & (y_true_class == 1), K.floatx()) * valid_mask)

    csi = TP / (TP + FP + FN + K.epsilon())
    return csi

# %% [markdown]
# ## Train .fit

# %%
optimizer = Adam(learning_rate=0.001)

# Callbacks
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True, mode='min', verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)

# Compile Model
model.compile(optimizer=optimizer, 
              loss=custom_mse_loss, 
              metrics=[RMSE, CC, R2, POD, FAR, CSI])

# Train Model
history = model.fit(X_train_scaled, y_train,
                    batch_size=32,
                    epochs=80,
                    verbose=1,
                    validation_data=(X_val_scaled, y_val),
                    callbacks=[checkpoint, reduce_lr, early_stopping])
# Out:
# Epoch 1/80
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746071251.966021      66 service.cc:148] XLA service 0x7c3f58002b50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746071251.966820      66 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1746071253.577481      66 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1746071289.205886      66 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - cc: 0.2158 - csi: 0.1656 - far: 0.7649 - loss: 3.5814 - pod: 0.4132 - r2: 0.0421 - rmse: 1.7252
# E0000 00:00:1746071309.104983      67 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746071309.344584      67 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746071310.065193      67 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746071310.329678      67 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 979ms/step - cc: 0.2161 - csi: 0.1657 - far: 0.7646 - loss: 3.5864 - pod: 0.4136 - r2: 0.0423 - rmse: 1.7252
# E0000 00:00:1746071342.681793      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746071342.918216      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746071343.498420      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746071343.758975      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_loss improved from inf to 2.19727, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - cc: 0.2164 - csi: 0.1659 - far: 0.7643 - loss: 3.5912 - pod: 0.4140 - r2: 0.0424 - rmse: 1.7251 - val_cc: 0.0298 - val_csi: 0.0000e+00 - val_far: 0.0000e+00 - val_loss: 2.1973 - val_pod: 0.0000e+00 - val_r2: -0.0095 - val_rmse: 1.4213 - learning_rate: 0.0010
# Epoch 2/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.2489 - csi: 0.2076 - far: 0.7402 - loss: 4.6478 - pod: 0.5356 - r2: 0.0539 - rmse: 1.8573
# Epoch 2: val_loss improved from 2.19727 to 2.18604, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 408ms/step - cc: 0.2494 - csi: 0.2076 - far: 0.7401 - loss: 4.6302 - pod: 0.5354 - r2: 0.0541 - rmse: 1.8537 - val_cc: 0.1567 - val_csi: 0.0000e+00 - val_far: 0.1818 - val_loss: 2.1860 - val_pod: 0.0000e+00 - val_r2: -0.0038 - val_rmse: 1.4176 - learning_rate: 0.0010
# Epoch 3/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.2732 - csi: 0.2116 - far: 0.7407 - loss: 2.9919 - pod: 0.5624 - r2: 0.0601 - rmse: 1.5608
# Epoch 3: val_loss did not improve from 2.18604
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.2732 - csi: 0.2116 - far: 0.7406 - loss: 3.0073 - pod: 0.5620 - r2: 0.0601 - rmse: 1.5628 - val_cc: 0.0194 - val_csi: 0.0197 - val_far: 0.9711 - val_loss: 2.2198 - val_pod: 0.0601 - val_r2: -0.0263 - val_rmse: 1.4309 - learning_rate: 0.0010
# Epoch 4/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.2553 - csi: 0.2136 - far: 0.7389 - loss: 4.7023 - pod: 0.5707 - r2: 0.0441 - rmse: 1.9063
# Epoch 4: val_loss did not improve from 2.18604
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.2555 - csi: 0.2134 - far: 0.7389 - loss: 4.6836 - pod: 0.5699 - r2: 0.0444 - rmse: 1.9023 - val_cc: 0.0217 - val_csi: 6.3013e-04 - val_far: 0.6250 - val_loss: 2.1971 - val_pod: 6.3291e-04 - val_r2: -0.0093 - val_rmse: 1.4212 - learning_rate: 0.0010
# Epoch 5/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.2633 - csi: 0.2091 - far: 0.6724 - loss: 5.0532 - pod: 0.4695 - r2: 0.0571 - rmse: 1.9506
# Epoch 5: val_loss improved from 2.18604 to 2.17732, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 407ms/step - cc: 0.2638 - csi: 0.2093 - far: 0.6732 - loss: 5.0271 - pod: 0.4706 - r2: 0.0574 - rmse: 1.9457 - val_cc: 0.0718 - val_csi: 1.9722e-04 - val_far: 0.9699 - val_loss: 2.1773 - val_pod: 1.9983e-04 - val_r2: 9.8315e-04 - val_rmse: 1.4143 - learning_rate: 0.0010
# Epoch 6/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.2776 - csi: 0.2093 - far: 0.7428 - loss: 3.9758 - pod: 0.5454 - r2: 0.0716 - rmse: 1.7490
# Epoch 6: val_loss did not improve from 2.17732
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.2779 - csi: 0.2093 - far: 0.7428 - loss: 3.9711 - pod: 0.5457 - r2: 0.0716 - rmse: 1.7479 - val_cc: 0.0000e+00 - val_csi: 0.0000e+00 - val_far: 0.0000e+00 - val_loss: 2.1976 - val_pod: 0.0000e+00 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 0.0010
# Epoch 7/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.3284 - csi: 0.2242 - far: 0.7081 - loss: 2.5742 - pod: 0.5268 - r2: 0.1017 - rmse: 1.4056
# Epoch 7: val_loss did not improve from 2.17732
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.3279 - csi: 0.2240 - far: 0.7085 - loss: 2.5973 - pod: 0.5270 - r2: 0.1014 - rmse: 1.4105 - val_cc: 0.0996 - val_csi: 0.0668 - val_far: 0.9107 - val_loss: 2.3328 - val_pod: 0.2146 - val_r2: -0.0911 - val_rmse: 1.4686 - learning_rate: 0.0010
# Epoch 8/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.2943 - csi: 0.2321 - far: 0.7037 - loss: 3.6431 - pod: 0.5376 - r2: 0.0848 - rmse: 1.6591
# Epoch 8: val_loss did not improve from 2.17732
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.2941 - csi: 0.2318 - far: 0.7042 - loss: 3.6452 - pod: 0.5374 - r2: 0.0846 - rmse: 1.6596 - val_cc: 0.1997 - val_csi: 0.1484 - val_far: 0.8364 - val_loss: 2.6117 - val_pod: 0.6234 - val_r2: -0.2437 - val_rmse: 1.5530 - learning_rate: 0.0010
# Epoch 9/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.2962 - csi: 0.2234 - far: 0.7279 - loss: 4.5261 - pod: 0.5933 - r2: 0.0772 - rmse: 1.8603
# Epoch 9: val_loss improved from 2.17732 to 2.17276, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 408ms/step - cc: 0.2961 - csi: 0.2232 - far: 0.7280 - loss: 4.5102 - pod: 0.5928 - r2: 0.0772 - rmse: 1.8572 - val_cc: 0.2428 - val_csi: 0.1233 - val_far: 0.8679 - val_loss: 2.1728 - val_pod: 0.6507 - val_r2: -0.0121 - val_rmse: 1.4174 - learning_rate: 0.0010
# Epoch 10/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.3063 - csi: 0.2249 - far: 0.7173 - loss: 3.3035 - pod: 0.5700 - r2: 0.0731 - rmse: 1.5886
# Epoch 10: val_loss did not improve from 2.17276
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.3063 - csi: 0.2249 - far: 0.7171 - loss: 3.3116 - pod: 0.5695 - r2: 0.0735 - rmse: 1.5907 - val_cc: 0.2545 - val_csi: 0.1567 - val_far: 0.8097 - val_loss: 2.2702 - val_pod: 0.4781 - val_r2: -0.0811 - val_rmse: 1.4557 - learning_rate: 0.0010
# Epoch 11/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.3386 - csi: 0.2275 - far: 0.7167 - loss: 2.7330 - pod: 0.5693 - r2: 0.0989 - rmse: 1.4717
# Epoch 11: val_loss did not improve from 2.17276
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.3379 - csi: 0.2273 - far: 0.7168 - loss: 2.7525 - pod: 0.5686 - r2: 0.0986 - rmse: 1.4760 - val_cc: 0.1147 - val_csi: 0.1125 - val_far: 0.7966 - val_loss: 2.6246 - val_pod: 0.2099 - val_r2: -0.2184 - val_rmse: 1.5371 - learning_rate: 0.0010
# Epoch 12/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.2941 - csi: 0.2174 - far: 0.7280 - loss: 3.3712 - pod: 0.5437 - r2: 0.0791 - rmse: 1.6102
# Epoch 12: val_loss did not improve from 2.17276
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.2944 - csi: 0.2175 - far: 0.7277 - loss: 3.3777 - pod: 0.5437 - r2: 0.0792 - rmse: 1.6117 - val_cc: 0.1792 - val_csi: 0.1590 - val_far: 0.6626 - val_loss: 2.2322 - val_pod: 0.2393 - val_r2: -0.0154 - val_rmse: 1.4272 - learning_rate: 0.0010
# Epoch 13/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.2936 - csi: 0.2398 - far: 0.6449 - loss: 5.3972 - pod: 0.4612 - r2: 0.0677 - rmse: 2.0117
# Epoch 13: val_loss did not improve from 2.17276
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.2941 - csi: 0.2397 - far: 0.6456 - loss: 5.3633 - pod: 0.4622 - r2: 0.0681 - rmse: 2.0049 - val_cc: 0.2713 - val_csi: 0.1829 - val_far: 0.7767 - val_loss: 2.5059 - val_pod: 0.5187 - val_r2: -0.2687 - val_rmse: 1.5476 - learning_rate: 0.0010
# Epoch 14/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.3469 - csi: 0.2448 - far: 0.6990 - loss: 3.4578 - pod: 0.5864 - r2: 0.1193 - rmse: 1.6263
# Epoch 14: val_loss did not improve from 2.17276
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.3465 - csi: 0.2444 - far: 0.6993 - loss: 3.4621 - pod: 0.5860 - r2: 0.1190 - rmse: 1.6271 - val_cc: 0.2057 - val_csi: 0.1890 - val_far: 0.7146 - val_loss: 2.3296 - val_pod: 0.3720 - val_r2: -0.1025 - val_rmse: 1.4704 - learning_rate: 0.0010
# Epoch 15/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.3627 - csi: 0.2524 - far: 0.6797 - loss: 3.3135 - pod: 0.5630 - r2: 0.1174 - rmse: 1.6091
# Epoch 15: val_loss did not improve from 2.17276
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.3625 - csi: 0.2522 - far: 0.6802 - loss: 3.3196 - pod: 0.5633 - r2: 0.1172 - rmse: 1.6098 - val_cc: 0.1752 - val_csi: 0.1127 - val_far: 0.8724 - val_loss: 2.6658 - val_pod: 0.4986 - val_r2: -0.3158 - val_rmse: 1.5874 - learning_rate: 5.0000e-04
# Epoch 16/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.3857 - csi: 0.2613 - far: 0.6744 - loss: 2.9670 - pod: 0.5813 - r2: 0.1426 - rmse: 1.5786
# Epoch 16: val_loss did not improve from 2.17276
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.3852 - csi: 0.2611 - far: 0.6747 - loss: 2.9794 - pod: 0.5809 - r2: 0.1422 - rmse: 1.5792 - val_cc: 0.1866 - val_csi: 0.0610 - val_far: 0.9382 - val_loss: 6.2342 - val_pod: 0.8375 - val_r2: -2.6075 - val_rmse: 2.4879 - learning_rate: 5.0000e-04
# Epoch 17/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.3687 - csi: 0.2421 - far: 0.7058 - loss: 3.7672 - pod: 0.5896 - r2: 0.1288 - rmse: 1.6877
# Epoch 17: val_loss improved from 2.17276 to 2.12461, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 407ms/step - cc: 0.3684 - csi: 0.2422 - far: 0.7055 - loss: 3.7638 - pod: 0.5890 - r2: 0.1287 - rmse: 1.6870 - val_cc: 0.2119 - val_csi: 0.1036 - val_far: 0.8734 - val_loss: 2.1246 - val_pod: 0.3878 - val_r2: 0.0182 - val_rmse: 1.3992 - learning_rate: 5.0000e-04
# Epoch 18/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.3838 - csi: 0.2553 - far: 0.6717 - loss: 4.0239 - pod: 0.5718 - r2: 0.1519 - rmse: 1.7122
# Epoch 18: val_loss did not improve from 2.12461
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.3835 - csi: 0.2551 - far: 0.6719 - loss: 4.0150 - pod: 0.5715 - r2: 0.1516 - rmse: 1.7107 - val_cc: 0.2653 - val_csi: 0.0961 - val_far: 0.9006 - val_loss: 2.9576 - val_pod: 0.7466 - val_r2: -0.4883 - val_rmse: 1.6653 - learning_rate: 5.0000e-04
# Epoch 19/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.3814 - csi: 0.2441 - far: 0.6901 - loss: 4.0543 - pod: 0.5439 - r2: 0.1462 - rmse: 1.7141
# Epoch 19: val_loss did not improve from 2.12461
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.3813 - csi: 0.2442 - far: 0.6901 - loss: 4.0444 - pod: 0.5444 - r2: 0.1461 - rmse: 1.7128 - val_cc: 0.2580 - val_csi: 0.1384 - val_far: 0.8440 - val_loss: 2.7746 - val_pod: 0.5569 - val_r2: -0.3975 - val_rmse: 1.6182 - learning_rate: 5.0000e-04
# Epoch 20/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.3885 - csi: 0.2475 - far: 0.6772 - loss: 2.4801 - pod: 0.5200 - r2: 0.1470 - rmse: 1.4153
# Epoch 20: val_loss did not improve from 2.12461
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.3881 - csi: 0.2476 - far: 0.6773 - loss: 2.5015 - pod: 0.5204 - r2: 0.1467 - rmse: 1.4191 - val_cc: 0.2291 - val_csi: 0.1352 - val_far: 0.8539 - val_loss: 5.9819 - val_pod: 0.6520 - val_r2: -2.4023 - val_rmse: 2.4057 - learning_rate: 5.0000e-04
# Epoch 21/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.3653 - csi: 0.2386 - far: 0.7061 - loss: 3.5668 - pod: 0.5726 - r2: 0.1310 - rmse: 1.6196
# Epoch 21: val_loss did not improve from 2.12461
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.3658 - csi: 0.2390 - far: 0.7056 - loss: 3.5660 - pod: 0.5731 - r2: 0.1313 - rmse: 1.6199 - val_cc: 0.2911 - val_csi: 0.1026 - val_far: 0.8949 - val_loss: 3.8675 - val_pod: 0.8163 - val_r2: -1.0811 - val_rmse: 1.9250 - learning_rate: 5.0000e-04
# Epoch 22/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.3956 - csi: 0.2582 - far: 0.6546 - loss: 3.0572 - pod: 0.5414 - r2: 0.1485 - rmse: 1.5479
# Epoch 22: val_loss did not improve from 2.12461
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.3956 - csi: 0.2582 - far: 0.6547 - loss: 3.0666 - pod: 0.5416 - r2: 0.1486 - rmse: 1.5495 - val_cc: 0.2027 - val_csi: 0.0614 - val_far: 0.9377 - val_loss: 7.2121 - val_pod: 0.8078 - val_r2: -3.0889 - val_rmse: 2.6481 - learning_rate: 5.0000e-04
# Epoch 23/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.3743 - csi: 0.2507 - far: 0.6868 - loss: 3.7642 - pod: 0.5632 - r2: 0.1354 - rmse: 1.7148
# Epoch 23: val_loss did not improve from 2.12461
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.3747 - csi: 0.2509 - far: 0.6865 - loss: 3.7590 - pod: 0.5631 - r2: 0.1357 - rmse: 1.7127 - val_cc: 0.3329 - val_csi: 0.1813 - val_far: 0.8038 - val_loss: 2.2897 - val_pod: 0.7054 - val_r2: -0.1100 - val_rmse: 1.4602 - learning_rate: 2.5000e-04
# Epoch 24/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.3968 - csi: 0.2557 - far: 0.6856 - loss: 3.4218 - pod: 0.5845 - r2: 0.1516 - rmse: 1.5748
# Epoch 24: val_loss did not improve from 2.12461
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.3970 - csi: 0.2558 - far: 0.6854 - loss: 3.4220 - pod: 0.5844 - r2: 0.1519 - rmse: 1.5755 - val_cc: 0.3045 - val_csi: 0.1650 - val_far: 0.8237 - val_loss: 2.6097 - val_pod: 0.7217 - val_r2: -0.2968 - val_rmse: 1.5619 - learning_rate: 2.5000e-04
# Epoch 25/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.4366 - csi: 0.2569 - far: 0.6756 - loss: 2.5954 - pod: 0.5599 - r2: 0.1909 - rmse: 1.4067
# Epoch 25: val_loss did not improve from 2.12461
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.4363 - csi: 0.2570 - far: 0.6756 - loss: 2.6112 - pod: 0.5603 - r2: 0.1906 - rmse: 1.4102 - val_cc: 0.2912 - val_csi: 0.1426 - val_far: 0.8486 - val_loss: 2.5662 - val_pod: 0.7112 - val_r2: -0.3048 - val_rmse: 1.5618 - learning_rate: 2.5000e-04
# Epoch 26/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.4212 - csi: 0.2739 - far: 0.6555 - loss: 3.7289 - pod: 0.5810 - r2: 0.1765 - rmse: 1.6848
# Epoch 26: val_loss did not improve from 2.12461
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.4212 - csi: 0.2736 - far: 0.6559 - loss: 3.7219 - pod: 0.5810 - r2: 0.1764 - rmse: 1.6828 - val_cc: 0.2880 - val_csi: 0.1564 - val_far: 0.8324 - val_loss: 2.6547 - val_pod: 0.7061 - val_r2: -0.2411 - val_rmse: 1.5332 - learning_rate: 2.5000e-04
# Epoch 27/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.4190 - csi: 0.2764 - far: 0.6202 - loss: 3.3364 - pod: 0.5286 - r2: 0.1701 - rmse: 1.6002
# Epoch 27: val_loss improved from 2.12461 to 2.04374, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 408ms/step - cc: 0.4189 - csi: 0.2762 - far: 0.6207 - loss: 3.3380 - pod: 0.5293 - r2: 0.1700 - rmse: 1.6003 - val_cc: 0.3493 - val_csi: 0.2164 - val_far: 0.7494 - val_loss: 2.0437 - val_pod: 0.6161 - val_r2: 0.0416 - val_rmse: 1.3720 - learning_rate: 2.5000e-04
# Epoch 28/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.4495 - csi: 0.2754 - far: 0.6467 - loss: 2.6252 - pod: 0.5581 - r2: 0.1954 - rmse: 1.4203
# Epoch 28: val_loss did not improve from 2.04374
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.4491 - csi: 0.2752 - far: 0.6471 - loss: 2.6398 - pod: 0.5586 - r2: 0.1949 - rmse: 1.4233 - val_cc: 0.2990 - val_csi: 0.2037 - val_far: 0.7481 - val_loss: 2.4027 - val_pod: 0.5247 - val_r2: -0.1485 - val_rmse: 1.4890 - learning_rate: 2.5000e-04
# Epoch 29/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.4248 - csi: 0.2746 - far: 0.6410 - loss: 4.2818 - pod: 0.5456 - r2: 0.1754 - rmse: 1.7591
# Epoch 29: val_loss did not improve from 2.04374
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.4248 - csi: 0.2745 - far: 0.6411 - loss: 4.2644 - pod: 0.5454 - r2: 0.1756 - rmse: 1.7561 - val_cc: 0.3064 - val_csi: 0.2451 - val_far: 0.6116 - val_loss: 2.1023 - val_pod: 0.4097 - val_r2: 0.0503 - val_rmse: 1.3805 - learning_rate: 2.5000e-04
# Epoch 30/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.4874 - csi: 0.2703 - far: 0.6536 - loss: 2.5960 - pod: 0.5597 - r2: 0.2384 - rmse: 1.4142
# Epoch 30: val_loss did not improve from 2.04374
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.4866 - csi: 0.2704 - far: 0.6536 - loss: 2.6103 - pod: 0.5597 - r2: 0.2376 - rmse: 1.4174 - val_cc: 0.2752 - val_csi: 0.2189 - val_far: 0.7097 - val_loss: 2.4136 - val_pod: 0.4747 - val_r2: -0.0947 - val_rmse: 1.4637 - learning_rate: 2.5000e-04
# Epoch 31/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.4031 - csi: 0.2622 - far: 0.6586 - loss: 2.8787 - pod: 0.5518 - r2: 0.1449 - rmse: 1.4798
# Epoch 31: val_loss did not improve from 2.04374
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.4036 - csi: 0.2624 - far: 0.6587 - loss: 2.8874 - pod: 0.5523 - r2: 0.1454 - rmse: 1.4817 - val_cc: 0.3244 - val_csi: 0.1998 - val_far: 0.7746 - val_loss: 2.2430 - val_pod: 0.6482 - val_r2: -0.0713 - val_rmse: 1.4387 - learning_rate: 2.5000e-04
# Epoch 32/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.4455 - csi: 0.2876 - far: 0.6180 - loss: 2.6307 - pod: 0.5428 - r2: 0.2092 - rmse: 1.4714
# Epoch 32: val_loss did not improve from 2.04374
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.4457 - csi: 0.2875 - far: 0.6184 - loss: 2.6428 - pod: 0.5430 - r2: 0.2092 - rmse: 1.4737 - val_cc: 0.3042 - val_csi: 0.1489 - val_far: 0.8436 - val_loss: 2.5099 - val_pod: 0.7578 - val_r2: -0.1688 - val_rmse: 1.5017 - learning_rate: 2.5000e-04
# Epoch 33/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.4534 - csi: 0.2643 - far: 0.6719 - loss: 3.6855 - pod: 0.5798 - r2: 0.1960 - rmse: 1.6692
# Epoch 33: val_loss did not improve from 2.04374
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.4530 - csi: 0.2643 - far: 0.6719 - loss: 3.6766 - pod: 0.5798 - r2: 0.1958 - rmse: 1.6672 - val_cc: 0.3165 - val_csi: 0.1970 - val_far: 0.7758 - val_loss: 2.1013 - val_pod: 0.6221 - val_r2: 0.0390 - val_rmse: 1.3834 - learning_rate: 1.2500e-04
# Epoch 34/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.4549 - csi: 0.2602 - far: 0.6540 - loss: 4.2192 - pod: 0.5173 - r2: 0.1967 - rmse: 1.6632
# Epoch 34: val_loss improved from 2.04374 to 2.04135, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 407ms/step - cc: 0.4550 - csi: 0.2605 - far: 0.6536 - loss: 4.1997 - pod: 0.5178 - r2: 0.1968 - rmse: 1.6608 - val_cc: 0.3452 - val_csi: 0.1971 - val_far: 0.7761 - val_loss: 2.0414 - val_pod: 0.6241 - val_r2: 0.0609 - val_rmse: 1.3637 - learning_rate: 1.2500e-04
# Epoch 35/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.4697 - csi: 0.2687 - far: 0.6599 - loss: 3.4522 - pod: 0.5643 - r2: 0.2294 - rmse: 1.6039
# Epoch 35: val_loss did not improve from 2.04135
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.4701 - csi: 0.2688 - far: 0.6597 - loss: 3.4467 - pod: 0.5645 - r2: 0.2296 - rmse: 1.6027 - val_cc: 0.3488 - val_csi: 0.1949 - val_far: 0.7816 - val_loss: 2.0446 - val_pod: 0.6424 - val_r2: 0.0395 - val_rmse: 1.3747 - learning_rate: 1.2500e-04
# Epoch 36/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.4108 - csi: 0.2751 - far: 0.6463 - loss: 3.6271 - pod: 0.5504 - r2: 0.1899 - rmse: 1.6931
# Epoch 36: val_loss did not improve from 2.04135
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.4115 - csi: 0.2752 - far: 0.6462 - loss: 3.6170 - pod: 0.5505 - r2: 0.1903 - rmse: 1.6905 - val_cc: 0.3022 - val_csi: 0.1127 - val_far: 0.8822 - val_loss: 2.3300 - val_pod: 0.7248 - val_r2: -0.0617 - val_rmse: 1.4439 - learning_rate: 1.2500e-04
# Epoch 37/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.4562 - csi: 0.2640 - far: 0.6589 - loss: 2.7427 - pod: 0.5376 - r2: 0.2086 - rmse: 1.4462
# Epoch 37: val_loss did not improve from 2.04135
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.4566 - csi: 0.2641 - far: 0.6587 - loss: 2.7507 - pod: 0.5379 - r2: 0.2091 - rmse: 1.4477 - val_cc: 0.3104 - val_csi: 0.1157 - val_far: 0.8784 - val_loss: 2.2232 - val_pod: 0.7107 - val_r2: -0.0463 - val_rmse: 1.4322 - learning_rate: 1.2500e-04
# Epoch 38/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.4798 - csi: 0.2851 - far: 0.6342 - loss: 3.4650 - pod: 0.5683 - r2: 0.2107 - rmse: 1.6132
# Epoch 38: val_loss improved from 2.04135 to 1.89768, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 408ms/step - cc: 0.4797 - csi: 0.2850 - far: 0.6343 - loss: 3.4582 - pod: 0.5679 - r2: 0.2105 - rmse: 1.6116 - val_cc: 0.3696 - val_csi: 0.2213 - val_far: 0.7333 - val_loss: 1.8977 - val_pod: 0.5662 - val_r2: 0.1258 - val_rmse: 1.3199 - learning_rate: 1.2500e-04
# Epoch 39/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.4490 - csi: 0.2504 - far: 0.6895 - loss: 3.4492 - pod: 0.5710 - r2: 0.1991 - rmse: 1.5230
# Epoch 39: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.4492 - csi: 0.2507 - far: 0.6891 - loss: 3.4428 - pod: 0.5711 - r2: 0.1990 - rmse: 1.5225 - val_cc: 0.3640 - val_csi: 0.2589 - val_far: 0.6051 - val_loss: 1.9297 - val_pod: 0.4344 - val_r2: 0.1131 - val_rmse: 1.3312 - learning_rate: 1.2500e-04
# Epoch 40/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.5048 - csi: 0.3029 - far: 0.5918 - loss: 1.9742 - pod: 0.5428 - r2: 0.2537 - rmse: 1.3064
# Epoch 40: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5042 - csi: 0.3025 - far: 0.5925 - loss: 1.9976 - pod: 0.5428 - r2: 0.2530 - rmse: 1.3107 - val_cc: 0.3041 - val_csi: 0.2185 - val_far: 0.7252 - val_loss: 2.1389 - val_pod: 0.5252 - val_r2: 0.0106 - val_rmse: 1.3988 - learning_rate: 1.2500e-04
# Epoch 41/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - cc: 0.4328 - csi: 0.2755 - far: 0.6532 - loss: 3.4724 - pod: 0.5757 - r2: 0.1838 - rmse: 1.6440
# Epoch 41: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 367ms/step - cc: 0.4331 - csi: 0.2755 - far: 0.6532 - loss: 3.4663 - pod: 0.5759 - r2: 0.1839 - rmse: 1.6417 - val_cc: 0.3666 - val_csi: 0.2471 - val_far: 0.6785 - val_loss: 2.0281 - val_pod: 0.5183 - val_r2: 0.0577 - val_rmse: 1.3581 - learning_rate: 1.2500e-04
# Epoch 42/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.4916 - csi: 0.2859 - far: 0.6102 - loss: 3.1982 - pod: 0.5165 - r2: 0.2369 - rmse: 1.5430
# Epoch 42: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.4913 - csi: 0.2858 - far: 0.6106 - loss: 3.1967 - pod: 0.5169 - r2: 0.2367 - rmse: 1.5431 - val_cc: 0.3787 - val_csi: 0.2587 - val_far: 0.6389 - val_loss: 1.9299 - val_pod: 0.4786 - val_r2: 0.1042 - val_rmse: 1.3287 - learning_rate: 1.2500e-04
# Epoch 43/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.5035 - csi: 0.2833 - far: 0.6379 - loss: 2.3762 - pod: 0.5693 - r2: 0.2519 - rmse: 1.3699
# Epoch 43: val_loss did not improve from 1.89768
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5032 - csi: 0.2833 - far: 0.6378 - loss: 2.3890 - pod: 0.5692 - r2: 0.2516 - rmse: 1.3722 - val_cc: 0.3232 - val_csi: 0.1287 - val_far: 0.8651 - val_loss: 2.1971 - val_pod: 0.7362 - val_r2: -0.0527 - val_rmse: 1.4297 - learning_rate: 1.2500e-04
# Epoch 44/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.4635 - csi: 0.2688 - far: 0.6635 - loss: 3.4766 - pod: 0.5681 - r2: 0.2152 - rmse: 1.6048
# Epoch 44: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.4638 - csi: 0.2689 - far: 0.6633 - loss: 3.4673 - pod: 0.5680 - r2: 0.2156 - rmse: 1.6027 - val_cc: 0.3689 - val_csi: 0.2272 - val_far: 0.7381 - val_loss: 2.1206 - val_pod: 0.6367 - val_r2: 0.0373 - val_rmse: 1.3759 - learning_rate: 6.2500e-05
# Epoch 45/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.5132 - csi: 0.3008 - far: 0.6197 - loss: 3.4786 - pod: 0.5907 - r2: 0.2661 - rmse: 1.6161
# Epoch 45: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5125 - csi: 0.3004 - far: 0.6202 - loss: 3.4680 - pod: 0.5903 - r2: 0.2653 - rmse: 1.6139 - val_cc: 0.3746 - val_csi: 0.2394 - val_far: 0.7157 - val_loss: 2.0982 - val_pod: 0.6081 - val_r2: 0.0498 - val_rmse: 1.3681 - learning_rate: 6.2500e-05
# Epoch 46/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.4801 - csi: 0.2682 - far: 0.6360 - loss: 3.7853 - pod: 0.5040 - r2: 0.2233 - rmse: 1.7053
# Epoch 46: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.4802 - csi: 0.2684 - far: 0.6359 - loss: 3.7693 - pod: 0.5048 - r2: 0.2235 - rmse: 1.7018 - val_cc: 0.3232 - val_csi: 0.2516 - val_far: 0.5935 - val_loss: 2.1169 - val_pod: 0.4040 - val_r2: 0.0430 - val_rmse: 1.3821 - learning_rate: 6.2500e-05
# Epoch 47/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.5109 - csi: 0.2887 - far: 0.6352 - loss: 2.9587 - pod: 0.5797 - r2: 0.2647 - rmse: 1.5388
# Epoch 47: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5108 - csi: 0.2885 - far: 0.6354 - loss: 2.9588 - pod: 0.5795 - r2: 0.2644 - rmse: 1.5384 - val_cc: 0.3767 - val_csi: 0.2139 - val_far: 0.7530 - val_loss: 2.0022 - val_pod: 0.6178 - val_r2: 0.0822 - val_rmse: 1.3472 - learning_rate: 6.2500e-05
# Epoch 48/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.4813 - csi: 0.2966 - far: 0.6162 - loss: 2.5485 - pod: 0.5654 - r2: 0.2149 - rmse: 1.4254
# Epoch 48: val_loss did not improve from 1.89768
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.4815 - csi: 0.2963 - far: 0.6166 - loss: 2.5554 - pod: 0.5655 - r2: 0.2155 - rmse: 1.4270 - val_cc: 0.3781 - val_csi: 0.2161 - val_far: 0.7532 - val_loss: 2.0030 - val_pod: 0.6377 - val_r2: 0.0849 - val_rmse: 1.3463 - learning_rate: 6.2500e-05
# Epoch 49/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.5151 - csi: 0.2756 - far: 0.6509 - loss: 3.5363 - pod: 0.5692 - r2: 0.2625 - rmse: 1.6673
# Epoch 49: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5148 - csi: 0.2756 - far: 0.6510 - loss: 3.5234 - pod: 0.5693 - r2: 0.2621 - rmse: 1.6640 - val_cc: 0.3842 - val_csi: 0.2674 - val_far: 0.6488 - val_loss: 2.0308 - val_pod: 0.5360 - val_r2: 0.0820 - val_rmse: 1.3491 - learning_rate: 3.1250e-05
# Epoch 50/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.5016 - csi: 0.2906 - far: 0.6174 - loss: 2.4454 - pod: 0.5532 - r2: 0.2619 - rmse: 1.4391
# Epoch 50: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.5017 - csi: 0.2906 - far: 0.6175 - loss: 2.4533 - pod: 0.5532 - r2: 0.2618 - rmse: 1.4404 - val_cc: 0.3901 - val_csi: 0.2607 - val_far: 0.6692 - val_loss: 1.9889 - val_pod: 0.5597 - val_r2: 0.0958 - val_rmse: 1.3388 - learning_rate: 3.1250e-05
# Epoch 51/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.5248 - csi: 0.2899 - far: 0.6248 - loss: 2.9226 - pod: 0.5638 - r2: 0.2707 - rmse: 1.5343
# Epoch 51: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5243 - csi: 0.2897 - far: 0.6250 - loss: 2.9212 - pod: 0.5637 - r2: 0.2702 - rmse: 1.5337 - val_cc: 0.3881 - val_csi: 0.2499 - val_far: 0.6947 - val_loss: 2.0836 - val_pod: 0.5857 - val_r2: 0.0580 - val_rmse: 1.3612 - learning_rate: 3.1250e-05
# Epoch 52/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.4895 - csi: 0.2833 - far: 0.6305 - loss: 3.3739 - pod: 0.5522 - r2: 0.2418 - rmse: 1.6227
# Epoch 52: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.4896 - csi: 0.2833 - far: 0.6306 - loss: 3.3634 - pod: 0.5523 - r2: 0.2420 - rmse: 1.6204 - val_cc: 0.3843 - val_csi: 0.2484 - val_far: 0.6970 - val_loss: 2.0895 - val_pod: 0.5845 - val_r2: 0.0574 - val_rmse: 1.3634 - learning_rate: 3.1250e-05
# Epoch 53/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.5072 - csi: 0.2881 - far: 0.6302 - loss: 2.6993 - pod: 0.5675 - r2: 0.2677 - rmse: 1.4906
# Epoch 53: val_loss did not improve from 1.89768
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.5071 - csi: 0.2879 - far: 0.6304 - loss: 2.7010 - pod: 0.5674 - r2: 0.2677 - rmse: 1.4906 - val_cc: 0.3962 - val_csi: 0.2457 - val_far: 0.7004 - val_loss: 2.0013 - val_pod: 0.5825 - val_r2: 0.0900 - val_rmse: 1.3409 - learning_rate: 3.1250e-05
# Epoch 54/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.5344 - csi: 0.2844 - far: 0.6301 - loss: 3.3319 - pod: 0.5556 - r2: 0.2908 - rmse: 1.5849
# Epoch 54: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.5340 - csi: 0.2843 - far: 0.6302 - loss: 3.3202 - pod: 0.5556 - r2: 0.2904 - rmse: 1.5828 - val_cc: 0.3903 - val_csi: 0.2459 - val_far: 0.7032 - val_loss: 2.0772 - val_pod: 0.5943 - val_r2: 0.0618 - val_rmse: 1.3596 - learning_rate: 1.5625e-05
# Epoch 55/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.4893 - csi: 0.2792 - far: 0.6372 - loss: 2.2384 - pod: 0.5457 - r2: 0.2374 - rmse: 1.3726
# Epoch 55: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.4895 - csi: 0.2792 - far: 0.6372 - loss: 2.2491 - pod: 0.5460 - r2: 0.2378 - rmse: 1.3749 - val_cc: 0.3893 - val_csi: 0.2562 - val_far: 0.6803 - val_loss: 2.0752 - val_pod: 0.5687 - val_r2: 0.0644 - val_rmse: 1.3586 - learning_rate: 1.5625e-05
# Epoch 56/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.5072 - csi: 0.2759 - far: 0.6468 - loss: 2.0860 - pod: 0.5621 - r2: 0.2582 - rmse: 1.2985
# Epoch 56: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5071 - csi: 0.2759 - far: 0.6467 - loss: 2.0996 - pod: 0.5619 - r2: 0.2582 - rmse: 1.3019 - val_cc: 0.3883 - val_csi: 0.2428 - val_far: 0.7053 - val_loss: 2.1060 - val_pod: 0.5836 - val_r2: 0.0510 - val_rmse: 1.3658 - learning_rate: 1.5625e-05
# Epoch 57/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.5164 - csi: 0.2834 - far: 0.6321 - loss: 3.6695 - pod: 0.5568 - r2: 0.2582 - rmse: 1.6059
# Epoch 57: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5163 - csi: 0.2833 - far: 0.6322 - loss: 3.6511 - pod: 0.5568 - r2: 0.2581 - rmse: 1.6029 - val_cc: 0.3881 - val_csi: 0.2562 - val_far: 0.6823 - val_loss: 2.1296 - val_pod: 0.5750 - val_r2: 0.0432 - val_rmse: 1.3709 - learning_rate: 1.5625e-05
# Epoch 58/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.5002 - csi: 0.2798 - far: 0.6403 - loss: 2.6028 - pod: 0.5579 - r2: 0.2214 - rmse: 1.4483
# Epoch 58: val_loss did not improve from 1.89768
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5002 - csi: 0.2798 - far: 0.6402 - loss: 2.6069 - pod: 0.5579 - r2: 0.2216 - rmse: 1.4490 - val_cc: 0.3852 - val_csi: 0.2697 - val_far: 0.6494 - val_loss: 2.1072 - val_pod: 0.5460 - val_r2: 0.0538 - val_rmse: 1.3662 - learning_rate: 1.5625e-05
# Epoch 59/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.5131 - csi: 0.2893 - far: 0.6298 - loss: 2.9343 - pod: 0.5654 - r2: 0.2328 - rmse: 1.5210
# Epoch 59: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5129 - csi: 0.2892 - far: 0.6299 - loss: 2.9307 - pod: 0.5652 - r2: 0.2332 - rmse: 1.5197 - val_cc: 0.3882 - val_csi: 0.2650 - val_far: 0.6613 - val_loss: 2.1359 - val_pod: 0.5551 - val_r2: 0.0411 - val_rmse: 1.3720 - learning_rate: 7.8125e-06
# Epoch 60/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.5326 - csi: 0.2828 - far: 0.6387 - loss: 3.3615 - pod: 0.5698 - r2: 0.2922 - rmse: 1.6234
# Epoch 60: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5322 - csi: 0.2829 - far: 0.6386 - loss: 3.3507 - pod: 0.5696 - r2: 0.2917 - rmse: 1.6206 - val_cc: 0.3912 - val_csi: 0.2451 - val_far: 0.7019 - val_loss: 2.1560 - val_pod: 0.5844 - val_r2: 0.0284 - val_rmse: 1.3777 - learning_rate: 7.8125e-06
# Epoch 61/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.5142 - csi: 0.2887 - far: 0.6283 - loss: 3.0206 - pod: 0.5716 - r2: 0.2544 - rmse: 1.4677
# Epoch 61: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5141 - csi: 0.2886 - far: 0.6284 - loss: 3.0160 - pod: 0.5715 - r2: 0.2544 - rmse: 1.4673 - val_cc: 0.3929 - val_csi: 0.2517 - val_far: 0.6893 - val_loss: 2.1340 - val_pod: 0.5749 - val_r2: 0.0387 - val_rmse: 1.3716 - learning_rate: 7.8125e-06
# Epoch 62/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.5533 - csi: 0.2935 - far: 0.6201 - loss: 2.2652 - pod: 0.5664 - r2: 0.3178 - rmse: 1.3291
# Epoch 62: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.5528 - csi: 0.2934 - far: 0.6204 - loss: 2.2753 - pod: 0.5663 - r2: 0.3172 - rmse: 1.3317 - val_cc: 0.3896 - val_csi: 0.2340 - val_far: 0.7194 - val_loss: 2.1355 - val_pod: 0.5883 - val_r2: 0.0350 - val_rmse: 1.3744 - learning_rate: 7.8125e-06
# Epoch 63/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.5451 - csi: 0.2988 - far: 0.6114 - loss: 2.1273 - pod: 0.5676 - r2: 0.3006 - rmse: 1.3122
# Epoch 63: val_loss did not improve from 1.89768
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5443 - csi: 0.2985 - far: 0.6118 - loss: 2.1395 - pod: 0.5674 - r2: 0.2999 - rmse: 1.3154 - val_cc: 0.3947 - val_csi: 0.2528 - val_far: 0.6874 - val_loss: 2.0932 - val_pod: 0.5743 - val_r2: 0.0546 - val_rmse: 1.3629 - learning_rate: 7.8125e-06
# Epoch 64/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.4839 - csi: 0.2800 - far: 0.6420 - loss: 2.5177 - pod: 0.5644 - r2: 0.2480 - rmse: 1.4131
# Epoch 64: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.4844 - csi: 0.2801 - far: 0.6418 - loss: 2.5223 - pod: 0.5644 - r2: 0.2484 - rmse: 1.4141 - val_cc: 0.3935 - val_csi: 0.2570 - val_far: 0.6789 - val_loss: 2.1133 - val_pod: 0.5682 - val_r2: 0.0476 - val_rmse: 1.3670 - learning_rate: 3.9063e-06
# Epoch 65/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.5088 - csi: 0.2836 - far: 0.6358 - loss: 3.9920 - pod: 0.5617 - r2: 0.2676 - rmse: 1.7061
# Epoch 65: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.5090 - csi: 0.2836 - far: 0.6358 - loss: 3.9667 - pod: 0.5617 - r2: 0.2675 - rmse: 1.7011 - val_cc: 0.3924 - val_csi: 0.2541 - val_far: 0.6852 - val_loss: 2.1377 - val_pod: 0.5732 - val_r2: 0.0378 - val_rmse: 1.3724 - learning_rate: 3.9063e-06
# Epoch 66/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.5179 - csi: 0.2848 - far: 0.6313 - loss: 2.5484 - pod: 0.5539 - r2: 0.2773 - rmse: 1.4419
# Epoch 66: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5179 - csi: 0.2848 - far: 0.6313 - loss: 2.5519 - pod: 0.5539 - r2: 0.2771 - rmse: 1.4424 - val_cc: 0.3913 - val_csi: 0.2532 - val_far: 0.6867 - val_loss: 2.1562 - val_pod: 0.5735 - val_r2: 0.0304 - val_rmse: 1.3764 - learning_rate: 3.9063e-06
# Epoch 67/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.4957 - csi: 0.2736 - far: 0.6479 - loss: 2.4734 - pod: 0.5513 - r2: 0.2463 - rmse: 1.3720
# Epoch 67: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.4957 - csi: 0.2737 - far: 0.6477 - loss: 2.4800 - pod: 0.5512 - r2: 0.2462 - rmse: 1.3739 - val_cc: 0.3916 - val_csi: 0.2546 - val_far: 0.6830 - val_loss: 2.1617 - val_pod: 0.5691 - val_r2: 0.0282 - val_rmse: 1.3773 - learning_rate: 3.9063e-06
# Epoch 68/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.5125 - csi: 0.2961 - far: 0.6183 - loss: 2.4249 - pod: 0.5685 - r2: 0.2674 - rmse: 1.4204
# Epoch 68: val_loss did not improve from 1.89768
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.5123 - csi: 0.2958 - far: 0.6187 - loss: 2.4313 - pod: 0.5683 - r2: 0.2672 - rmse: 1.4216 - val_cc: 0.3913 - val_csi: 0.2529 - val_far: 0.6871 - val_loss: 2.1708 - val_pod: 0.5737 - val_r2: 0.0245 - val_rmse: 1.3794 - learning_rate: 3.9063e-06
# Epoch 69/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.5322 - csi: 0.2890 - far: 0.6265 - loss: 2.4758 - pod: 0.5581 - r2: 0.2981 - rmse: 1.3939
# Epoch 69: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5318 - csi: 0.2888 - far: 0.6267 - loss: 2.4815 - pod: 0.5581 - r2: 0.2976 - rmse: 1.3953 - val_cc: 0.3914 - val_csi: 0.2534 - val_far: 0.6856 - val_loss: 2.1744 - val_pod: 0.5715 - val_r2: 0.0230 - val_rmse: 1.3801 - learning_rate: 1.9531e-06
# Epoch 70/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.4857 - csi: 0.2708 - far: 0.6512 - loss: 2.4385 - pod: 0.5451 - r2: 0.2416 - rmse: 1.3746
# Epoch 70: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.4863 - csi: 0.2710 - far: 0.6509 - loss: 2.4442 - pod: 0.5452 - r2: 0.2418 - rmse: 1.3765 - val_cc: 0.3915 - val_csi: 0.2550 - val_far: 0.6820 - val_loss: 2.1769 - val_pod: 0.5680 - val_r2: 0.0221 - val_rmse: 1.3805 - learning_rate: 1.9531e-06
# Epoch 71/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.4927 - csi: 0.2733 - far: 0.6502 - loss: 2.4176 - pod: 0.5585 - r2: 0.2446 - rmse: 1.3795
# Epoch 71: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.4929 - csi: 0.2735 - far: 0.6499 - loss: 2.4240 - pod: 0.5585 - r2: 0.2449 - rmse: 1.3814 - val_cc: 0.3910 - val_csi: 0.2558 - val_far: 0.6805 - val_loss: 2.1796 - val_pod: 0.5673 - val_r2: 0.0213 - val_rmse: 1.3810 - learning_rate: 1.9531e-06
# Epoch 72/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.4713 - csi: 0.2750 - far: 0.6444 - loss: 2.6877 - pod: 0.5487 - r2: 0.2404 - rmse: 1.4602
# Epoch 72: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.4721 - csi: 0.2751 - far: 0.6443 - loss: 2.6893 - pod: 0.5489 - r2: 0.2411 - rmse: 1.4604 - val_cc: 0.3915 - val_csi: 0.2585 - val_far: 0.6747 - val_loss: 2.1786 - val_pod: 0.5629 - val_r2: 0.0217 - val_rmse: 1.3807 - learning_rate: 1.9531e-06
# Epoch 73/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.5099 - csi: 0.2845 - far: 0.6397 - loss: 1.9675 - pod: 0.5779 - r2: 0.2743 - rmse: 1.3153
# Epoch 73: val_loss did not improve from 1.89768
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 1e-06.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.5099 - csi: 0.2845 - far: 0.6396 - loss: 1.9824 - pod: 0.5776 - r2: 0.2742 - rmse: 1.3188 - val_cc: 0.3915 - val_csi: 0.2583 - val_far: 0.6754 - val_loss: 2.1808 - val_pod: 0.5640 - val_r2: 0.0207 - val_rmse: 1.3812 - learning_rate: 1.9531e-06
# Epoch 74/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.5362 - csi: 0.2858 - far: 0.6322 - loss: 3.0156 - pod: 0.5659 - r2: 0.3011 - rmse: 1.5334
# Epoch 74: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5356 - csi: 0.2857 - far: 0.6323 - loss: 3.0103 - pod: 0.5659 - r2: 0.3003 - rmse: 1.5320 - val_cc: 0.3914 - val_csi: 0.2577 - val_far: 0.6767 - val_loss: 2.1875 - val_pod: 0.5647 - val_r2: 0.0179 - val_rmse: 1.3827 - learning_rate: 1.0000e-06
# Epoch 75/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.5290 - csi: 0.2947 - far: 0.6205 - loss: 2.8087 - pod: 0.5714 - r2: 0.2825 - rmse: 1.4774
# Epoch 75: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - cc: 0.5287 - csi: 0.2944 - far: 0.6208 - loss: 2.8068 - pod: 0.5712 - r2: 0.2821 - rmse: 1.4768 - val_cc: 0.3913 - val_csi: 0.2577 - val_far: 0.6764 - val_loss: 2.1945 - val_pod: 0.5643 - val_r2: 0.0152 - val_rmse: 1.3840 - learning_rate: 1.0000e-06
# Epoch 76/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - cc: 0.5126 - csi: 0.2702 - far: 0.6476 - loss: 2.6367 - pod: 0.5359 - r2: 0.2503 - rmse: 1.4850
# Epoch 76: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5125 - csi: 0.2704 - far: 0.6474 - loss: 2.6387 - pod: 0.5364 - r2: 0.2506 - rmse: 1.4850 - val_cc: 0.3913 - val_csi: 0.2570 - val_far: 0.6777 - val_loss: 2.1945 - val_pod: 0.5644 - val_r2: 0.0150 - val_rmse: 1.3841 - learning_rate: 1.0000e-06
# Epoch 77/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.4771 - csi: 0.2664 - far: 0.6537 - loss: 3.2871 - pod: 0.5358 - r2: 0.2390 - rmse: 1.5678
# Epoch 77: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.4775 - csi: 0.2667 - far: 0.6534 - loss: 3.2777 - pod: 0.5362 - r2: 0.2394 - rmse: 1.5656 - val_cc: 0.3915 - val_csi: 0.2573 - val_far: 0.6766 - val_loss: 2.1946 - val_pod: 0.5628 - val_r2: 0.0148 - val_rmse: 1.3841 - learning_rate: 1.0000e-06
# Epoch 78/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - cc: 0.5113 - csi: 0.2906 - far: 0.6253 - loss: 2.6615 - pod: 0.5685 - r2: 0.2711 - rmse: 1.4588
# Epoch 78: val_loss did not improve from 1.89768
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - cc: 0.5111 - csi: 0.2903 - far: 0.6256 - loss: 2.6626 - pod: 0.5682 - r2: 0.2709 - rmse: 1.4590 - val_cc: 0.3915 - val_csi: 0.2574 - val_far: 0.6767 - val_loss: 2.2005 - val_pod: 0.5635 - val_r2: 0.0124 - val_rmse: 1.3853 - learning_rate: 1.0000e-06
# Epoch 78: early stopping
# Restoring model weights from the end of the best epoch: 38.

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Metric valid set

# %%
best_epoch = np.argmin(history.history['val_loss'])

# Print all metrics for that epoch
print(f"Best Epoch: {best_epoch + 1}")
for metric in history.history.keys():
    print(f"{metric}: {history.history[metric][best_epoch]:.4f}")
# Out:
# Best Epoch: 38
# cc: 0.4762
# csi: 0.2766
# far: 0.6401
# loss: 3.1234
# pod: 0.5494
# r2: 0.2009
# rmse: 1.5324
# val_cc: 0.3696
# val_csi: 0.2213
# val_far: 0.7333
# val_loss: 1.8977
# val_pod: 0.5662
# val_r2: 0.1258
# val_rmse: 1.3199
# learning_rate: 0.0001

# %%
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix
from scipy.stats import pearsonr
from tensorflow.keras.models import load_model

# %% [markdown]
# ## Metric test set

# %%
best_model = load_model('/kaggle/working/best_model.keras')
y_test_pred = best_model.predict(X_test_scaled)
y_test_pred_flat = y_test_pred.flatten()
y_test_flat = y_test.flatten()

# Mask to exclude missing data 
mask = y_test_flat >= 0

# Apply mask to filter out missing data
y_test_flat_filtered = y_test_flat[mask]
y_test_pred_flat_filtered = y_test_pred_flat[mask]

mse = mean_squared_error(y_test_flat_filtered, y_test_pred_flat_filtered)
rmse = np.sqrt(mse)
cc, _ = pearsonr(y_test_flat_filtered, y_test_pred_flat_filtered)
r2 = r2_score(y_test_flat_filtered, y_test_pred_flat_filtered)

print("Test set")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"Correlation Coefficient (CC): {cc}")
print(f"R²: {r2}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 242ms/step
# Test set
# MSE: 2.1100051403045654
# RMSE: 1.4525856971740723
# Correlation Coefficient (CC): 0.3913162350654602
# R²: 0.15312829531079108

# %%
from sklearn.metrics import confusion_matrix
true_class_mask = y_test_flat >= 0.5
pred_class_mask = y_test_pred_flat >= 0.5


true_class_mask = np.where(mask, true_class_mask, -1)
pred_class_mask = np.where(mask, pred_class_mask, -1)

valid_mask = (true_class_mask != -1) & (pred_class_mask != -1)
true_class_mask_filtered = true_class_mask[valid_mask]
pred_class_mask_filtered = pred_class_mask[valid_mask]
cm = confusion_matrix(true_class_mask_filtered, pred_class_mask_filtered)

# If cm is a 2x2 matrix, unpack it
if cm.shape == (2, 2):
    tn, fp, fn, tp = cm.ravel()
else:
    # Handle cases where there's no confusion matrix (only one class present)
    tn = cm[0, 0] if cm.shape[0] > 1 else 1
    fp = cm[0, 1] if cm.shape[1] > 1 else 0
    fn = cm[1, 0] if cm.shape[0] > 1 else 0
    tp = cm[1, 1] if cm.shape[1] > 1 else 1

far = fp / (tp + fp) if (tp + fp) > 0 else 0.0

# Probability of Detection (POD) = TP / (TP + FN)
pod = tp / (tp + fn) if (tp + fn) > 0 else 0.0

# Critical Success Index (CSI) = TP / (TP + FP + FN)
csi = tp / (tp + fp + fn) if (tp + fp + fn) > 0 else 0.0

# Print the metrics
print(f"FAR: {far}")
print(f"POD: {pod}")
print(f"CSI: {csi}")
# Out:
# FAR: 0.7008461707431213
# POD: 0.6001044126310546
# CSI: 0.24943014526567672

# %% [markdown]
# ## Plot

# %%
num_examples = 16  # Number of examples to visualize
plt.figure(figsize=(20, 5 * num_examples))
random_indices = np.random.choice(len(y_test), size=num_examples, replace=False)
np.random.seed(42)
for i, index in enumerate(random_indices):
    
    predicted_image = y_test_pred[index]
    radar_image = y_test[index]
    
    mask = radar_image >= 0
    predicted_image[~mask] = -np.inf
    radar_image[~mask] = -np.inf
    vmin = 0
    vmax_true = np.max(radar_image)
    vmax_pred = np.max(predicted_image)
    vmax = np.max([vmax_true, vmax_pred])

    plt.subplot(num_examples, 2, i * 2 + 1)
    im1 = plt.imshow(radar_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Actual Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im1, fraction=0.046, pad=0.04)

    # Plot predicted image
    plt.subplot(num_examples, 2, i * 2 + 2)
    im2 = plt.imshow(predicted_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Predicted Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im2, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()

# %%
num_examples = len(random_indices)
cols = 4
rows = (num_examples + cols - 1) // cols

plt.figure(figsize=(cols * 5, rows * 4))  # Adjust size as needed

for i, index in enumerate(random_indices):
    predicted_image = y_test_pred[index]
    radar_image = y_test[index]
    
    # Mask invalid values
    mask = radar_image >= 0
    predicted_image = predicted_image[mask]
    radar_image = radar_image[mask]
    
    # Scatter plot
    plt.subplot(rows, cols, i + 1)
    plt.scatter(radar_image.flatten(), predicted_image.flatten(), alpha=0.6, s=10)
    plt.title(f'Image #{index}', fontsize=10)
    plt.xlabel('Actual', fontsize=8)
    plt.ylabel('Predicted', fontsize=8)
    plt.axis('equal')
    plt.xticks(fontsize=6)
    plt.yticks(fontsize=6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot val

# %%
y_val_pred = best_model.predict(X_val_scaled)

plt.figure(figsize=(20, 5 * num_examples))
for i, index in enumerate(random_indices):
    
    predicted_image = y_val_pred[index]
    radar_image = y_val[index]
    
    mask = radar_image >= 0
    predicted_image[~mask] = -np.inf
    radar_image[~mask] = -np.inf
    vmin = 0
    vmax_true = np.max(radar_image)
    vmax_pred = np.max(predicted_image)
    vmax = np.max([vmax_true, vmax_pred])

    plt.subplot(num_examples, 2, i * 2 + 1)
    im1 = plt.imshow(radar_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Actual Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im1, fraction=0.046, pad=0.04)

    # Plot predicted image
    plt.subplot(num_examples, 2, i * 2 + 2)
    im2 = plt.imshow(predicted_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Predicted Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im2, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step

# %%
plt.figure(figsize=(20, 5 * num_examples))
for i, index in enumerate(random_indices):
    
    predicted_image = y_val_pred[index]
    radar_image = y_val[index]
    
    mask = radar_image >= 0
    radar_image[~mask] = -np.inf
    vmin = 0
    vmax_true = np.max(radar_image)
    vmax_pred = np.max(predicted_image)
    vmax = np.max([vmax_true, vmax_pred])

    plt.subplot(num_examples, 2, i * 2 + 1)
    im1 = plt.imshow(radar_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Actual Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im1, fraction=0.046, pad=0.04)

    # Plot predicted image
    plt.subplot(num_examples, 2, i * 2 + 2)
    im2 = plt.imshow(predicted_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Predicted Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im2, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
