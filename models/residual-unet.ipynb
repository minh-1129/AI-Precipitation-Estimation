# %%
# !pip install rasterio h5py
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (3.12.1)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio) (2025.1.31)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio) (8.1.8)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.11/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.11/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from rasterio) (3.2.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24->rasterio) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.24->rasterio) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.24->rasterio) (2024.2.0)
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 83.6 MB/s eta 0:00:00
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.4.3

# %%
import os
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
import rasterio
import matplotlib.pyplot as plt
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.losses import Huber
print(tf.__version__)
# Out:
# 2025-05-03 07:49:37.863670: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746258578.081390      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746258578.138983      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2.18.0

# %%
DATA_PATH = "/kaggle/input/data-rain-v2/DATA_RAIN_V2"
# ERA5_ATTRIBUTES = ["CAPE", "CIN", "EWSS", "IE", "ISOR", "KX", "PEV", "R250", "R500", "R850", "SLHF", "SLOR", "SSHF","TCLW","TCW","TCWV", "U250", "U850","V250", "V850"]
# HIMA_BANDS = ["B09B", "B10B", "B11B","B12B", "B14B", "B16B", "IRB", "I2B", "I4B", "WVB"]

ERA5_ATTRIBUTES = ["CAPE", "CIN", "R500", "TCLW","TCW","TCWV", "V250", "V850"]
HIMA_BANDS = ["B09B", "B11B","B12B", "B16B", "I4B", "WVB"]
print(len(ERA5_ATTRIBUTES ))
print(len(HIMA_BANDS))
# Out:
# 8
# 6

# %% [markdown]
# # 1. Load dữ liệu

# %% [markdown]
# ## 1.1. Hàm lấy file

# %%
def convert_time_to_strings(year, month, day, hour):
    year_str = str(year)
    month_str = f"{int(month):02d}"
    day_str = f"{int(day):02d}"
    hour_str = f"{int(hour):02d}"
    return year_str, month_str, day_str, hour_str

def get_era5_file_path(attribute, year, month, day, hour):
    year, month, day, hour = convert_time_to_strings(year, month, day, hour)
    file_name = f"ERA5_{attribute}_{year}_{month}_{day}_{hour}.tif"
    file_path = os.path.join(DATA_PATH, year, month, day, hour, "ERA5", file_name)
    return file_path


def get_hima_file_path(band, year, month, day, hour):
    year, month, day, hour = convert_time_to_strings(year, month, day, hour)
    file_name = f"Hima_{band}_{year}_{month}_{day}_{hour}.tif"
    file_path = os.path.join(DATA_PATH, year, month, day, hour, "Hima", file_name)
    return file_path

def get_radar_file_path(year, month, day, hour):
    year, month, day, hour = convert_time_to_strings(year, month, day, hour)
    file_name = f"Radar_{year}_{month}_{day}_{hour}.tif"
    file_path = os.path.join(DATA_PATH, year, month, day, hour, "Radar", file_name)
    return file_path

# %% [markdown]
# ## 1.2. Load file

# %%
def load_era5_attributes(year, month, day, hour):
    era5_imgs= []
    for attribute in ERA5_ATTRIBUTES:
        file_path = get_era5_file_path(attribute, year, month, day, hour)
        try:
            with rasterio.open(file_path) as src:
                era5_imgs.append(src.read(1)) 
        except Exception as e:
            print(f"Failed to load {attribute} for {year}-{month}-{day} {hour}:00:00 {e}")
    era5_data = np.stack(era5_imgs, axis=-1)  
    return era5_data

def load_hima_bands(year, month, day, hour):
    hima_imgs = []
    for band in HIMA_BANDS:
        file_path = get_hima_file_path(band, year, month, day, hour)
        try:
            with rasterio.open(file_path) as src:
                hima_imgs.append(src.read(1))
        except Exception as e:
                print(f"Failed to load {band} for {year}-{month}-{day} {hour}:00:00 {e}")
    hima_data = np.stack(hima_imgs, axis = -1)
    return hima_data

def load_radar(year, month, day, hour):
    radar_img = None
    file_path = get_radar_file_path(year, month, day, hour)
    try: 
        with rasterio.open(file_path) as src:
            radar_img = src.read(1)
    except Exception as e:
        print(f"Failed to load radar for {year}-{month}-{day} {hour}:00:00 {e}")
    return radar_img

# %%
def load_data_for_timestamp(year, month, day, hour, use_era5 = True):
    try:
        era5_data = None
        if use_era5:
            era5_data = load_era5_attributes(year, month, day, hour)

        hima_data = load_hima_bands(year, month, day, hour)
        radar_data = load_radar(year, month, day, hour)
        if use_era5:
            input_images = np.concatenate((hima_data, era5_data), axis = -1) #shape (90, 250, hima + era5)
        else:
            input_images = hima_data

        return input_images, radar_data

    except Exception as e:
        print(f"Failed to load data for {year}-{month}-{day} {hour}:00:00 {e}")
        return None, None

# %%
def load_dataset(timestamps_df, use_era5 = True):
    X = []
    y = []
    timestamps_tuples = list(timestamps_df[['year', 'month', 'day', 'hour']].itertuples(index=False, name=None))
    for year, month, day, hour in tqdm(timestamps_tuples):
        input_images, radar_image = load_data_for_timestamp(year, month, day, hour, use_era5)
        if input_images is not None and radar_image is not None:
            X.append(input_images)
            y.append(radar_image)
    
    X = np.array(X)
    y = np.array(y)
    y = y[..., np.newaxis] #(90, 250, 1)
    return X, y

# %% [markdown]
# ## 1.3. Chia dữ liệu

# %%
rain_df = pd.read_csv("/kaggle/input/valid-time-rain/final_rain_timestamps.csv", index_col=None)
rain_df.drop(columns = ['Unnamed: 0'], inplace = True)
train_df, tmp_df = train_test_split(
    rain_df, test_size = 0.3, stratify=rain_df["radar_mean_class"], random_state = 42
)

val_df, test_df = train_test_split(
    tmp_df, test_size=0.5, stratify=tmp_df["radar_mean_class"], random_state=42
)

# %% [markdown]
# ## USE_ERA5

# %%
USE_ERA5 = True

# %% [markdown]
# ## 1.4. Scale dữ liệu

# %%
X_train, y_train = load_dataset(train_df, USE_ERA5)
X_val, y_val = load_dataset(val_df, USE_ERA5)
X_test, y_test = load_dataset(test_df, USE_ERA5)
# Out:
# 100%|██████████| 1562/1562 [04:20<00:00,  5.99it/s]
# 100%|██████████| 335/335 [00:52<00:00,  6.33it/s]
# 100%|██████████| 335/335 [00:54<00:00,  6.17it/s]

# %%
# np.savez_compressed('/kaggle/working/raindataset.npz', X_train=X_train, y_train=y_train, X_val = X_val, y_val = y_val, X_test = X_test, y_test = y_test)

# %%
y_train.max()
# Out:
# 260.0

# %%
y_val.max()
# Out:
# 231.0

# %%
y_test.max()
# Out:
# 234.71875

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_X = MinMaxScaler()

X_train_reshaped = X_train.reshape(-1, X_train.shape[-1]) #(num_sample * 250 * 90, hima + era5)
scaler_X.fit(X_train_reshaped)

X_train_scaled = scaler_X.transform(X_train_reshaped).reshape(X_train.shape)
X_val_scaled = scaler_X.transform(X_val.reshape(-1, X_val.shape[-1])).reshape(X_val.shape)
X_test_scaled = scaler_X.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

# %% [markdown]
# # Xử lý -inf

# %%
y_train = np.where(y_train < 0, -1, y_train)
y_val = np.where(y_val < 0, -1, y_val)
y_test = np.where(y_test < 0, -1, y_test)

# %% [markdown]
# # 2. Train

# %% [markdown]
# ## 2.1. Tham số mô hình

# %%
BATCH_SIZE = 32
NUM_FILTERS = [64, 128, 256, 512]
BOTTLENECK_FILTER = 1024
EPOCHS = 100

# %% [markdown]
# ## 2.2. Tạo mô hình

# %%
def residual_conv_block(inputs, num_filters, kernel_size=3):
    x = inputs
    adjusted_inputs = inputs
    if inputs.shape[-1] != num_filters:
        adjusted_inputs = Conv2D(num_filters, kernel_size=1, padding="same")(inputs)
        

    x = Conv2D(num_filters, kernel_size=kernel_size, padding="same")(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)

    x = Conv2D(num_filters, kernel_size=kernel_size, padding="same")(x)
    x = BatchNormalization()(x)

    x = Add()([x, adjusted_inputs])
    x = LeakyReLU(alpha=0.1)(x)
    return x

def encoder_block(inputs, num_filters):
    x = residual_conv_block(inputs, num_filters)
    p = MaxPooling2D(pool_size=(2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, kernel_size=3, strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = residual_conv_block(x, num_filters)
    return x

# %%
def Unet(input_shape):
    inputs = Input(shape=input_shape, name="input")
    x = ZeroPadding2D(padding=((3, 3), (3, 3)))(inputs) #90 x 250 -> 96 x 256
    skip_connections = []
    #(96, 256) -> (48, 128) -> (24, 64) -> (12, 32) -> (6, 16)
    for num_filters in NUM_FILTERS:
        skip, x = encoder_block(x, num_filters)
        skip_connections.append(skip)

    x = residual_conv_block(x, BOTTLENECK_FILTER)

    skip_connections = skip_connections[::-1]
    
    for num_filters, skip in zip(NUM_FILTERS[::-1], skip_connections):
        x = decoder_block(x, skip, num_filters)
    

    x = Cropping2D(cropping=((3, 3), (3, 3)))(x)  # (96x256) → (90x250)
    outputs = Conv2D(1, kernel_size = 1, padding = 'same', activation='relu')(x)
    model = Model(inputs, outputs)
    return model

# %%
channel = None
if USE_ERA5:
    channel = len(HIMA_BANDS) + len(ERA5_ATTRIBUTES)
else:
    channel = len(HIMA_BANDS)
    
input_shape = (90, 250, channel)
model = Unet(input_shape)
model.summary()
# Out:
# I0000 00:00:1746258971.181011      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)        │ (None, 90, 250, 14)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ zero_padding2d            │ (None, 96, 256, 14)    │              0 │ input[0][0]            │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 96, 256, 64)    │          8,128 │ zero_padding2d[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 96, 256, 64)    │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu (LeakyReLU)   │ (None, 96, 256, 64)    │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 96, 256, 64)    │         36,928 │ leaky_re_lu[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 96, 256, 64)    │            256 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 96, 256, 64)    │            960 │ zero_padding2d[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 96, 256, 64)    │              0 │ batch_normalization_1… │
# │                           │                        │                │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU) │ (None, 96, 256, 64)    │              0 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 48, 128, 64)    │              0 │ leaky_re_lu_1[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 48, 128, 128)   │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 48, 128, 128)   │            512 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_2 (LeakyReLU) │ (None, 48, 128, 128)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 48, 128, 128)   │        147,584 │ leaky_re_lu_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 48, 128, 128)   │            512 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 48, 128, 128)   │          8,320 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 48, 128, 128)   │              0 │ batch_normalization_3… │
# │                           │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU) │ (None, 48, 128, 128)   │              0 │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 24, 64, 128)    │              0 │ leaky_re_lu_3[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 24, 64, 256)    │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 24, 64, 256)    │          1,024 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_4 (LeakyReLU) │ (None, 24, 64, 256)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 24, 64, 256)    │        590,080 │ leaky_re_lu_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 24, 64, 256)    │          1,024 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 24, 64, 256)    │         33,024 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 24, 64, 256)    │              0 │ batch_normalization_5… │
# │                           │                        │                │ conv2d_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_5 (LeakyReLU) │ (None, 24, 64, 256)    │              0 │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 12, 32, 256)    │              0 │ leaky_re_lu_5[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 12, 32, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 12, 32, 512)    │          2,048 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_6 (LeakyReLU) │ (None, 12, 32, 512)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 12, 32, 512)    │      2,359,808 │ leaky_re_lu_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 12, 32, 512)    │          2,048 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 12, 32, 512)    │        131,584 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 12, 32, 512)    │              0 │ batch_normalization_7… │
# │                           │                        │                │ conv2d_9[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_7 (LeakyReLU) │ (None, 12, 32, 512)    │              0 │ add_3[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 6, 16, 512)     │              0 │ leaky_re_lu_7[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 6, 16, 1024)    │      4,719,616 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 6, 16, 1024)    │          4,096 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_8 (LeakyReLU) │ (None, 6, 16, 1024)    │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 6, 16, 1024)    │      9,438,208 │ leaky_re_lu_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 6, 16, 1024)    │          4,096 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 6, 16, 1024)    │        525,312 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 6, 16, 1024)    │              0 │ batch_normalization_9… │
# │                           │                        │                │ conv2d_12[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_9 (LeakyReLU) │ (None, 6, 16, 1024)    │              0 │ add_4[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 12, 32, 512)    │      4,719,104 │ leaky_re_lu_9[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 12, 32, 1024)   │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ leaky_re_lu_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 12, 32, 512)    │      4,719,104 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 12, 32, 512)    │          2,048 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_10            │ (None, 12, 32, 512)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 12, 32, 512)    │      2,359,808 │ leaky_re_lu_10[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 12, 32, 512)    │          2,048 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 12, 32, 512)    │        524,800 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 12, 32, 512)    │              0 │ batch_normalization_1… │
# │                           │                        │                │ conv2d_15[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_11            │ (None, 12, 32, 512)    │              0 │ add_5[0][0]            │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 24, 64, 256)    │      1,179,904 │ leaky_re_lu_11[0][0]   │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 24, 64, 512)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ leaky_re_lu_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_19 (Conv2D)        │ (None, 24, 64, 256)    │      1,179,904 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 24, 64, 256)    │          1,024 │ conv2d_19[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_12            │ (None, 24, 64, 256)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_20 (Conv2D)        │ (None, 24, 64, 256)    │        590,080 │ leaky_re_lu_12[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 24, 64, 256)    │          1,024 │ conv2d_20[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 24, 64, 256)    │        131,328 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 24, 64, 256)    │              0 │ batch_normalization_1… │
# │                           │                        │                │ conv2d_18[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_13            │ (None, 24, 64, 256)    │              0 │ add_6[0][0]            │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 48, 128, 128)   │        295,040 │ leaky_re_lu_13[0][0]   │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 48, 128, 256)   │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ leaky_re_lu_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_22 (Conv2D)        │ (None, 48, 128, 128)   │        295,040 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 48, 128, 128)   │            512 │ conv2d_22[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_14            │ (None, 48, 128, 128)   │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_23 (Conv2D)        │ (None, 48, 128, 128)   │        147,584 │ leaky_re_lu_14[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 48, 128, 128)   │            512 │ conv2d_23[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_21 (Conv2D)        │ (None, 48, 128, 128)   │         32,896 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_7 (Add)               │ (None, 48, 128, 128)   │              0 │ batch_normalization_1… │
# │                           │                        │                │ conv2d_21[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_15            │ (None, 48, 128, 128)   │              0 │ add_7[0][0]            │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 96, 256, 64)    │         73,792 │ leaky_re_lu_15[0][0]   │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 96, 256, 128)   │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ leaky_re_lu_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_25 (Conv2D)        │ (None, 96, 256, 64)    │         73,792 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 96, 256, 64)    │            256 │ conv2d_25[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_16            │ (None, 96, 256, 64)    │              0 │ batch_normalization_1… │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_26 (Conv2D)        │ (None, 96, 256, 64)    │         36,928 │ leaky_re_lu_16[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 96, 256, 64)    │            256 │ conv2d_26[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_24 (Conv2D)        │ (None, 96, 256, 64)    │          8,256 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_8 (Add)               │ (None, 96, 256, 64)    │              0 │ batch_normalization_1… │
# │                           │                        │                │ conv2d_24[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ leaky_re_lu_17            │ (None, 96, 256, 64)    │              0 │ add_8[0][0]            │
# │ (LeakyReLU)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ cropping2d (Cropping2D)   │ (None, 90, 250, 64)    │              0 │ leaky_re_lu_17[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_27 (Conv2D)        │ (None, 90, 250, 1)     │             65 │ cropping2d[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 35,939,713 (137.10 MB)
#  Trainable params: 35,927,937 (137.05 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %% [markdown]
# ## Train

# %% [markdown]
# ## Metric Regression

# %%
from tensorflow.keras import backend as K

@tf.keras.utils.register_keras_serializable()
def create_non_negative_mask(y_true):
    return K.cast(K.greater_equal(y_true, 0), K.floatx())  # Mask where y_true >= 0


@tf.keras.utils.register_keras_serializable()    
def CC(y_true, y_pred):
    mask = create_non_negative_mask(y_true)
    y_true_masked = y_true * mask
    y_pred_masked = y_pred * mask
    return K.mean((y_true_masked - K.mean(y_true_masked)) * 
                  (y_pred_masked - K.mean(y_pred_masked)) / 
                  (K.std(y_true_masked) * K.std(y_pred_masked) + K.epsilon()))
    
@tf.keras.utils.register_keras_serializable()
def R2(y_true, y_pred):
    mask = create_non_negative_mask(y_true)
    y_true_masked = y_true * mask
    y_pred_masked = y_pred * mask
    ss_total = K.sum(K.square(y_true_masked - K.mean(y_true_masked)))
    ss_residual = K.sum(K.square(y_true_masked - y_pred_masked))
    return 1 - (ss_residual / (ss_total + K.epsilon()))
    
@tf.keras.utils.register_keras_serializable()
def custom_mse_loss(y_true, y_pred):
    mask = create_non_negative_mask(y_true)
    y_true_masked = y_true * mask
    y_pred_masked = y_pred * mask
    squared_error = K.square(y_true_masked - y_pred_masked)
    return K.sum(squared_error) / (K.sum(mask) + K.epsilon())

@tf.keras.utils.register_keras_serializable()
def RMSE(y_true, y_pred):
    mask = create_non_negative_mask(y_true)
    y_true_masked = y_true * mask
    y_pred_masked = y_pred * mask
    squared_error = K.square(y_true_masked - y_pred_masked)
    mse = K.sum(squared_error) / (K.sum(mask) + K.epsilon())
    return K.sqrt(mse)

@tf.keras.utils.register_keras_serializable()
def weighted_sigmoid_mse(y_true, y_pred):
    scaling_factor=1
    threshold=0.05
    mask = create_non_negative_mask(y_true)
    y_norm = y_true / 260.0  # max y_train = 260
    weights = K.sigmoid(scaling_factor * (y_norm - threshold))  # Compute the weights using sigmoid
    weights_masked = weights * mask  
    y_true_masked = y_true * mask 
    y_pred_masked = y_pred * mask  
    squared_error = K.square(y_true_masked - y_pred_masked)  
    weighted_error = weights_masked * squared_error  # Apply weights
    return K.sum(weighted_error) / (K.sum(weights_masked) + K.epsilon())  # Normalize

# %% [markdown]
# ## Metric classification

# %%
@tf.keras.utils.register_keras_serializable()
def create_missing_data_mask(y):
    return K.cast(K.less(y, 0), K.floatx()) # Mask where y == -1 (missing data)

# Mask for classifying values greater than or equal to 0.5
@tf.keras.utils.register_keras_serializable()
def create_class_mask(y):
    return K.cast(K.greater_equal(y, 0.5), K.floatx())

@tf.keras.utils.register_keras_serializable()
def FAR(y_true, y_pred):
    missing_mask = create_missing_data_mask(y_true)  # 1 where missing
    valid_mask = 1.0 - missing_mask  # 1 where valid

    y_true_class = create_class_mask(y_true)
    y_pred_class = create_class_mask(y_pred)

    # Only consider positions where valid_mask == 1
    FP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 0), K.floatx()) * valid_mask)
    TP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 1), K.floatx()) * valid_mask)

    far = FP / (TP + FP + K.epsilon())
    return far

@tf.keras.utils.register_keras_serializable()
def POD(y_true, y_pred):
    # Mask for missing data and valid values
    missing_mask = create_missing_data_mask(y_true)
    valid_mask = 1.0 - missing_mask

    # Convert to binary class masks
    y_true_class = create_class_mask(y_true)
    y_pred_class = create_class_mask(y_pred)


    TP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 1), K.floatx()) * valid_mask)
    FN = K.sum(K.cast((y_pred_class == 0) & (y_true_class == 1), K.floatx()) * valid_mask)

    pod = TP / (TP + FN + K.epsilon())
    return pod

@tf.keras.utils.register_keras_serializable()
def CSI(y_true, y_pred):
    # Create the missing data mask
    missing_mask = create_missing_data_mask(y_true)
    valid_mask = 1.0 - missing_mask

    # Convert to binary class masks
    y_true_class = create_class_mask(y_true)
    y_pred_class = create_class_mask(y_pred)

    # TP, FP, FN (only on valid data)
    TP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 1), K.floatx()) * valid_mask)
    FP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 0), K.floatx()) * valid_mask)
    FN = K.sum(K.cast((y_pred_class == 0) & (y_true_class == 1), K.floatx()) * valid_mask)

    csi = TP / (TP + FP + FN + K.epsilon())
    return csi

# %% [markdown]
# ## Train .fit

# %%
optimizer = Adam(learning_rate=0.001)

# Callbacks
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True, mode='min', verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)

# Compile Model
model.compile(optimizer=optimizer, 
              loss=weighted_sigmoid_mse, 
              metrics=[RMSE, CC, R2, POD, FAR, CSI])

# Train Model
history = model.fit(X_train_scaled, y_train,
                    batch_size=32,
                    epochs=80,
                    verbose=1,
                    validation_data=(X_val_scaled, y_val),
                    callbacks=[checkpoint, reduce_lr, early_stopping])
# Out:
# Epoch 1/80
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746258999.556881      65 service.cc:148] XLA service 0x788fc4002d10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746258999.557721      65 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1746259001.361851      65 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-05-03 07:57:07.915012: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[64,14,1,1]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,32,90,250]{3,2,1,0}, f32[14,32,90,250]{3,2,1,0}), window={size=90x250 rhs_reversal=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-05-03 07:57:08.684758: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.76989002s
# Trying algorithm eng0{} for conv (f32[64,14,1,1]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,32,90,250]{3,2,1,0}, f32[14,32,90,250]{3,2,1,0}), window={size=90x250 rhs_reversal=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1746259045.026487      65 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: 0.2183 - csi: 0.1392 - far: 0.6373 - loss: 4.5881 - pod: 0.3549 - r2: -0.0451 - rmse: 1.7210
# E0000 00:00:1746259068.108999      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746259068.348763      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746259069.065587      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746259069.329977      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746259074.488927      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746259074.728394      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746259079.389670      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746259079.629766      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - cc: 0.2191 - csi: 0.1398 - far: 0.6371 - loss: 4.5878 - pod: 0.3555 - r2: -0.0436 - rmse: 1.7207
# E0000 00:00:1746259110.820341      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746259111.057220      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746259111.630563      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746259111.890987      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746259115.351482      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746259115.588574      66 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_loss improved from inf to 2.41426, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - cc: 0.2199 - csi: 0.1404 - far: 0.6369 - loss: 4.5874 - pod: 0.3561 - r2: -0.0422 - rmse: 1.7204 - val_cc: 0.0012 - val_csi: 0.0000e+00 - val_far: 0.0000e+00 - val_loss: 2.4143 - val_pod: 0.0000e+00 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 0.0010
# Epoch 2/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: 0.3455 - csi: 0.2724 - far: 0.6359 - loss: 5.1898 - pod: 0.5311 - r2: 0.1246 - rmse: 1.7648
# Epoch 2: val_loss improved from 2.41426 to 2.41194, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 474ms/step - cc: 0.3454 - csi: 0.2721 - far: 0.6364 - loss: 5.1745 - pod: 0.5310 - r2: 0.1245 - rmse: 1.7630 - val_cc: 0.1212 - val_csi: 3.1394e-04 - val_far: 0.0909 - val_loss: 2.4119 - val_pod: 3.1394e-04 - val_r2: -0.0085 - val_rmse: 1.4207 - learning_rate: 0.0010
# Epoch 3/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: 0.3372 - csi: 0.2654 - far: 0.6491 - loss: 4.5902 - pod: 0.5305 - r2: 0.1079 - rmse: 1.7073
# Epoch 3: val_loss did not improve from 2.41194
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 427ms/step - cc: 0.3373 - csi: 0.2653 - far: 0.6492 - loss: 4.5863 - pod: 0.5305 - r2: 0.1078 - rmse: 1.7065 - val_cc: 0.0858 - val_csi: 0.0016 - val_far: 0.1169 - val_loss: 2.4123 - val_pod: 0.0016 - val_r2: -0.0085 - val_rmse: 1.4208 - learning_rate: 0.0010
# Epoch 4/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: 0.3510 - csi: 0.2548 - far: 0.6606 - loss: 3.9952 - pod: 0.5147 - r2: 0.1158 - rmse: 1.5820
# Epoch 4: val_loss improved from 2.41194 to 2.39727, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 474ms/step - cc: 0.3510 - csi: 0.2547 - far: 0.6609 - loss: 4.0032 - pod: 0.5152 - r2: 0.1155 - rmse: 1.5831 - val_cc: 0.2054 - val_csi: 0.0159 - val_far: 0.3094 - val_loss: 2.3973 - val_pod: 0.0163 - val_r2: -3.7690e-04 - val_rmse: 1.4155 - learning_rate: 0.0010
# Epoch 5/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: 0.3568 - csi: 0.2643 - far: 0.6534 - loss: 4.5803 - pod: 0.5556 - r2: 0.0765 - rmse: 1.7166
# Epoch 5: val_loss improved from 2.39727 to 2.26038, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 474ms/step - cc: 0.3566 - csi: 0.2640 - far: 0.6536 - loss: 4.5768 - pod: 0.5552 - r2: 0.0767 - rmse: 1.7156 - val_cc: 0.2520 - val_csi: 0.1468 - val_far: 0.8297 - val_loss: 2.2604 - val_pod: 0.5141 - val_r2: 0.0613 - val_rmse: 1.3709 - learning_rate: 0.0010
# Epoch 6/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: 0.3580 - csi: 0.2549 - far: 0.6861 - loss: 3.5882 - pod: 0.6144 - r2: 0.1231 - rmse: 1.5722
# Epoch 6: val_loss improved from 2.26038 to 2.21206, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 474ms/step - cc: 0.3578 - csi: 0.2550 - far: 0.6858 - loss: 3.6039 - pod: 0.6132 - r2: 0.1229 - rmse: 1.5738 - val_cc: 0.3113 - val_csi: 0.2054 - val_far: 0.7098 - val_loss: 2.2121 - val_pod: 0.4166 - val_r2: 0.0866 - val_rmse: 1.3538 - learning_rate: 0.0010
# Epoch 7/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: 0.3552 - csi: 0.2456 - far: 0.6945 - loss: 3.0023 - pod: 0.5557 - r2: 0.1117 - rmse: 1.4631
# Epoch 7: val_loss improved from 2.21206 to 2.17834, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 474ms/step - cc: 0.3552 - csi: 0.2458 - far: 0.6942 - loss: 3.0297 - pod: 0.5560 - r2: 0.1118 - rmse: 1.4669 - val_cc: 0.3294 - val_csi: 0.2202 - val_far: 0.7084 - val_loss: 2.1783 - val_pod: 0.4759 - val_r2: 0.1016 - val_rmse: 1.3425 - learning_rate: 0.0010
# Epoch 8/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: 0.3373 - csi: 0.2704 - far: 0.6462 - loss: 5.5771 - pod: 0.5385 - r2: 0.1099 - rmse: 1.8032
# Epoch 8: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 429ms/step - cc: 0.3379 - csi: 0.2704 - far: 0.6462 - loss: 5.5526 - pod: 0.5387 - r2: 0.1103 - rmse: 1.8002 - val_cc: 0.3216 - val_csi: 0.1478 - val_far: 0.8432 - val_loss: 2.2595 - val_pod: 0.7213 - val_r2: 0.0334 - val_rmse: 1.3819 - learning_rate: 0.0010
# Epoch 9/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: 0.2484 - csi: 0.1626 - far: 0.6781 - loss: 5.3924 - pod: 0.3726 - r2: -0.1349 - rmse: 1.8085
# Epoch 9: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 429ms/step - cc: 0.2461 - csi: 0.1610 - far: 0.6763 - loss: 5.3888 - pod: 0.3688 - r2: -0.1393 - rmse: 1.8092 - val_cc: 0.0000e+00 - val_csi: 0.0000e+00 - val_far: 0.0000e+00 - val_loss: 2.4143 - val_pod: 0.0000e+00 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 0.0010
# Epoch 10/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: -6.4794e-07 - csi: 0.0000e+00 - far: 0.0062 - loss: 5.0437 - pod: 0.0000e+00 - r2: -0.0092 - rmse: 1.8539
# Epoch 10: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 427ms/step - cc: -6.7751e-07 - csi: 0.0000e+00 - far: 0.0065 - loss: 5.0377 - pod: 0.0000e+00 - r2: -0.0092 - rmse: 1.8522 - val_cc: 0.0000e+00 - val_csi: 0.0000e+00 - val_far: 0.0000e+00 - val_loss: 2.4143 - val_pod: 0.0000e+00 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 0.0010
# Epoch 11/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 5.1763 - pod: 0.0000e+00 - r2: -0.0091 - rmse: 1.8646
# Epoch 11: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 5.1676 - pod: 0.0000e+00 - r2: -0.0091 - rmse: 1.8629 - val_cc: 0.0000e+00 - val_csi: 0.0000e+00 - val_far: 0.0000e+00 - val_loss: 2.4143 - val_pod: 0.0000e+00 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 0.0010
# Epoch 12/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 6.0446 - pod: 0.0000e+00 - r2: -0.0088 - rmse: 1.9193
# Epoch 12: val_loss did not improve from 2.17834
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 427ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 6.0184 - pod: 0.0000e+00 - r2: -0.0088 - rmse: 1.9158 - val_cc: 0.0000e+00 - val_csi: 0.0000e+00 - val_far: 0.0000e+00 - val_loss: 2.4143 - val_pod: 0.0000e+00 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 0.0010
# Epoch 13/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: -7.8548e-06 - csi: 0.0000e+00 - far: 0.0608 - loss: 5.2448 - pod: 0.0000e+00 - r2: -0.0098 - rmse: 1.7906
# Epoch 13: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: -7.7504e-06 - csi: 0.0000e+00 - far: 0.0600 - loss: 5.2347 - pod: 0.0000e+00 - r2: -0.0098 - rmse: 1.7898 - val_cc: 8.8589e-06 - val_csi: 0.0000e+00 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 0.0000e+00 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 5.0000e-04
# Epoch 14/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - cc: -2.5636e-06 - csi: 0.0000e+00 - far: 0.0086 - loss: 4.0172 - pod: 0.0000e+00 - r2: -0.0094 - rmse: 1.6100
# Epoch 14: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 427ms/step - cc: -2.6034e-06 - csi: 0.0000e+00 - far: 0.0088 - loss: 4.0317 - pod: 0.0000e+00 - r2: -0.0094 - rmse: 1.6134 - val_cc: 8.8590e-06 - val_csi: 0.0000e+00 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 0.0000e+00 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 5.0000e-04
# Epoch 15/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: -1.1578e-06 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 4.5752 - pod: 0.0000e+00 - r2: -0.0092 - rmse: 1.7592
# Epoch 15: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: -1.1766e-06 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 4.5784 - pod: 0.0000e+00 - r2: -0.0092 - rmse: 1.7592 - val_cc: 0.0000e+00 - val_csi: 0.0000e+00 - val_far: 0.0000e+00 - val_loss: 2.4143 - val_pod: 0.0000e+00 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 5.0000e-04
# Epoch 16/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: -2.8720e-06 - csi: 0.0000e+00 - far: 0.0201 - loss: 4.4506 - pod: 0.0000e+00 - r2: -0.0091 - rmse: 1.6829
# Epoch 16: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: -2.8729e-06 - csi: 0.0000e+00 - far: 0.0201 - loss: 4.4564 - pod: 0.0000e+00 - r2: -0.0091 - rmse: 1.6846 - val_cc: 8.7955e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 5.0000e-04
# Epoch 17/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: -3.7433e-06 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 6.1276 - pod: 0.0000e+00 - r2: -0.0087 - rmse: 1.9240
# Epoch 17: val_loss did not improve from 2.17834
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: -3.7228e-06 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 6.0998 - pod: 0.0000e+00 - r2: -0.0088 - rmse: 1.9210 - val_cc: 8.7959e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 5.0000e-04
# Epoch 18/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: -2.7510e-08 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 4.6698 - pod: 0.0000e+00 - r2: -0.0089 - rmse: 1.7285
# Epoch 18: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 427ms/step - cc: -3.1219e-08 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 4.6713 - pod: 0.0000e+00 - r2: -0.0089 - rmse: 1.7290 - val_cc: 8.7959e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 2.5000e-04
# Epoch 19/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 3.6256 - pod: 0.0000e+00 - r2: -0.0092 - rmse: 1.6658
# Epoch 19: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 3.6479 - pod: 0.0000e+00 - r2: -0.0092 - rmse: 1.6681 - val_cc: 8.6946e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 2.5000e-04
# Epoch 20/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 5.5176 - pod: 0.0000e+00 - r2: -0.0089 - rmse: 1.9175
# Epoch 20: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 427ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 5.5020 - pod: 0.0000e+00 - r2: -0.0089 - rmse: 1.9142 - val_cc: 8.7948e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 2.5000e-04
# Epoch 21/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 5.1995 - pod: 0.0000e+00 - r2: -0.0092 - rmse: 1.8079
# Epoch 21: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 427ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 5.1903 - pod: 0.0000e+00 - r2: -0.0092 - rmse: 1.8072 - val_cc: 8.7954e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 2.5000e-04
# Epoch 22/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 6.0537 - pod: 0.0000e+00 - r2: -0.0093 - rmse: 1.8766
# Epoch 22: val_loss did not improve from 2.17834
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 429ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 6.0274 - pod: 0.0000e+00 - r2: -0.0093 - rmse: 1.8736 - val_cc: 8.7939e-04 - val_csi: 0.0000e+00 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 0.0000e+00 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 2.5000e-04
# Epoch 23/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 5.6305 - pod: 0.0000e+00 - r2: -0.0088 - rmse: 1.9162
# Epoch 23: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 426ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 5.6125 - pod: 0.0000e+00 - r2: -0.0088 - rmse: 1.9126 - val_cc: 8.7932e-04 - val_csi: 0.0000e+00 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 0.0000e+00 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 1.2500e-04
# Epoch 24/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: -6.5523e-06 - csi: 0.0000e+00 - far: 0.0540 - loss: 4.7249 - pod: 0.0000e+00 - r2: -0.0085 - rmse: 1.7080
# Epoch 24: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: -6.4965e-06 - csi: 0.0000e+00 - far: 0.0533 - loss: 4.7252 - pod: 0.0000e+00 - r2: -0.0085 - rmse: 1.7088 - val_cc: -9.4459e-06 - val_csi: 0.0000e+00 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 0.0000e+00 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 1.2500e-04
# Epoch 25/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: -3.0386e-06 - csi: 2.9046e-07 - far: 0.0000e+00 - loss: 4.1610 - pod: 2.9046e-07 - r2: -0.0085 - rmse: 1.6714
# Epoch 25: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: -2.7783e-06 - csi: 3.0557e-07 - far: 0.0000e+00 - loss: 4.1724 - pod: 3.0557e-07 - r2: -0.0085 - rmse: 1.6734 - val_cc: 8.7955e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 1.2500e-04
# Epoch 26/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: 6.6255e-06 - csi: 3.5377e-07 - far: 0.0000e+00 - loss: 6.6784 - pod: 3.5377e-07 - r2: -0.0099 - rmse: 1.9372
# Epoch 26: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 427ms/step - cc: 6.8916e-06 - csi: 3.6797e-07 - far: 0.0000e+00 - loss: 6.6395 - pod: 3.6797e-07 - r2: -0.0099 - rmse: 1.9329 - val_cc: 8.7951e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 1.2500e-04
# Epoch 27/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: -1.0027e-05 - csi: 0.0000e+00 - far: 0.0914 - loss: 5.1413 - pod: 0.0000e+00 - r2: -0.0088 - rmse: 1.8107
# Epoch 27: val_loss did not improve from 2.17834
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: -9.8717e-06 - csi: 0.0000e+00 - far: 0.0900 - loss: 5.1332 - pod: 0.0000e+00 - r2: -0.0088 - rmse: 1.8098 - val_cc: 8.7950e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4215 - learning_rate: 1.2500e-04
# Epoch 28/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 4.8038 - pod: 0.0000e+00 - r2: -0.0085 - rmse: 1.8061
# Epoch 28: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 4.8025 - pod: 0.0000e+00 - r2: -0.0085 - rmse: 1.8054 - val_cc: 8.7959e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 6.2500e-05
# Epoch 29/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 4.2443 - pod: 0.0000e+00 - r2: -0.0090 - rmse: 1.7204
# Epoch 29: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 4.2541 - pod: 0.0000e+00 - r2: -0.0090 - rmse: 1.7212 - val_cc: 8.7960e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 6.2500e-05
# Epoch 30/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: -1.4375e-06 - csi: 0.0000e+00 - far: 0.0099 - loss: 5.6780 - pod: 0.0000e+00 - r2: -0.0079 - rmse: 1.8827
# Epoch 30: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 429ms/step - cc: -1.4681e-06 - csi: 0.0000e+00 - far: 0.0101 - loss: 5.6592 - pod: 0.0000e+00 - r2: -0.0079 - rmse: 1.8803 - val_cc: 8.7960e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 6.2500e-05
# Epoch 31/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 4.6679 - pod: 0.0000e+00 - r2: -0.0093 - rmse: 1.7103
# Epoch 31: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 4.6694 - pod: 0.0000e+00 - r2: -0.0093 - rmse: 1.7108 - val_cc: 8.7959e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 6.2500e-05
# Epoch 32/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: -6.1463e-07 - csi: 2.3774e-07 - far: 0.0080 - loss: 4.6338 - pod: 2.3774e-07 - r2: -0.0099 - rmse: 1.6931
# Epoch 32: val_loss did not improve from 2.17834
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: -3.8885e-07 - csi: 2.5669e-07 - far: 0.0082 - loss: 4.6360 - pod: 2.5669e-07 - r2: -0.0099 - rmse: 1.6937 - val_cc: 8.7960e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 6.2500e-05
# Epoch 33/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: -4.7737e-06 - csi: 0.0000e+00 - far: 0.0359 - loss: 4.6844 - pod: 0.0000e+00 - r2: -0.0101 - rmse: 1.7618
# Epoch 33: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 429ms/step - cc: -4.7707e-06 - csi: 0.0000e+00 - far: 0.0356 - loss: 4.6856 - pod: 0.0000e+00 - r2: -0.0101 - rmse: 1.7617 - val_cc: 8.7960e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 3.1250e-05
# Epoch 34/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: -5.5050e-06 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 4.3896 - pod: 0.0000e+00 - r2: -0.0088 - rmse: 1.7259
# Epoch 34: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 429ms/step - cc: -5.4409e-06 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 4.3967 - pod: 0.0000e+00 - r2: -0.0089 - rmse: 1.7267 - val_cc: 8.7960e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 3.1250e-05
# Epoch 35/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: -2.1467e-06 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 5.1869 - pod: 0.0000e+00 - r2: -0.0095 - rmse: 1.7346
# Epoch 35: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 427ms/step - cc: -2.1648e-06 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 5.1778 - pod: 0.0000e+00 - r2: -0.0095 - rmse: 1.7343 - val_cc: 8.8838e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 3.1250e-05
# Epoch 36/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: -3.6525e-06 - csi: 0.0000e+00 - far: 0.0359 - loss: 3.8590 - pod: 0.0000e+00 - r2: -0.0094 - rmse: 1.5712
# Epoch 36: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 429ms/step - cc: -3.6209e-06 - csi: 0.0000e+00 - far: 0.0356 - loss: 3.8766 - pod: 0.0000e+00 - r2: -0.0094 - rmse: 1.5746 - val_cc: 8.7960e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 3.1250e-05
# Epoch 37/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: -1.3720e-06 - csi: 0.0000e+00 - far: 0.0041 - loss: 4.2511 - pod: 0.0000e+00 - r2: -0.0096 - rmse: 1.7187
# Epoch 37: val_loss did not improve from 2.17834
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: -1.4442e-06 - csi: 0.0000e+00 - far: 0.0044 - loss: 4.2609 - pod: 0.0000e+00 - r2: -0.0096 - rmse: 1.7197 - val_cc: 8.7960e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 3.1250e-05
# Epoch 38/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 4.0961 - pod: 0.0000e+00 - r2: -0.0098 - rmse: 1.6861
# Epoch 38: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 427ms/step - cc: 0.0000e+00 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 4.1090 - pod: 0.0000e+00 - r2: -0.0098 - rmse: 1.6879 - val_cc: 8.7960e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 1.5625e-05
# Epoch 39/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: -2.8150e-07 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 3.6545 - pod: 0.0000e+00 - r2: -0.0094 - rmse: 1.5932
# Epoch 39: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: -3.1944e-07 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 3.6761 - pod: 0.0000e+00 - r2: -0.0094 - rmse: 1.5964 - val_cc: 8.7960e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 1.5625e-05
# Epoch 40/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: -1.4670e-05 - csi: 0.0000e+00 - far: 0.0767 - loss: 4.9653 - pod: 0.0000e+00 - r2: -0.0101 - rmse: 1.7454
# Epoch 40: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: -1.4508e-05 - csi: 0.0000e+00 - far: 0.0760 - loss: 4.9608 - pod: 0.0000e+00 - r2: -0.0101 - rmse: 1.7454 - val_cc: 8.7960e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 1.5625e-05
# Epoch 41/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: 2.1220e-06 - csi: 0.0000e+00 - far: 0.0128 - loss: 4.4260 - pod: 0.0000e+00 - r2: -0.0092 - rmse: 1.6695
# Epoch 41: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 427ms/step - cc: 2.1475e-06 - csi: 0.0000e+00 - far: 0.0129 - loss: 4.4324 - pod: 0.0000e+00 - r2: -0.0092 - rmse: 1.6715 - val_cc: 8.7960e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 1.5625e-05
# Epoch 42/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: 6.3952e-07 - csi: 4.9865e-08 - far: 0.0000e+00 - loss: 3.6305 - pod: 4.9865e-08 - r2: -0.0093 - rmse: 1.5615
# Epoch 42: val_loss did not improve from 2.17834
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: 1.0325e-06 - csi: 7.3049e-08 - far: 0.0000e+00 - loss: 3.6527 - pod: 7.3049e-08 - r2: -0.0093 - rmse: 1.5655 - val_cc: 8.7960e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 1.5625e-05
# Epoch 43/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - cc: 2.8140e-07 - csi: 0.0000e+00 - far: 0.0068 - loss: 5.3240 - pod: 0.0000e+00 - r2: -0.0083 - rmse: 1.8404
# Epoch 43: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: 3.9954e-07 - csi: 0.0000e+00 - far: 0.0071 - loss: 5.3123 - pod: 0.0000e+00 - r2: -0.0084 - rmse: 1.8390 - val_cc: 8.7960e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 7.8125e-06
# Epoch 44/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: 1.0838e-05 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 3.0638 - pod: 0.0000e+00 - r2: -0.0095 - rmse: 1.4866
# Epoch 44: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: 1.0854e-05 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 3.0974 - pod: 0.0000e+00 - r2: -0.0095 - rmse: 1.4910 - val_cc: 8.7960e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 7.8125e-06
# Epoch 45/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - cc: -1.4126e-06 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 3.6112 - pod: 0.0000e+00 - r2: -0.0096 - rmse: 1.5846
# Epoch 45: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 429ms/step - cc: -1.4245e-06 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 3.6339 - pod: 0.0000e+00 - r2: -0.0096 - rmse: 1.5882 - val_cc: 8.7960e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 7.8125e-06
# Epoch 46/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: -1.4714e-06 - csi: 0.0000e+00 - far: 0.0186 - loss: 6.6767 - pod: 0.0000e+00 - r2: -0.0090 - rmse: 2.0416
# Epoch 46: val_loss did not improve from 2.17834
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 429ms/step - cc: -1.5100e-06 - csi: 0.0000e+00 - far: 0.0191 - loss: 6.6378 - pod: 0.0000e+00 - r2: -0.0090 - rmse: 2.0358 - val_cc: 8.7960e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 7.8125e-06
# Epoch 47/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - cc: -2.1722e-07 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 5.3350 - pod: 0.0000e+00 - r2: -0.0090 - rmse: 1.8185
# Epoch 47: val_loss did not improve from 2.17834
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - cc: -2.3752e-07 - csi: 0.0000e+00 - far: 0.0000e+00 - loss: 5.3231 - pod: 0.0000e+00 - r2: -0.0090 - rmse: 1.8171 - val_cc: 8.7960e-04 - val_csi: 5.7443e-06 - val_far: 0.0909 - val_loss: 2.4143 - val_pod: 5.7443e-06 - val_r2: -0.0097 - val_rmse: 1.4214 - learning_rate: 7.8125e-06
# Epoch 47: early stopping
# Restoring model weights from the end of the best epoch: 7.

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Metric valid set

# %%
best_epoch = np.argmin(history.history['val_loss'])

# Print all metrics for that epoch
print(f"Best Epoch: {best_epoch + 1}")
for metric in history.history.keys():
    print(f"{metric}: {history.history[metric][best_epoch]:.4f}")
# Out:
# Best Epoch: 7
# cc: 0.3547
# csi: 0.2555
# far: 0.6815
# loss: 4.3722
# pod: 0.5708
# r2: 0.1167
# rmse: 1.6530
# val_cc: 0.3294
# val_csi: 0.2202
# val_far: 0.7084
# val_loss: 2.1783
# val_pod: 0.4759
# val_r2: 0.1016
# val_rmse: 1.3425
# learning_rate: 0.0010

# %%
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix
from scipy.stats import pearsonr
from tensorflow.keras.models import load_model

# %% [markdown]
# ## Metric test set

# %%
best_model = load_model('/kaggle/working/best_model.keras')
y_test_pred = best_model.predict(X_test_scaled)
y_test_pred_flat = y_test_pred.flatten()
y_test_flat = y_test.flatten()

# Mask to exclude missing data 
mask = y_test_flat >= 0

# Apply mask to filter out missing data
y_test_flat_filtered = y_test_flat[mask]
y_test_pred_flat_filtered = y_test_pred_flat[mask]

mse = mean_squared_error(y_test_flat_filtered, y_test_pred_flat_filtered)
rmse = np.sqrt(mse)
cc, _ = pearsonr(y_test_flat_filtered, y_test_pred_flat_filtered)
r2 = r2_score(y_test_flat_filtered, y_test_pred_flat_filtered)

print("Test set")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"Correlation Coefficient (CC): {cc}")
print(f"R²: {r2}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step
# Test set
# MSE: 2.2490975856781006
# RMSE: 1.4996991157531738
# Correlation Coefficient (CC): 0.3265845775604248
# R²: 0.0973022786140959

# %%
from sklearn.metrics import confusion_matrix
true_class_mask = y_test_flat >= 0.5
pred_class_mask = y_test_pred_flat >= 0.5


true_class_mask = np.where(mask, true_class_mask, -1)
pred_class_mask = np.where(mask, pred_class_mask, -1)

valid_mask = (true_class_mask != -1) & (pred_class_mask != -1)
true_class_mask_filtered = true_class_mask[valid_mask]
pred_class_mask_filtered = pred_class_mask[valid_mask]
cm = confusion_matrix(true_class_mask_filtered, pred_class_mask_filtered)

# If cm is a 2x2 matrix, unpack it
if cm.shape == (2, 2):
    tn, fp, fn, tp = cm.ravel()
else:
    # Handle cases where there's no confusion matrix (only one class present)
    tn = cm[0, 0] if cm.shape[0] > 1 else 1
    fp = cm[0, 1] if cm.shape[1] > 1 else 0
    fn = cm[1, 0] if cm.shape[0] > 1 else 0
    tp = cm[1, 1] if cm.shape[1] > 1 else 1

far = fp / (tp + fp) if (tp + fp) > 0 else 0.0

# Probability of Detection (POD) = TP / (TP + FN)
pod = tp / (tp + fn) if (tp + fn) > 0 else 0.0

# Critical Success Index (CSI) = TP / (TP + FP + FN)
csi = tp / (tp + fp + fn) if (tp + fp + fn) > 0 else 0.0

# Print the metrics
print(f"FAR: {far}")
print(f"POD: {pod}")
print(f"CSI: {csi}")
# Out:
# FAR: 0.6874023113721404
# POD: 0.5057690373442791
# CSI: 0.2394528760966628

# %% [markdown]
# ## Plot

# %%
num_examples = 16  # Number of examples to visualize
plt.figure(figsize=(20, 5 * num_examples))
random_indices = np.random.choice(len(y_test), size=num_examples, replace=False)
np.random.seed(42)
for i, index in enumerate(random_indices):
    
    predicted_image = y_test_pred[index]
    radar_image = y_test[index]
    
    mask = radar_image >= 0
    predicted_image[~mask] = -np.inf
    radar_image[~mask] = -np.inf
    vmin = 0
    vmax_true = np.max(radar_image)
    vmax_pred = np.max(predicted_image)
    vmax = np.max([vmax_true, vmax_pred])

    plt.subplot(num_examples, 2, i * 2 + 1)
    im1 = plt.imshow(radar_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Actual Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im1, fraction=0.046, pad=0.04)

    # Plot predicted image
    plt.subplot(num_examples, 2, i * 2 + 2)
    im2 = plt.imshow(predicted_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Predicted Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im2, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()

# %%
num_examples = len(random_indices)
cols = 4
rows = (num_examples + cols - 1) // cols

plt.figure(figsize=(cols * 5, rows * 4))  # Adjust size as needed

for i, index in enumerate(random_indices):
    predicted_image = y_test_pred[index]
    radar_image = y_test[index]
    
    # Mask invalid values
    mask = radar_image >= 0
    predicted_image = predicted_image[mask]
    radar_image = radar_image[mask]
    
    # Scatter plot
    plt.subplot(rows, cols, i + 1)
    plt.scatter(radar_image.flatten(), predicted_image.flatten(), alpha=0.6, s=10)
    plt.title(f'Image #{index}', fontsize=10)
    plt.xlabel('Actual', fontsize=8)
    plt.ylabel('Predicted', fontsize=8)
    plt.axis('equal')
    plt.xticks(fontsize=6)
    plt.yticks(fontsize=6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot val

# %%
y_val_pred = best_model.predict(X_val_scaled)

plt.figure(figsize=(20, 5 * num_examples))
for i, index in enumerate(random_indices):
    
    predicted_image = y_val_pred[index]
    radar_image = y_val[index]
    
    mask = radar_image >= 0
    predicted_image[~mask] = -np.inf
    radar_image[~mask] = -np.inf
    vmin = 0
    vmax_true = np.max(radar_image)
    vmax_pred = np.max(predicted_image)
    vmax = np.max([vmax_true, vmax_pred])

    plt.subplot(num_examples, 2, i * 2 + 1)
    im1 = plt.imshow(radar_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Actual Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im1, fraction=0.046, pad=0.04)

    # Plot predicted image
    plt.subplot(num_examples, 2, i * 2 + 2)
    im2 = plt.imshow(predicted_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Predicted Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im2, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step

# %%
plt.figure(figsize=(20, 5 * num_examples))
for i, index in enumerate(random_indices):
    
    predicted_image = y_val_pred[index]
    radar_image = y_val[index]
    
    mask = radar_image >= 0
    radar_image[~mask] = -np.inf
    vmin = 0
    vmax_true = np.max(radar_image)
    vmax_pred = np.max(predicted_image)
    vmax = np.max([vmax_true, vmax_pred])

    plt.subplot(num_examples, 2, i * 2 + 1)
    im1 = plt.imshow(radar_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Actual Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im1, fraction=0.046, pad=0.04)

    # Plot predicted image
    plt.subplot(num_examples, 2, i * 2 + 2)
    im2 = plt.imshow(predicted_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Predicted Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im2, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
