# %%
# !pip install rasterio h5py
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (3.12.1)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio) (2025.1.31)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio) (8.1.8)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.11/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.11/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from rasterio) (3.2.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24->rasterio) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24->rasterio) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.24->rasterio) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.24->rasterio) (2024.2.0)
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 84.4 MB/s eta 0:00:00
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.4.3

# %%
import os
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
import rasterio
import matplotlib.pyplot as plt
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.losses import Huber
print(tf.__version__)
# Out:
# 2025-05-03 07:47:26.671610: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746258446.867934      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746258446.924850      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2.18.0

# %%
DATA_PATH = "/kaggle/input/data-rain-v2/DATA_RAIN_V2"
# ERA5_ATTRIBUTES = ["CAPE", "CIN", "EWSS", "IE", "ISOR", "KX", "PEV", "R250", "R500", "R850", "SLHF", "SLOR", "SSHF","TCLW","TCW","TCWV", "U250", "U850","V250", "V850"]
# HIMA_BANDS = ["B09B", "B10B", "B11B","B12B", "B14B", "B16B", "IRB", "I2B", "I4B", "WVB"]
ERA5_ATTRIBUTES = ["CAPE", "CIN", "R500", "TCLW","TCW","TCWV", "V250", "V850"]
HIMA_BANDS = ["B09B", "B11B","B12B", "B16B", "I4B", "WVB"]
print(len(ERA5_ATTRIBUTES ))
print(len(HIMA_BANDS))
# Out:
# 8
# 6

# %% [markdown]
# # 1. Load dữ liệu

# %% [markdown]
# ## 1.1. Hàm lấy file

# %%
def convert_time_to_strings(year, month, day, hour):
    year_str = str(year)
    month_str = f"{int(month):02d}"
    day_str = f"{int(day):02d}"
    hour_str = f"{int(hour):02d}"
    return year_str, month_str, day_str, hour_str

def get_era5_file_path(attribute, year, month, day, hour):
    year, month, day, hour = convert_time_to_strings(year, month, day, hour)
    file_name = f"ERA5_{attribute}_{year}_{month}_{day}_{hour}.tif"
    file_path = os.path.join(DATA_PATH, year, month, day, hour, "ERA5", file_name)
    return file_path


def get_hima_file_path(band, year, month, day, hour):
    year, month, day, hour = convert_time_to_strings(year, month, day, hour)
    file_name = f"Hima_{band}_{year}_{month}_{day}_{hour}.tif"
    file_path = os.path.join(DATA_PATH, year, month, day, hour, "Hima", file_name)
    return file_path

def get_radar_file_path(year, month, day, hour):
    year, month, day, hour = convert_time_to_strings(year, month, day, hour)
    file_name = f"Radar_{year}_{month}_{day}_{hour}.tif"
    file_path = os.path.join(DATA_PATH, year, month, day, hour, "Radar", file_name)
    return file_path

# %% [markdown]
# ## 1.2. Load file

# %%
def load_era5_attributes(year, month, day, hour):
    era5_imgs= []
    for attribute in ERA5_ATTRIBUTES:
        file_path = get_era5_file_path(attribute, year, month, day, hour)
        try:
            with rasterio.open(file_path) as src:
                era5_imgs.append(src.read(1)) 
        except Exception as e:
            print(f"Failed to load {attribute} for {year}-{month}-{day} {hour}:00:00 {e}")
    era5_data = np.stack(era5_imgs, axis=-1)  
    return era5_data

def load_hima_bands(year, month, day, hour):
    hima_imgs = []
    for band in HIMA_BANDS:
        file_path = get_hima_file_path(band, year, month, day, hour)
        try:
            with rasterio.open(file_path) as src:
                hima_imgs.append(src.read(1))
        except Exception as e:
                print(f"Failed to load {band} for {year}-{month}-{day} {hour}:00:00 {e}")
    hima_data = np.stack(hima_imgs, axis = -1)
    return hima_data

def load_radar(year, month, day, hour):
    radar_img = None
    file_path = get_radar_file_path(year, month, day, hour)
    try: 
        with rasterio.open(file_path) as src:
            radar_img = src.read(1)
    except Exception as e:
        print(f"Failed to load radar for {year}-{month}-{day} {hour}:00:00 {e}")
    return radar_img

# %%
def load_data_for_timestamp(year, month, day, hour, use_era5 = True):
    try:
        era5_data = None
        if use_era5:
            era5_data = load_era5_attributes(year, month, day, hour)

        hima_data = load_hima_bands(year, month, day, hour)
        radar_data = load_radar(year, month, day, hour)
        if use_era5:
            input_images = np.concatenate((hima_data, era5_data), axis = -1) #shape (90, 250, hima + era5)
        else:
            input_images = hima_data

        return input_images, radar_data

    except Exception as e:
        print(f"Failed to load data for {year}-{month}-{day} {hour}:00:00 {e}")
        return None, None

# %%
def load_dataset(timestamps_df, use_era5 = True):
    X = []
    y = []
    timestamps_tuples = list(timestamps_df[['year', 'month', 'day', 'hour']].itertuples(index=False, name=None))
    for year, month, day, hour in tqdm(timestamps_tuples):
        input_images, radar_image = load_data_for_timestamp(year, month, day, hour, use_era5)
        if input_images is not None and radar_image is not None:
            X.append(input_images)
            y.append(radar_image)
    
    X = np.array(X)
    y = np.array(y)
    y = y[..., np.newaxis] #(90, 250, 1)
    return X, y

# %% [markdown]
# ## 1.3. Chia dữ liệu

# %%
rain_df = pd.read_csv("/kaggle/input/valid-time-rain/final_rain_timestamps.csv", index_col=None)
rain_df.drop(columns = ['Unnamed: 0'], inplace = True)
train_df, tmp_df = train_test_split(
    rain_df, test_size = 0.3, stratify=rain_df["radar_mean_class"], random_state = 42
)

val_df, test_df = train_test_split(
    tmp_df, test_size=0.5, stratify=tmp_df["radar_mean_class"], random_state=42
)

# %% [markdown]
# ## USE_ERA5

# %%
USE_ERA5 = True

# %% [markdown]
# ## 1.4. Scale dữ liệu

# %%
X_train, y_train = load_dataset(train_df, USE_ERA5)
X_val, y_val = load_dataset(val_df, USE_ERA5)
X_test, y_test = load_dataset(test_df, USE_ERA5)
# Out:
# 100%|██████████| 1562/1562 [03:25<00:00,  7.62it/s]
# 100%|██████████| 335/335 [00:41<00:00,  7.98it/s]
# 100%|██████████| 335/335 [00:43<00:00,  7.68it/s]

# %%
# np.savez_compressed('/kaggle/working/raindataset.npz', X_train=X_train, y_train=y_train, X_val = X_val, y_val = y_val, X_test = X_test, y_test = y_test)

# %%
y_train.max()
# Out:
# 260.0

# %%
y_val.max()
# Out:
# 231.0

# %%
y_test.max()
# Out:
# 234.71875

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_X = MinMaxScaler()

X_train_reshaped = X_train.reshape(-1, X_train.shape[-1]) #(num_sample * 250 * 90, hima + era5)
scaler_X.fit(X_train_reshaped)

X_train_scaled = scaler_X.transform(X_train_reshaped).reshape(X_train.shape)
X_val_scaled = scaler_X.transform(X_val.reshape(-1, X_val.shape[-1])).reshape(X_val.shape)
X_test_scaled = scaler_X.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

# %% [markdown]
# # Xử lý -inf

# %%
y_train = np.where(y_train < 0, -1, y_train)
y_val = np.where(y_val < 0, -1, y_val)
y_test = np.where(y_test < 0, -1, y_test)

# %% [markdown]
# # 2. Train

# %% [markdown]
# ## 2.1. Tham số mô hình

# %%
# BATCH_SIZE = 32
# NUM_FILTERS = [64, 128, 256, 512]
# BOTTLENECK_FILTER = 1024
# EPOCHS = 100

# %% [markdown]
# ## 2.2. Tạo mô hình

# %%
# Each convolutional layer is followed by a batch-normalization layer and the ReLU activation function, except for the last 1 × 1 convolutional layers of each sub-networks
def conv_block(inputs, num_filters, kernel_size = 3):
    x = Conv2D(num_filters, kernel_size=kernel_size, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x

def residual_block(x, num_filters, kernel_size = 3):
    shortcut = x

    x = Conv2D(num_filters, kernel_size=1, padding='same', activation='relu')(x)
    x = Conv2D(num_filters, kernel_size=3, padding='same', activation='relu')(x)

    x = Add()([x, shortcut])
    return x

def inception_block(x, num_filters):
    #The “n × n reduce“ stands for the 1 × 1 convolutions preceding the concording n × n convolutions.
    if num_filters == 256:
        config = {
            "conv1x1": 64,
            "conv3x3_reduce": 128,
            "conv3x3": 128,
            "conv5x5_reduce": 64,
            "conv5x5": 32,
            "conv7x7_reduce": 32,
            "conv7x7": 32
        }
    elif num_filters == 512:
        config = {
            "conv1x1": 64,
            "conv3x3_reduce": 256,
            "conv3x3": 384,
            "conv5x5_reduce": 64,
            "conv5x5": 32,
            "conv7x7_reduce": 32,
            "conv7x7": 32
        }
    # Branch 1: 1x1 conv
    branch1 = Conv2D(config["conv1x1"], kernel_size=1, padding='same')(x)
    branch1 = BatchNormalization()(branch1)
    branch1 = ReLU()(branch1)

    # Branch 2: 1x1 conv -> 3x3 conv
    branch2 = Conv2D(config["conv3x3_reduce"], kernel_size=1, padding='same')(x)
    branch2 = ReLU()(branch2)
    branch2 = Conv2D(config["conv3x3"], kernel_size=3, padding='same')(branch2)
    branch2 = BatchNormalization()(branch2)
    branch2 = ReLU()(branch2)

    # Branch 3: 1x1 conv -> 5x5 conv
    branch3 = Conv2D(config["conv5x5_reduce"], kernel_size=1, padding='same')(x)
    branch3 = BatchNormalization()(branch3)
    branch3 = ReLU()(branch3)
    branch3 = Conv2D(config["conv5x5"], kernel_size=5, padding='same')(branch3)
    branch3 = BatchNormalization()(branch3)
    branch3 = ReLU()(branch3)

    # Branch 4: 1x1 conv -> 7x7 conv
    branch4 = Conv2D(config["conv7x7_reduce"], kernel_size=1, padding='same')(x)
    branch4 = BatchNormalization()(branch4)
    branch4 = ReLU()(branch4)
    branch4 = Conv2D(config["conv7x7"], kernel_size=7, padding='same')(branch4)
    branch4 = BatchNormalization()(branch4)
    branch4 = ReLU()(branch4)

    
    output = Concatenate()([branch1, branch2, branch3, branch4])
    return output
    
def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    x = conv_block(x, num_filters)
    p = MaxPooling2D(pool_size=(2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, kernel_size=3, strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    x = conv_block(x, num_filters)
    return x

# %%
def InceptionResUnet(input_shape):
    inputs = Input(shape=input_shape, name="input")
    x = ZeroPadding2D(padding=((3, 3), (3, 3)))(inputs) #90 x 250 -> 96 x 256

    # 2 lần 3x3conv-> pool
    skip0, pool0 = encoder_block(x, 64)
    # 2 lần 3x3conv-> pool
    skip1, pool1 = encoder_block(pool0, 128)

    #2 block inception
    skip2 = inception_block(pool1, 256)
    skip2 = inception_block(skip2, 256)
    pool2 = MaxPooling2D(pool_size=(2, 2))(skip2)

    bottleneck0 = inception_block(pool2, 512)
    bottleneck1 = inception_block(bottleneck0, 512)

    up2 = Conv2DTranspose(256, kernel_size=3, strides=2, padding="same")(bottleneck1)
    skip2 = residual_block(skip2, 256)
    up2 = Concatenate()([up2, skip2])  

    up2 = inception_block(up2, 256)
    up2 = inception_block(up2, 256)

    up1 = Conv2DTranspose(128, kernel_size=3, strides=2, padding="same")(up2)
    skip1 = residual_block(skip1, 128)
    up1 = Concatenate()([up1, skip1]) 

    up1 = conv_block(up1, 128)
    up1 = conv_block(up1, 128)

    up0 = Conv2DTranspose(64, kernel_size=3, strides=2, padding="same")(up1)
    skip0 = residual_block(skip0, 64)
    up0 = Concatenate()([up0, skip0])

    up0 = conv_block(up0, 128)

    x = up0

    x = Cropping2D(cropping=((3, 3), (3, 3)))(x)  # (96x256) → (90x250)
    outputs = Conv2D(1, kernel_size = 1, padding = 'same', activation='relu')(x)
    model = Model(inputs, outputs)
    return model

# %%
channel = None
if USE_ERA5:
    channel = len(HIMA_BANDS) + len(ERA5_ATTRIBUTES)
else:
    channel = len(HIMA_BANDS)
    
input_shape = (90, 250, channel)
model = InceptionResUnet(input_shape)
model.summary()
# Out:
# I0000 00:00:1746258762.728814      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)        │ (None, 90, 250, 14)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ zero_padding2d            │ (None, 96, 256, 14)    │              0 │ input[0][0]            │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 96, 256, 64)    │          8,128 │ zero_padding2d[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 96, 256, 64)    │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu (ReLU)              │ (None, 96, 256, 64)    │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 96, 256, 64)    │         36,928 │ re_lu[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 96, 256, 64)    │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1 (ReLU)            │ (None, 96, 256, 64)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 48, 128, 64)    │              0 │ re_lu_1[0][0]          │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 48, 128, 128)   │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 48, 128, 128)   │            512 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_2 (ReLU)            │ (None, 48, 128, 128)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 48, 128, 128)   │        147,584 │ re_lu_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 48, 128, 128)   │            512 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_3 (ReLU)            │ (None, 48, 128, 128)   │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 24, 64, 128)    │              0 │ re_lu_3[0][0]          │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 24, 64, 64)     │          8,256 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 24, 64, 32)     │          4,128 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 24, 64, 128)    │         16,512 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 24, 64, 64)     │            256 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 24, 64, 32)     │            128 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_5 (ReLU)            │ (None, 24, 64, 128)    │              0 │ conv2d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_7 (ReLU)            │ (None, 24, 64, 64)     │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_9 (ReLU)            │ (None, 24, 64, 32)     │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 24, 64, 64)     │          8,256 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 24, 64, 128)    │        147,584 │ re_lu_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 24, 64, 32)     │         51,232 │ re_lu_7[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 24, 64, 32)     │         50,208 │ re_lu_9[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 24, 64, 64)     │            256 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 24, 64, 128)    │            512 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 24, 64, 32)     │            128 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 24, 64, 32)     │            128 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_4 (ReLU)            │ (None, 24, 64, 64)     │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_6 (ReLU)            │ (None, 24, 64, 128)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_8 (ReLU)            │ (None, 24, 64, 32)     │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_10 (ReLU)           │ (None, 24, 64, 32)     │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 24, 64, 256)    │              0 │ re_lu_4[0][0],         │
# │                           │                        │                │ re_lu_6[0][0],         │
# │                           │                        │                │ re_lu_8[0][0],         │
# │                           │                        │                │ re_lu_10[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 24, 64, 64)     │         16,448 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 24, 64, 32)     │          8,224 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 24, 64, 128)    │         32,896 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 24, 64, 64)     │            256 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 24, 64, 32)     │            128 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_12 (ReLU)           │ (None, 24, 64, 128)    │              0 │ conv2d_12[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_14 (ReLU)           │ (None, 24, 64, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_16 (ReLU)           │ (None, 24, 64, 32)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 24, 64, 64)     │         16,448 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 24, 64, 128)    │        147,584 │ re_lu_12[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 24, 64, 32)     │         51,232 │ re_lu_14[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 24, 64, 32)     │         50,208 │ re_lu_16[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 24, 64, 64)     │            256 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 24, 64, 128)    │            512 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 24, 64, 32)     │            128 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 24, 64, 32)     │            128 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_11 (ReLU)           │ (None, 24, 64, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_13 (ReLU)           │ (None, 24, 64, 128)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_15 (ReLU)           │ (None, 24, 64, 32)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_17 (ReLU)           │ (None, 24, 64, 32)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 24, 64, 256)    │              0 │ re_lu_11[0][0],        │
# │ (Concatenate)             │                        │                │ re_lu_13[0][0],        │
# │                           │                        │                │ re_lu_15[0][0],        │
# │                           │                        │                │ re_lu_17[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 12, 32, 256)    │              0 │ concatenate_1[0][0]    │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_21 (Conv2D)        │ (None, 12, 32, 64)     │         16,448 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_23 (Conv2D)        │ (None, 12, 32, 32)     │          8,224 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_19 (Conv2D)        │ (None, 12, 32, 256)    │         65,792 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 12, 32, 64)     │            256 │ conv2d_21[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_20    │ (None, 12, 32, 32)     │            128 │ conv2d_23[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_19 (ReLU)           │ (None, 12, 32, 256)    │              0 │ conv2d_19[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_21 (ReLU)           │ (None, 12, 32, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_23 (ReLU)           │ (None, 12, 32, 32)     │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 12, 32, 64)     │         16,448 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_20 (Conv2D)        │ (None, 12, 32, 384)    │        885,120 │ re_lu_19[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_22 (Conv2D)        │ (None, 12, 32, 32)     │         51,232 │ re_lu_21[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_24 (Conv2D)        │ (None, 12, 32, 32)     │         50,208 │ re_lu_23[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 12, 32, 64)     │            256 │ conv2d_18[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 12, 32, 384)    │          1,536 │ conv2d_20[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_19    │ (None, 12, 32, 32)     │            128 │ conv2d_22[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_21    │ (None, 12, 32, 32)     │            128 │ conv2d_24[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_18 (ReLU)           │ (None, 12, 32, 64)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_20 (ReLU)           │ (None, 12, 32, 384)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_22 (ReLU)           │ (None, 12, 32, 32)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_24 (ReLU)           │ (None, 12, 32, 32)     │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 12, 32, 512)    │              0 │ re_lu_18[0][0],        │
# │ (Concatenate)             │                        │                │ re_lu_20[0][0],        │
# │                           │                        │                │ re_lu_22[0][0],        │
# │                           │                        │                │ re_lu_24[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_28 (Conv2D)        │ (None, 12, 32, 64)     │         32,832 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_30 (Conv2D)        │ (None, 12, 32, 32)     │         16,416 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_26 (Conv2D)        │ (None, 12, 32, 256)    │        131,328 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_24    │ (None, 12, 32, 64)     │            256 │ conv2d_28[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_26    │ (None, 12, 32, 32)     │            128 │ conv2d_30[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_26 (ReLU)           │ (None, 12, 32, 256)    │              0 │ conv2d_26[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_28 (ReLU)           │ (None, 12, 32, 64)     │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_30 (ReLU)           │ (None, 12, 32, 32)     │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_25 (Conv2D)        │ (None, 12, 32, 64)     │         32,832 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_27 (Conv2D)        │ (None, 12, 32, 384)    │        885,120 │ re_lu_26[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_29 (Conv2D)        │ (None, 12, 32, 32)     │         51,232 │ re_lu_28[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_31 (Conv2D)        │ (None, 12, 32, 32)     │         50,208 │ re_lu_30[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_22    │ (None, 12, 32, 64)     │            256 │ conv2d_25[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_23    │ (None, 12, 32, 384)    │          1,536 │ conv2d_27[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_25    │ (None, 12, 32, 32)     │            128 │ conv2d_29[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_27    │ (None, 12, 32, 32)     │            128 │ conv2d_31[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_25 (ReLU)           │ (None, 12, 32, 64)     │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_27 (ReLU)           │ (None, 12, 32, 384)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_29 (ReLU)           │ (None, 12, 32, 32)     │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_31 (ReLU)           │ (None, 12, 32, 32)     │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_32 (Conv2D)        │ (None, 24, 64, 256)    │         65,792 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 12, 32, 512)    │              0 │ re_lu_25[0][0],        │
# │ (Concatenate)             │                        │                │ re_lu_27[0][0],        │
# │                           │                        │                │ re_lu_29[0][0],        │
# │                           │                        │                │ re_lu_31[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_33 (Conv2D)        │ (None, 24, 64, 256)    │        590,080 │ conv2d_32[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 24, 64, 256)    │      1,179,904 │ concatenate_3[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 24, 64, 256)    │              0 │ conv2d_33[0][0],       │
# │                           │                        │                │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 24, 64, 512)    │              0 │ conv2d_transpose[0][0… │
# │ (Concatenate)             │                        │                │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_37 (Conv2D)        │ (None, 24, 64, 64)     │         32,832 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_39 (Conv2D)        │ (None, 24, 64, 32)     │         16,416 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_35 (Conv2D)        │ (None, 24, 64, 128)    │         65,664 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_30    │ (None, 24, 64, 64)     │            256 │ conv2d_37[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_32    │ (None, 24, 64, 32)     │            128 │ conv2d_39[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_33 (ReLU)           │ (None, 24, 64, 128)    │              0 │ conv2d_35[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_35 (ReLU)           │ (None, 24, 64, 64)     │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_37 (ReLU)           │ (None, 24, 64, 32)     │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_34 (Conv2D)        │ (None, 24, 64, 64)     │         32,832 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_36 (Conv2D)        │ (None, 24, 64, 128)    │        147,584 │ re_lu_33[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_38 (Conv2D)        │ (None, 24, 64, 32)     │         51,232 │ re_lu_35[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_40 (Conv2D)        │ (None, 24, 64, 32)     │         50,208 │ re_lu_37[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_28    │ (None, 24, 64, 64)     │            256 │ conv2d_34[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_29    │ (None, 24, 64, 128)    │            512 │ conv2d_36[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_31    │ (None, 24, 64, 32)     │            128 │ conv2d_38[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_33    │ (None, 24, 64, 32)     │            128 │ conv2d_40[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_32 (ReLU)           │ (None, 24, 64, 64)     │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_34 (ReLU)           │ (None, 24, 64, 128)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_36 (ReLU)           │ (None, 24, 64, 32)     │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_38 (ReLU)           │ (None, 24, 64, 32)     │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_5             │ (None, 24, 64, 256)    │              0 │ re_lu_32[0][0],        │
# │ (Concatenate)             │                        │                │ re_lu_34[0][0],        │
# │                           │                        │                │ re_lu_36[0][0],        │
# │                           │                        │                │ re_lu_38[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_44 (Conv2D)        │ (None, 24, 64, 64)     │         16,448 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_46 (Conv2D)        │ (None, 24, 64, 32)     │          8,224 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_42 (Conv2D)        │ (None, 24, 64, 128)    │         32,896 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_36    │ (None, 24, 64, 64)     │            256 │ conv2d_44[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_38    │ (None, 24, 64, 32)     │            128 │ conv2d_46[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_40 (ReLU)           │ (None, 24, 64, 128)    │              0 │ conv2d_42[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_42 (ReLU)           │ (None, 24, 64, 64)     │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_44 (ReLU)           │ (None, 24, 64, 32)     │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_41 (Conv2D)        │ (None, 24, 64, 64)     │         16,448 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_43 (Conv2D)        │ (None, 24, 64, 128)    │        147,584 │ re_lu_40[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_45 (Conv2D)        │ (None, 24, 64, 32)     │         51,232 │ re_lu_42[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_47 (Conv2D)        │ (None, 24, 64, 32)     │         50,208 │ re_lu_44[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_34    │ (None, 24, 64, 64)     │            256 │ conv2d_41[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_35    │ (None, 24, 64, 128)    │            512 │ conv2d_43[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_37    │ (None, 24, 64, 32)     │            128 │ conv2d_45[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_39    │ (None, 24, 64, 32)     │            128 │ conv2d_47[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_39 (ReLU)           │ (None, 24, 64, 64)     │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_41 (ReLU)           │ (None, 24, 64, 128)    │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_43 (ReLU)           │ (None, 24, 64, 32)     │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_45 (ReLU)           │ (None, 24, 64, 32)     │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_48 (Conv2D)        │ (None, 48, 128, 128)   │         16,512 │ re_lu_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_6             │ (None, 24, 64, 256)    │              0 │ re_lu_39[0][0],        │
# │ (Concatenate)             │                        │                │ re_lu_41[0][0],        │
# │                           │                        │                │ re_lu_43[0][0],        │
# │                           │                        │                │ re_lu_45[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_49 (Conv2D)        │ (None, 48, 128, 128)   │        147,584 │ conv2d_48[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 48, 128, 128)   │        295,040 │ concatenate_6[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 48, 128, 128)   │              0 │ conv2d_49[0][0],       │
# │                           │                        │                │ re_lu_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_7             │ (None, 48, 128, 256)   │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_50 (Conv2D)        │ (None, 48, 128, 128)   │        295,040 │ concatenate_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_40    │ (None, 48, 128, 128)   │            512 │ conv2d_50[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_46 (ReLU)           │ (None, 48, 128, 128)   │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_51 (Conv2D)        │ (None, 48, 128, 128)   │        147,584 │ re_lu_46[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_41    │ (None, 48, 128, 128)   │            512 │ conv2d_51[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_52 (Conv2D)        │ (None, 96, 256, 64)    │          4,160 │ re_lu_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_47 (ReLU)           │ (None, 48, 128, 128)   │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_53 (Conv2D)        │ (None, 96, 256, 64)    │         36,928 │ conv2d_52[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 96, 256, 64)    │         73,792 │ re_lu_47[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 96, 256, 64)    │              0 │ conv2d_53[0][0],       │
# │                           │                        │                │ re_lu_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_8             │ (None, 96, 256, 128)   │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_54 (Conv2D)        │ (None, 96, 256, 128)   │        147,584 │ concatenate_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_42    │ (None, 96, 256, 128)   │            512 │ conv2d_54[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_48 (ReLU)           │ (None, 96, 256, 128)   │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ cropping2d (Cropping2D)   │ (None, 90, 250, 128)   │              0 │ re_lu_48[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_55 (Conv2D)        │ (None, 90, 250, 1)     │            129 │ cropping2d[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 6,902,657 (26.33 MB)
#  Trainable params: 6,895,873 (26.31 MB)
#  Non-trainable params: 6,784 (26.50 KB)

# %% [markdown]
# ## Train

# %% [markdown]
# ## Metric Regression

# %%
from tensorflow.keras import backend as K

@tf.keras.utils.register_keras_serializable()
def create_non_negative_mask(y_true):
    return K.cast(K.greater_equal(y_true, 0), K.floatx())  # Mask where y_true >= 0


@tf.keras.utils.register_keras_serializable()    
def CC(y_true, y_pred):
    mask = create_non_negative_mask(y_true)
    y_true_masked = y_true * mask
    y_pred_masked = y_pred * mask
    return K.mean((y_true_masked - K.mean(y_true_masked)) * 
                  (y_pred_masked - K.mean(y_pred_masked)) / 
                  (K.std(y_true_masked) * K.std(y_pred_masked) + K.epsilon()))
    
@tf.keras.utils.register_keras_serializable()
def R2(y_true, y_pred):
    mask = create_non_negative_mask(y_true)
    y_true_masked = y_true * mask
    y_pred_masked = y_pred * mask
    ss_total = K.sum(K.square(y_true_masked - K.mean(y_true_masked)))
    ss_residual = K.sum(K.square(y_true_masked - y_pred_masked))
    return 1 - (ss_residual / (ss_total + K.epsilon()))
    
@tf.keras.utils.register_keras_serializable()
def custom_mse_loss(y_true, y_pred):
    mask = create_non_negative_mask(y_true)
    y_true_masked = y_true * mask
    y_pred_masked = y_pred * mask
    squared_error = K.square(y_true_masked - y_pred_masked)
    return K.sum(squared_error) / (K.sum(mask) + K.epsilon())

@tf.keras.utils.register_keras_serializable()
def RMSE(y_true, y_pred):
    mask = create_non_negative_mask(y_true)
    y_true_masked = y_true * mask
    y_pred_masked = y_pred * mask
    squared_error = K.square(y_true_masked - y_pred_masked)
    mse = K.sum(squared_error) / (K.sum(mask) + K.epsilon())
    return K.sqrt(mse)

@tf.keras.utils.register_keras_serializable()
def weighted_sigmoid_mse(y_true, y_pred):
    scaling_factor=1
    threshold=0.1
    mask = create_non_negative_mask(y_true)
    y_norm = y_true / 260.0  # max y_train = 260
    weights = K.sigmoid(scaling_factor * (y_norm - threshold))  # Compute the weights using sigmoid
    weights_masked = weights * mask  
    y_true_masked = y_true * mask 
    y_pred_masked = y_pred * mask  
    squared_error = K.square(y_true_masked - y_pred_masked)  
    weighted_error = weights_masked * squared_error  # Apply weights
    return K.sum(weighted_error) / (K.sum(weights_masked) + K.epsilon())  # Normalize

# %% [markdown]
# ## Metric classification

# %%
@tf.keras.utils.register_keras_serializable()
def create_missing_data_mask(y):
    return K.cast(K.less(y, 0), K.floatx()) # Mask where y == -1 (missing data)

# Mask for classifying values greater than or equal to 0.5
@tf.keras.utils.register_keras_serializable()
def create_class_mask(y):
    return K.cast(K.greater_equal(y, 0.5), K.floatx())

@tf.keras.utils.register_keras_serializable()
def FAR(y_true, y_pred):
    missing_mask = create_missing_data_mask(y_true)  # 1 where missing
    valid_mask = 1.0 - missing_mask  # 1 where valid

    y_true_class = create_class_mask(y_true)
    y_pred_class = create_class_mask(y_pred)

    # Only consider positions where valid_mask == 1
    FP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 0), K.floatx()) * valid_mask)
    TP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 1), K.floatx()) * valid_mask)

    far = FP / (TP + FP + K.epsilon())
    return far

@tf.keras.utils.register_keras_serializable()
def POD(y_true, y_pred):
    # Mask for missing data and valid values
    missing_mask = create_missing_data_mask(y_true)
    valid_mask = 1.0 - missing_mask

    # Convert to binary class masks
    y_true_class = create_class_mask(y_true)
    y_pred_class = create_class_mask(y_pred)


    TP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 1), K.floatx()) * valid_mask)
    FN = K.sum(K.cast((y_pred_class == 0) & (y_true_class == 1), K.floatx()) * valid_mask)

    pod = TP / (TP + FN + K.epsilon())
    return pod

@tf.keras.utils.register_keras_serializable()
def CSI(y_true, y_pred):
    # Create the missing data mask
    missing_mask = create_missing_data_mask(y_true)
    valid_mask = 1.0 - missing_mask

    # Convert to binary class masks
    y_true_class = create_class_mask(y_true)
    y_pred_class = create_class_mask(y_pred)

    # TP, FP, FN (only on valid data)
    TP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 1), K.floatx()) * valid_mask)
    FP = K.sum(K.cast((y_pred_class == 1) & (y_true_class == 0), K.floatx()) * valid_mask)
    FN = K.sum(K.cast((y_pred_class == 0) & (y_true_class == 1), K.floatx()) * valid_mask)

    csi = TP / (TP + FP + FN + K.epsilon())
    return csi

# %% [markdown]
# ## Train .fit

# %%
optimizer = Adam(learning_rate=0.001)

# Callbacks
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True, mode='min', verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)

# Compile Model
model.compile(optimizer=optimizer, 
              loss=weighted_sigmoid_mse, 
              metrics=[RMSE, CC, R2, POD, FAR, CSI])

# Train Model
history = model.fit(X_train_scaled, y_train,
                    batch_size=32,
                    epochs=80,
                    verbose=1,
                    validation_data=(X_val_scaled, y_val),
                    callbacks=[checkpoint, reduce_lr, early_stopping])
# Out:
# Epoch 1/80
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746258812.122800      66 service.cc:148] XLA service 0x7c9614003ab0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746258812.123663      66 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1746258816.148967      66 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1746258854.263636      66 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 48/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.2069 - csi: 0.1688 - far: 0.7535 - loss: 6.1971 - pod: 0.4140 - r2: 0.0318 - rmse: 1.9853
# E0000 00:00:1746258878.732357      65 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746258878.996610      65 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - cc: 0.2085 - csi: 0.1697 - far: 0.7523 - loss: 6.1635 - pod: 0.4152 - r2: 0.0324 - rmse: 1.9800
# E0000 00:00:1746258920.578409      64 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1746258920.838506      64 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_loss improved from inf to 2.41911, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - cc: 0.2100 - csi: 0.1707 - far: 0.7512 - loss: 6.1311 - pod: 0.4162 - r2: 0.0331 - rmse: 1.9749 - val_cc: 0.1045 - val_csi: 3.7277e-04 - val_far: 0.0909 - val_loss: 2.4191 - val_pod: 3.7277e-04 - val_r2: -0.0089 - val_rmse: 1.4209 - learning_rate: 0.0010
# Epoch 2/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.3493 - csi: 0.2584 - far: 0.6756 - loss: 3.9877 - pod: 0.5710 - r2: 0.1190 - rmse: 1.5620
# Epoch 2: val_loss improved from 2.41911 to 2.39717, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 397ms/step - cc: 0.3493 - csi: 0.2583 - far: 0.6755 - loss: 3.9967 - pod: 0.5706 - r2: 0.1190 - rmse: 1.5630 - val_cc: 0.2604 - val_csi: 0.0130 - val_far: 0.1394 - val_loss: 2.3972 - val_pod: 0.0130 - val_r2: 0.0014 - val_rmse: 1.4138 - learning_rate: 0.0010
# Epoch 3/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.3511 - csi: 0.2718 - far: 0.6484 - loss: 4.3373 - pod: 0.5643 - r2: 0.1100 - rmse: 1.6359
# Epoch 3: val_loss did not improve from 2.39717
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.3511 - csi: 0.2715 - far: 0.6488 - loss: 4.3390 - pod: 0.5643 - r2: 0.1101 - rmse: 1.6364 - val_cc: 0.1853 - val_csi: 0.0138 - val_far: 0.1913 - val_loss: 2.4039 - val_pod: 0.0140 - val_r2: -0.0022 - val_rmse: 1.4162 - learning_rate: 0.0010
# Epoch 4/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.3342 - csi: 0.2599 - far: 0.6363 - loss: 3.4885 - pod: 0.5160 - r2: 0.0918 - rmse: 1.5877
# Epoch 4: val_loss improved from 2.39717 to 2.33041, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 396ms/step - cc: 0.3337 - csi: 0.2596 - far: 0.6369 - loss: 3.5090 - pod: 0.5160 - r2: 0.0915 - rmse: 1.5897 - val_cc: 0.1773 - val_csi: 0.1115 - val_far: 0.8614 - val_loss: 2.3304 - val_pod: 0.3650 - val_r2: 0.0273 - val_rmse: 1.3943 - learning_rate: 0.0010
# Epoch 5/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.3446 - csi: 0.2568 - far: 0.6450 - loss: 5.2470 - pod: 0.5298 - r2: 0.0978 - rmse: 1.7671
# Epoch 5: val_loss did not improve from 2.33041
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 377ms/step - cc: 0.3444 - csi: 0.2567 - far: 0.6451 - loss: 5.2310 - pod: 0.5294 - r2: 0.0978 - rmse: 1.7646 - val_cc: 0.2739 - val_csi: 0.1180 - val_far: 0.2896 - val_loss: 2.3526 - val_pod: 0.1242 - val_r2: 0.0254 - val_rmse: 1.3981 - learning_rate: 0.0010
# Epoch 6/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.3568 - csi: 0.2679 - far: 0.6413 - loss: 3.0351 - pod: 0.5361 - r2: 0.1099 - rmse: 1.4892
# Epoch 6: val_loss improved from 2.33041 to 2.25124, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 398ms/step - cc: 0.3565 - csi: 0.2677 - far: 0.6419 - loss: 3.0627 - pod: 0.5364 - r2: 0.1099 - rmse: 1.4926 - val_cc: 0.3322 - val_csi: 0.2374 - val_far: 0.4469 - val_loss: 2.2512 - val_pod: 0.2962 - val_r2: 0.0731 - val_rmse: 1.3641 - learning_rate: 0.0010
# Epoch 7/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - cc: 0.3550 - csi: 0.2583 - far: 0.6635 - loss: 4.2972 - pod: 0.5531 - r2: 0.1084 - rmse: 1.6294
# Epoch 7: val_loss improved from 2.25124 to 2.22957, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - cc: 0.3551 - csi: 0.2583 - far: 0.6632 - loss: 4.2997 - pod: 0.5527 - r2: 0.1085 - rmse: 1.6293 - val_cc: 0.2851 - val_csi: 0.1199 - val_far: 0.8636 - val_loss: 2.2296 - val_pod: 0.5016 - val_r2: 0.0731 - val_rmse: 1.3604 - learning_rate: 0.0010
# Epoch 8/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.3621 - csi: 0.2671 - far: 0.6535 - loss: 4.5507 - pod: 0.5382 - r2: 0.1225 - rmse: 1.6534
# Epoch 8: val_loss improved from 2.22957 to 2.16321, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 397ms/step - cc: 0.3620 - csi: 0.2671 - far: 0.6536 - loss: 4.5475 - pod: 0.5384 - r2: 0.1224 - rmse: 1.6534 - val_cc: 0.3511 - val_csi: 0.2317 - val_far: 0.7282 - val_loss: 2.1632 - val_pod: 0.6112 - val_r2: 0.0918 - val_rmse: 1.3419 - learning_rate: 0.0010
# Epoch 9/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.3936 - csi: 0.2695 - far: 0.6608 - loss: 3.4376 - pod: 0.5884 - r2: 0.1455 - rmse: 1.5287
# Epoch 9: val_loss improved from 2.16321 to 2.16048, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 397ms/step - cc: 0.3932 - csi: 0.2693 - far: 0.6611 - loss: 3.4565 - pod: 0.5883 - r2: 0.1452 - rmse: 1.5309 - val_cc: 0.3378 - val_csi: 0.1948 - val_far: 0.7696 - val_loss: 2.1605 - val_pod: 0.5573 - val_r2: 0.1052 - val_rmse: 1.3369 - learning_rate: 0.0010
# Epoch 10/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.3591 - csi: 0.2598 - far: 0.5929 - loss: 3.9122 - pod: 0.4877 - r2: 0.1104 - rmse: 1.5702
# Epoch 10: val_loss did not improve from 2.16048
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.3593 - csi: 0.2599 - far: 0.5936 - loss: 3.9220 - pod: 0.4886 - r2: 0.1106 - rmse: 1.5714 - val_cc: 0.3033 - val_csi: 0.2379 - val_far: 0.6138 - val_loss: 2.1921 - val_pod: 0.3796 - val_r2: 0.0753 - val_rmse: 1.3547 - learning_rate: 0.0010
# Epoch 11/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.3576 - csi: 0.2602 - far: 0.6757 - loss: 6.0855 - pod: 0.5942 - r2: 0.1108 - rmse: 1.8748
# Epoch 11: val_loss improved from 2.16048 to 2.12086, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 396ms/step - cc: 0.3579 - csi: 0.2603 - far: 0.6754 - loss: 6.0513 - pod: 0.5938 - r2: 0.1112 - rmse: 1.8704 - val_cc: 0.3674 - val_csi: 0.2473 - val_far: 0.6968 - val_loss: 2.1209 - val_pod: 0.5740 - val_r2: 0.1128 - val_rmse: 1.3276 - learning_rate: 0.0010
# Epoch 12/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.3802 - csi: 0.2778 - far: 0.6441 - loss: 4.4756 - pod: 0.5714 - r2: 0.1453 - rmse: 1.6880
# Epoch 12: val_loss did not improve from 2.12086
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.3800 - csi: 0.2776 - far: 0.6445 - loss: 4.4735 - pod: 0.5712 - r2: 0.1450 - rmse: 1.6871 - val_cc: 0.1904 - val_csi: 0.1505 - val_far: 0.5672 - val_loss: 2.3481 - val_pod: 0.1903 - val_r2: 0.0322 - val_rmse: 1.3943 - learning_rate: 0.0010
# Epoch 13/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.3621 - csi: 0.2617 - far: 0.6728 - loss: 5.2618 - pod: 0.5812 - r2: 0.1263 - rmse: 1.7563
# Epoch 13: val_loss did not improve from 2.12086
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - cc: 0.3622 - csi: 0.2618 - far: 0.6725 - loss: 5.2445 - pod: 0.5808 - r2: 0.1263 - rmse: 1.7540 - val_cc: 0.1849 - val_csi: 0.1512 - val_far: 0.8213 - val_loss: 2.8089 - val_pod: 0.4947 - val_r2: -0.2627 - val_rmse: 1.5632 - learning_rate: 0.0010
# Epoch 14/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.3855 - csi: 0.2647 - far: 0.6780 - loss: 3.5444 - pod: 0.6075 - r2: 0.1454 - rmse: 1.4770
# Epoch 14: val_loss did not improve from 2.12086
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.3856 - csi: 0.2648 - far: 0.6776 - loss: 3.5606 - pod: 0.6071 - r2: 0.1456 - rmse: 1.4800 - val_cc: 0.3644 - val_csi: 0.2474 - val_far: 0.6873 - val_loss: 2.1225 - val_pod: 0.5415 - val_r2: 0.1048 - val_rmse: 1.3299 - learning_rate: 0.0010
# Epoch 15/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.3962 - csi: 0.2665 - far: 0.6703 - loss: 3.2439 - pod: 0.5870 - r2: 0.1460 - rmse: 1.4834
# Epoch 15: val_loss improved from 2.12086 to 2.11283, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 399ms/step - cc: 0.3961 - csi: 0.2666 - far: 0.6703 - loss: 3.2660 - pod: 0.5871 - r2: 0.1459 - rmse: 1.4867 - val_cc: 0.3695 - val_csi: 0.2848 - val_far: 0.6089 - val_loss: 2.1128 - val_pod: 0.5116 - val_r2: 0.1174 - val_rmse: 1.3239 - learning_rate: 0.0010
# Epoch 16/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.3809 - csi: 0.2688 - far: 0.6472 - loss: 5.3646 - pod: 0.5684 - r2: 0.1471 - rmse: 1.7579
# Epoch 16: val_loss did not improve from 2.11283
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.3810 - csi: 0.2687 - far: 0.6473 - loss: 5.3442 - pod: 0.5682 - r2: 0.1469 - rmse: 1.7556 - val_cc: 0.2192 - val_csi: 0.1312 - val_far: 0.4069 - val_loss: 2.3516 - val_pod: 0.1460 - val_r2: 0.0250 - val_rmse: 1.3983 - learning_rate: 0.0010
# Epoch 17/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.3588 - csi: 0.2719 - far: 0.6628 - loss: 3.7934 - pod: 0.6001 - r2: 0.1073 - rmse: 1.5904
# Epoch 17: val_loss did not improve from 2.11283
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.3590 - csi: 0.2719 - far: 0.6626 - loss: 3.8046 - pod: 0.5996 - r2: 0.1076 - rmse: 1.5913 - val_cc: 0.3654 - val_csi: 0.2334 - val_far: 0.7240 - val_loss: 2.1579 - val_pod: 0.6002 - val_r2: 0.0762 - val_rmse: 1.3477 - learning_rate: 0.0010
# Epoch 18/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.3852 - csi: 0.2717 - far: 0.6709 - loss: 3.9921 - pod: 0.6274 - r2: 0.1263 - rmse: 1.6244
# Epoch 18: val_loss did not improve from 2.11283
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.3852 - csi: 0.2716 - far: 0.6709 - loss: 3.9988 - pod: 0.6267 - r2: 0.1263 - rmse: 1.6249 - val_cc: 0.2463 - val_csi: 0.1420 - val_far: 0.8147 - val_loss: 2.2720 - val_pod: 0.3926 - val_r2: 0.0487 - val_rmse: 1.3768 - learning_rate: 0.0010
# Epoch 19/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.3913 - csi: 0.2785 - far: 0.6327 - loss: 4.0124 - pod: 0.5591 - r2: 0.1534 - rmse: 1.6046
# Epoch 19: val_loss did not improve from 2.11283
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - cc: 0.3913 - csi: 0.2783 - far: 0.6333 - loss: 4.0183 - pod: 0.5595 - r2: 0.1533 - rmse: 1.6057 - val_cc: 0.3218 - val_csi: 0.2105 - val_far: 0.5149 - val_loss: 2.1897 - val_pod: 0.2726 - val_r2: 0.0862 - val_rmse: 1.3487 - learning_rate: 0.0010
# Epoch 20/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - cc: 0.3822 - csi: 0.2615 - far: 0.6652 - loss: 4.9265 - pod: 0.5507 - r2: 0.1492 - rmse: 1.7154
# Epoch 20: val_loss did not improve from 2.11283
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - cc: 0.3827 - csi: 0.2615 - far: 0.6653 - loss: 4.9136 - pod: 0.5512 - r2: 0.1492 - rmse: 1.7129 - val_cc: 0.1005 - val_csi: 0.0481 - val_far: 0.9488 - val_loss: 5.3008 - val_pod: 0.4542 - val_r2: -1.8750 - val_rmse: 2.2241 - learning_rate: 0.0010
# Epoch 21/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4007 - csi: 0.2852 - far: 0.6371 - loss: 4.1122 - pod: 0.5732 - r2: 0.1574 - rmse: 1.7063
# Epoch 21: val_loss did not improve from 2.11283
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4008 - csi: 0.2851 - far: 0.6374 - loss: 4.1151 - pod: 0.5732 - r2: 0.1574 - rmse: 1.7046 - val_cc: 0.2196 - val_csi: 0.1322 - val_far: 0.8090 - val_loss: 2.4032 - val_pod: 0.3113 - val_r2: -0.0423 - val_rmse: 1.4283 - learning_rate: 5.0000e-04
# Epoch 22/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4184 - csi: 0.2844 - far: 0.6365 - loss: 3.8207 - pod: 0.5781 - r2: 0.1746 - rmse: 1.6024
# Epoch 22: val_loss did not improve from 2.11283
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - cc: 0.4182 - csi: 0.2843 - far: 0.6368 - loss: 3.8288 - pod: 0.5784 - r2: 0.1744 - rmse: 1.6031 - val_cc: 0.3368 - val_csi: 0.2132 - val_far: 0.6820 - val_loss: 2.1489 - val_pod: 0.3907 - val_r2: 0.0918 - val_rmse: 1.3416 - learning_rate: 5.0000e-04
# Epoch 23/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4260 - csi: 0.2807 - far: 0.6467 - loss: 4.5161 - pod: 0.5786 - r2: 0.1704 - rmse: 1.6941
# Epoch 23: val_loss did not improve from 2.11283
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - cc: 0.4254 - csi: 0.2805 - far: 0.6469 - loss: 4.5104 - pod: 0.5785 - r2: 0.1700 - rmse: 1.6924 - val_cc: 0.3591 - val_csi: 0.2411 - val_far: 0.5331 - val_loss: 2.1294 - val_pod: 0.3313 - val_r2: 0.1117 - val_rmse: 1.3305 - learning_rate: 5.0000e-04
# Epoch 24/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4692 - csi: 0.3065 - far: 0.6171 - loss: 4.0975 - pod: 0.6100 - r2: 0.1954 - rmse: 1.5993
# Epoch 24: val_loss improved from 2.11283 to 2.11042, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - cc: 0.4682 - csi: 0.3060 - far: 0.6177 - loss: 4.0988 - pod: 0.6096 - r2: 0.1945 - rmse: 1.5990 - val_cc: 0.3528 - val_csi: 0.1866 - val_far: 0.7571 - val_loss: 2.1104 - val_pod: 0.4601 - val_r2: 0.1113 - val_rmse: 1.3270 - learning_rate: 5.0000e-04
# Epoch 25/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4461 - csi: 0.2739 - far: 0.6571 - loss: 3.2684 - pod: 0.5969 - r2: 0.1822 - rmse: 1.4655
# Epoch 25: val_loss improved from 2.11042 to 2.09778, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 397ms/step - cc: 0.4457 - csi: 0.2739 - far: 0.6571 - loss: 3.2866 - pod: 0.5970 - r2: 0.1818 - rmse: 1.4685 - val_cc: 0.3671 - val_csi: 0.2044 - val_far: 0.6761 - val_loss: 2.0978 - val_pod: 0.3591 - val_r2: 0.1255 - val_rmse: 1.3194 - learning_rate: 5.0000e-04
# Epoch 26/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4615 - csi: 0.2948 - far: 0.6300 - loss: 3.3375 - pod: 0.5978 - r2: 0.1890 - rmse: 1.4513
# Epoch 26: val_loss improved from 2.09778 to 2.06696, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 398ms/step - cc: 0.4608 - csi: 0.2945 - far: 0.6302 - loss: 3.3542 - pod: 0.5976 - r2: 0.1880 - rmse: 1.4544 - val_cc: 0.3803 - val_csi: 0.2559 - val_far: 0.6125 - val_loss: 2.0670 - val_pod: 0.4304 - val_r2: 0.1357 - val_rmse: 1.3105 - learning_rate: 5.0000e-04
# Epoch 27/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.4366 - csi: 0.2665 - far: 0.6749 - loss: 3.8651 - pod: 0.6116 - r2: 0.1714 - rmse: 1.5485
# Epoch 27: val_loss did not improve from 2.06696
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4365 - csi: 0.2667 - far: 0.6746 - loss: 3.8706 - pod: 0.6115 - r2: 0.1714 - rmse: 1.5495 - val_cc: 0.3361 - val_csi: 0.2382 - val_far: 0.6374 - val_loss: 2.1598 - val_pod: 0.4116 - val_r2: 0.0989 - val_rmse: 1.3398 - learning_rate: 5.0000e-04
# Epoch 28/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4282 - csi: 0.2851 - far: 0.6339 - loss: 3.9951 - pod: 0.5808 - r2: 0.1658 - rmse: 1.6370
# Epoch 28: val_loss did not improve from 2.06696
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4279 - csi: 0.2850 - far: 0.6340 - loss: 3.9991 - pod: 0.5807 - r2: 0.1655 - rmse: 1.6368 - val_cc: 0.3026 - val_csi: 0.1849 - val_far: 0.6928 - val_loss: 2.2035 - val_pod: 0.3238 - val_r2: 0.0772 - val_rmse: 1.3550 - learning_rate: 5.0000e-04
# Epoch 29/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - cc: 0.4428 - csi: 0.2829 - far: 0.6536 - loss: 4.3177 - pod: 0.6102 - r2: 0.1712 - rmse: 1.6319
# Epoch 29: val_loss did not improve from 2.06696
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4429 - csi: 0.2828 - far: 0.6536 - loss: 4.3140 - pod: 0.6100 - r2: 0.1712 - rmse: 1.6309 - val_cc: 0.3737 - val_csi: 0.2687 - val_far: 0.5489 - val_loss: 2.1155 - val_pod: 0.4003 - val_r2: 0.1287 - val_rmse: 1.3196 - learning_rate: 5.0000e-04
# Epoch 30/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.4377 - csi: 0.2912 - far: 0.6373 - loss: 3.0405 - pod: 0.6018 - r2: 0.1856 - rmse: 1.4249
# Epoch 30: val_loss did not improve from 2.06696
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 377ms/step - cc: 0.4373 - csi: 0.2912 - far: 0.6373 - loss: 3.0629 - pod: 0.6017 - r2: 0.1853 - rmse: 1.4284 - val_cc: 0.3777 - val_csi: 0.2518 - val_far: 0.6423 - val_loss: 2.1172 - val_pod: 0.4637 - val_r2: 0.1256 - val_rmse: 1.3207 - learning_rate: 5.0000e-04
# Epoch 31/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.4501 - csi: 0.2856 - far: 0.6485 - loss: 3.5784 - pod: 0.6080 - r2: 0.1949 - rmse: 1.4719
# Epoch 31: val_loss did not improve from 2.06696
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4499 - csi: 0.2856 - far: 0.6484 - loss: 3.5897 - pod: 0.6082 - r2: 0.1948 - rmse: 1.4744 - val_cc: 0.3745 - val_csi: 0.2843 - val_far: 0.5899 - val_loss: 2.0943 - val_pod: 0.4854 - val_r2: 0.1124 - val_rmse: 1.3226 - learning_rate: 5.0000e-04
# Epoch 32/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4382 - csi: 0.2811 - far: 0.6539 - loss: 3.7462 - pod: 0.5946 - r2: 0.1668 - rmse: 1.4781
# Epoch 32: val_loss did not improve from 2.06696
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - cc: 0.4382 - csi: 0.2812 - far: 0.6536 - loss: 3.7532 - pod: 0.5945 - r2: 0.1666 - rmse: 1.4802 - val_cc: 0.3773 - val_csi: 0.2622 - val_far: 0.5710 - val_loss: 2.0942 - val_pod: 0.4040 - val_r2: 0.1299 - val_rmse: 1.3171 - learning_rate: 2.5000e-04
# Epoch 33/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4407 - csi: 0.2893 - far: 0.6428 - loss: 3.1493 - pod: 0.6162 - r2: 0.1876 - rmse: 1.4905
# Epoch 33: val_loss improved from 2.06696 to 1.98213, saving model to best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - cc: 0.4409 - csi: 0.2891 - far: 0.6431 - loss: 3.1673 - pod: 0.6161 - r2: 0.1878 - rmse: 1.4926 - val_cc: 0.4220 - val_csi: 0.2786 - val_far: 0.6405 - val_loss: 1.9821 - val_pod: 0.5546 - val_r2: 0.1608 - val_rmse: 1.2855 - learning_rate: 2.5000e-04
# Epoch 34/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4467 - csi: 0.2931 - far: 0.6500 - loss: 5.1024 - pod: 0.6417 - r2: 0.2079 - rmse: 1.7465
# Epoch 34: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4473 - csi: 0.2931 - far: 0.6500 - loss: 5.0805 - pod: 0.6413 - r2: 0.2081 - rmse: 1.7430 - val_cc: 0.4162 - val_csi: 0.2699 - val_far: 0.6722 - val_loss: 2.0670 - val_pod: 0.6060 - val_r2: 0.1212 - val_rmse: 1.3126 - learning_rate: 2.5000e-04
# Epoch 35/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.4349 - csi: 0.2796 - far: 0.6580 - loss: 4.6100 - pod: 0.6079 - r2: 0.1417 - rmse: 1.6580
# Epoch 35: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 377ms/step - cc: 0.4354 - csi: 0.2797 - far: 0.6579 - loss: 4.5976 - pod: 0.6081 - r2: 0.1428 - rmse: 1.6566 - val_cc: 0.4149 - val_csi: 0.2607 - val_far: 0.6864 - val_loss: 2.0491 - val_pod: 0.6107 - val_r2: 0.1302 - val_rmse: 1.3069 - learning_rate: 2.5000e-04
# Epoch 36/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - cc: 0.4808 - csi: 0.3029 - far: 0.6336 - loss: 4.2937 - pod: 0.6407 - r2: 0.2166 - rmse: 1.6326
# Epoch 36: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - cc: 0.4807 - csi: 0.3028 - far: 0.6336 - loss: 4.2880 - pod: 0.6402 - r2: 0.2165 - rmse: 1.6312 - val_cc: 0.4264 - val_csi: 0.2817 - val_far: 0.6481 - val_loss: 1.9874 - val_pod: 0.5861 - val_r2: 0.1676 - val_rmse: 1.2837 - learning_rate: 2.5000e-04
# Epoch 37/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4679 - csi: 0.3047 - far: 0.6355 - loss: 4.9574 - pod: 0.6536 - r2: 0.2089 - rmse: 1.7186
# Epoch 37: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4677 - csi: 0.3044 - far: 0.6358 - loss: 4.9371 - pod: 0.6530 - r2: 0.2087 - rmse: 1.7153 - val_cc: 0.4131 - val_csi: 0.2806 - val_far: 0.6506 - val_loss: 2.0668 - val_pod: 0.5879 - val_r2: 0.1014 - val_rmse: 1.3176 - learning_rate: 2.5000e-04
# Epoch 38/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4806 - csi: 0.3109 - far: 0.6049 - loss: 3.0902 - pod: 0.6024 - r2: 0.2013 - rmse: 1.4311
# Epoch 38: val_loss did not improve from 1.98213
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4803 - csi: 0.3107 - far: 0.6053 - loss: 3.1086 - pod: 0.6026 - r2: 0.2011 - rmse: 1.4336 - val_cc: 0.4202 - val_csi: 0.2562 - val_far: 0.7062 - val_loss: 2.0862 - val_pod: 0.6658 - val_r2: 0.0780 - val_rmse: 1.3293 - learning_rate: 2.5000e-04
# Epoch 39/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4764 - csi: 0.2937 - far: 0.6371 - loss: 3.3886 - pod: 0.6057 - r2: 0.2101 - rmse: 1.4725
# Epoch 39: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - cc: 0.4761 - csi: 0.2939 - far: 0.6369 - loss: 3.3994 - pod: 0.6058 - r2: 0.2099 - rmse: 1.4740 - val_cc: 0.4261 - val_csi: 0.2813 - val_far: 0.6551 - val_loss: 1.9957 - val_pod: 0.6038 - val_r2: 0.1484 - val_rmse: 1.2914 - learning_rate: 1.2500e-04
# Epoch 40/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4645 - csi: 0.2765 - far: 0.6679 - loss: 3.1418 - pod: 0.6204 - r2: 0.2092 - rmse: 1.4301
# Epoch 40: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4646 - csi: 0.2767 - far: 0.6676 - loss: 3.1559 - pod: 0.6204 - r2: 0.2094 - rmse: 1.4323 - val_cc: 0.4253 - val_csi: 0.2699 - val_far: 0.6852 - val_loss: 2.1116 - val_pod: 0.6544 - val_r2: 0.0736 - val_rmse: 1.3363 - learning_rate: 1.2500e-04
# Epoch 41/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4847 - csi: 0.2868 - far: 0.6459 - loss: 3.6208 - pod: 0.6036 - r2: 0.1735 - rmse: 1.4941
# Epoch 41: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - cc: 0.4845 - csi: 0.2870 - far: 0.6458 - loss: 3.6263 - pod: 0.6038 - r2: 0.1738 - rmse: 1.4954 - val_cc: 0.4266 - val_csi: 0.2700 - val_far: 0.6815 - val_loss: 2.0345 - val_pod: 0.6396 - val_r2: 0.1198 - val_rmse: 1.3069 - learning_rate: 1.2500e-04
# Epoch 42/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.4526 - csi: 0.2874 - far: 0.6508 - loss: 3.0261 - pod: 0.6199 - r2: 0.1803 - rmse: 1.4480
# Epoch 42: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4529 - csi: 0.2876 - far: 0.6505 - loss: 3.0445 - pod: 0.6198 - r2: 0.1805 - rmse: 1.4503 - val_cc: 0.4337 - val_csi: 0.2554 - val_far: 0.7084 - val_loss: 2.0405 - val_pod: 0.6730 - val_r2: 0.1180 - val_rmse: 1.3105 - learning_rate: 1.2500e-04
# Epoch 43/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4895 - csi: 0.2858 - far: 0.6512 - loss: 2.7853 - pod: 0.6191 - r2: 0.2088 - rmse: 1.3809
# Epoch 43: val_loss did not improve from 1.98213
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4890 - csi: 0.2860 - far: 0.6509 - loss: 2.8069 - pod: 0.6189 - r2: 0.2086 - rmse: 1.3842 - val_cc: 0.4128 - val_csi: 0.2613 - val_far: 0.6952 - val_loss: 2.1397 - val_pod: 0.6489 - val_r2: 0.0895 - val_rmse: 1.3373 - learning_rate: 1.2500e-04
# Epoch 44/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.5026 - csi: 0.2986 - far: 0.6417 - loss: 3.4462 - pod: 0.6456 - r2: 0.2165 - rmse: 1.5030
# Epoch 44: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.5022 - csi: 0.2985 - far: 0.6416 - loss: 3.4539 - pod: 0.6452 - r2: 0.2159 - rmse: 1.5040 - val_cc: 0.4313 - val_csi: 0.2830 - val_far: 0.6566 - val_loss: 1.9953 - val_pod: 0.6181 - val_r2: 0.1495 - val_rmse: 1.2906 - learning_rate: 6.2500e-05
# Epoch 45/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4693 - csi: 0.3025 - far: 0.6367 - loss: 2.7068 - pod: 0.6433 - r2: 0.2094 - rmse: 1.3261
# Epoch 45: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4697 - csi: 0.3024 - far: 0.6368 - loss: 2.7283 - pod: 0.6431 - r2: 0.2097 - rmse: 1.3296 - val_cc: 0.4335 - val_csi: 0.2708 - val_far: 0.6844 - val_loss: 2.0350 - val_pod: 0.6574 - val_r2: 0.1197 - val_rmse: 1.3080 - learning_rate: 6.2500e-05
# Epoch 46/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4723 - csi: 0.2873 - far: 0.6538 - loss: 3.2539 - pod: 0.6326 - r2: 0.1890 - rmse: 1.4702
# Epoch 46: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4725 - csi: 0.2875 - far: 0.6535 - loss: 3.2654 - pod: 0.6325 - r2: 0.1890 - rmse: 1.4715 - val_cc: 0.4329 - val_csi: 0.2794 - val_far: 0.6672 - val_loss: 1.9988 - val_pod: 0.6352 - val_r2: 0.1452 - val_rmse: 1.2934 - learning_rate: 6.2500e-05
# Epoch 47/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.4636 - csi: 0.2832 - far: 0.6518 - loss: 4.8273 - pod: 0.6060 - r2: 0.1924 - rmse: 1.6160
# Epoch 47: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 377ms/step - cc: 0.4642 - csi: 0.2833 - far: 0.6516 - loss: 4.8069 - pod: 0.6062 - r2: 0.1926 - rmse: 1.6143 - val_cc: 0.4314 - val_csi: 0.2868 - val_far: 0.6491 - val_loss: 1.9994 - val_pod: 0.6106 - val_r2: 0.1448 - val_rmse: 1.2939 - learning_rate: 6.2500e-05
# Epoch 48/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - cc: 0.5349 - csi: 0.3000 - far: 0.6229 - loss: 2.9553 - pod: 0.5976 - r2: 0.2778 - rmse: 1.4114
# Epoch 48: val_loss did not improve from 1.98213
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - cc: 0.5342 - csi: 0.3002 - far: 0.6227 - loss: 2.9723 - pod: 0.5979 - r2: 0.2769 - rmse: 1.4141 - val_cc: 0.4299 - val_csi: 0.2788 - val_far: 0.6580 - val_loss: 2.0159 - val_pod: 0.6022 - val_r2: 0.1344 - val_rmse: 1.2993 - learning_rate: 6.2500e-05
# Epoch 49/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4829 - csi: 0.2875 - far: 0.6449 - loss: 2.8777 - pod: 0.6002 - r2: 0.2263 - rmse: 1.4060
# Epoch 49: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - cc: 0.4831 - csi: 0.2878 - far: 0.6446 - loss: 2.8951 - pod: 0.6007 - r2: 0.2264 - rmse: 1.4088 - val_cc: 0.4325 - val_csi: 0.2888 - val_far: 0.6456 - val_loss: 2.0229 - val_pod: 0.6091 - val_r2: 0.1296 - val_rmse: 1.3033 - learning_rate: 3.1250e-05
# Epoch 50/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.4861 - csi: 0.2876 - far: 0.6420 - loss: 3.1761 - pod: 0.5890 - r2: 0.2257 - rmse: 1.4124
# Epoch 50: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4862 - csi: 0.2879 - far: 0.6416 - loss: 3.1871 - pod: 0.5894 - r2: 0.2260 - rmse: 1.4146 - val_cc: 0.4313 - val_csi: 0.2859 - val_far: 0.6549 - val_loss: 2.0345 - val_pod: 0.6252 - val_r2: 0.1246 - val_rmse: 1.3077 - learning_rate: 3.1250e-05
# Epoch 51/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.5049 - csi: 0.3027 - far: 0.6314 - loss: 3.3609 - pod: 0.6251 - r2: 0.2540 - rmse: 1.4863
# Epoch 51: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - cc: 0.5046 - csi: 0.3027 - far: 0.6313 - loss: 3.3688 - pod: 0.6249 - r2: 0.2537 - rmse: 1.4871 - val_cc: 0.4308 - val_csi: 0.2888 - val_far: 0.6477 - val_loss: 2.0299 - val_pod: 0.6162 - val_r2: 0.1269 - val_rmse: 1.3057 - learning_rate: 3.1250e-05
# Epoch 52/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.5059 - csi: 0.3076 - far: 0.6276 - loss: 2.6596 - pod: 0.6393 - r2: 0.2579 - rmse: 1.3795
# Epoch 52: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.5058 - csi: 0.3075 - far: 0.6276 - loss: 2.6814 - pod: 0.6389 - r2: 0.2576 - rmse: 1.3821 - val_cc: 0.4301 - val_csi: 0.2874 - val_far: 0.6511 - val_loss: 2.0398 - val_pod: 0.6195 - val_r2: 0.1203 - val_rmse: 1.3092 - learning_rate: 3.1250e-05
# Epoch 53/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - cc: 0.4766 - csi: 0.3002 - far: 0.6348 - loss: 2.8461 - pod: 0.6239 - r2: 0.2276 - rmse: 1.3938
# Epoch 53: val_loss did not improve from 1.98213
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - cc: 0.4769 - csi: 0.3002 - far: 0.6348 - loss: 2.8634 - pod: 0.6238 - r2: 0.2278 - rmse: 1.3965 - val_cc: 0.4296 - val_csi: 0.2812 - val_far: 0.6665 - val_loss: 2.0593 - val_pod: 0.6416 - val_r2: 0.1057 - val_rmse: 1.3178 - learning_rate: 3.1250e-05
# Epoch 54/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - cc: 0.5080 - csi: 0.3002 - far: 0.6270 - loss: 5.3325 - pod: 0.6038 - r2: 0.2555 - rmse: 1.6732
# Epoch 54: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - cc: 0.5078 - csi: 0.3003 - far: 0.6270 - loss: 5.2998 - pod: 0.6041 - r2: 0.2550 - rmse: 1.6699 - val_cc: 0.4266 - val_csi: 0.2862 - val_far: 0.6539 - val_loss: 2.0484 - val_pod: 0.6224 - val_r2: 0.1182 - val_rmse: 1.3121 - learning_rate: 1.5625e-05
# Epoch 55/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4804 - csi: 0.3051 - far: 0.6254 - loss: 3.8943 - pod: 0.6219 - r2: 0.2254 - rmse: 1.5947
# Epoch 55: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - cc: 0.4805 - csi: 0.3051 - far: 0.6254 - loss: 3.8903 - pod: 0.6218 - r2: 0.2255 - rmse: 1.5934 - val_cc: 0.4255 - val_csi: 0.2835 - val_far: 0.6610 - val_loss: 2.0712 - val_pod: 0.6338 - val_r2: 0.1058 - val_rmse: 1.3204 - learning_rate: 1.5625e-05
# Epoch 56/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4925 - csi: 0.3041 - far: 0.6271 - loss: 4.2991 - pod: 0.6227 - r2: 0.2453 - rmse: 1.6761
# Epoch 56: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4926 - csi: 0.3041 - far: 0.6271 - loss: 4.2866 - pod: 0.6226 - r2: 0.2452 - rmse: 1.6733 - val_cc: 0.4252 - val_csi: 0.2844 - val_far: 0.6583 - val_loss: 2.0605 - val_pod: 0.6285 - val_r2: 0.1105 - val_rmse: 1.3166 - learning_rate: 1.5625e-05
# Epoch 57/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.4944 - csi: 0.2957 - far: 0.6361 - loss: 3.6879 - pod: 0.6125 - r2: 0.2325 - rmse: 1.4977
# Epoch 57: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 377ms/step - cc: 0.4946 - csi: 0.2958 - far: 0.6359 - loss: 3.6875 - pod: 0.6127 - r2: 0.2327 - rmse: 1.4975 - val_cc: 0.4239 - val_csi: 0.2819 - val_far: 0.6624 - val_loss: 2.0768 - val_pod: 0.6307 - val_r2: 0.1036 - val_rmse: 1.3220 - learning_rate: 1.5625e-05
# Epoch 58/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.5122 - csi: 0.3100 - far: 0.6154 - loss: 4.3138 - pod: 0.6221 - r2: 0.2631 - rmse: 1.5773
# Epoch 58: val_loss did not improve from 1.98213
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.5120 - csi: 0.3098 - far: 0.6157 - loss: 4.3012 - pod: 0.6221 - r2: 0.2629 - rmse: 1.5766 - val_cc: 0.4244 - val_csi: 0.2817 - val_far: 0.6627 - val_loss: 2.0677 - val_pod: 0.6308 - val_r2: 0.1066 - val_rmse: 1.3193 - learning_rate: 1.5625e-05
# Epoch 59/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.5185 - csi: 0.3106 - far: 0.6093 - loss: 3.5225 - pod: 0.6018 - r2: 0.2651 - rmse: 1.5408
# Epoch 59: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.5179 - csi: 0.3104 - far: 0.6096 - loss: 3.5258 - pod: 0.6020 - r2: 0.2645 - rmse: 1.5404 - val_cc: 0.4236 - val_csi: 0.2842 - val_far: 0.6570 - val_loss: 2.0741 - val_pod: 0.6234 - val_r2: 0.1048 - val_rmse: 1.3210 - learning_rate: 7.8125e-06
# Epoch 60/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.4896 - csi: 0.3028 - far: 0.6199 - loss: 3.5316 - pod: 0.6036 - r2: 0.2266 - rmse: 1.4613
# Epoch 60: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4896 - csi: 0.3028 - far: 0.6201 - loss: 3.5338 - pod: 0.6038 - r2: 0.2265 - rmse: 1.4616 - val_cc: 0.4230 - val_csi: 0.2833 - val_far: 0.6596 - val_loss: 2.0897 - val_pod: 0.6281 - val_r2: 0.0966 - val_rmse: 1.3265 - learning_rate: 7.8125e-06
# Epoch 61/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.5235 - csi: 0.3099 - far: 0.6162 - loss: 4.1366 - pod: 0.6210 - r2: 0.2748 - rmse: 1.5582
# Epoch 61: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - cc: 0.5231 - csi: 0.3098 - far: 0.6165 - loss: 4.1275 - pod: 0.6209 - r2: 0.2742 - rmse: 1.5575 - val_cc: 0.4233 - val_csi: 0.2800 - val_far: 0.6664 - val_loss: 2.0952 - val_pod: 0.6354 - val_r2: 0.0920 - val_rmse: 1.3290 - learning_rate: 7.8125e-06
# Epoch 62/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.5148 - csi: 0.3033 - far: 0.6266 - loss: 3.2284 - pod: 0.6174 - r2: 0.2353 - rmse: 1.4521
# Epoch 62: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.5144 - csi: 0.3032 - far: 0.6267 - loss: 3.2367 - pod: 0.6174 - r2: 0.2347 - rmse: 1.4533 - val_cc: 0.4226 - val_csi: 0.2829 - val_far: 0.6590 - val_loss: 2.0788 - val_pod: 0.6244 - val_r2: 0.1022 - val_rmse: 1.3227 - learning_rate: 7.8125e-06
# Epoch 63/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - cc: 0.4861 - csi: 0.3030 - far: 0.6254 - loss: 4.2119 - pod: 0.6136 - r2: 0.2279 - rmse: 1.5871
# Epoch 63: val_loss did not improve from 1.98213
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - cc: 0.4862 - csi: 0.3030 - far: 0.6255 - loss: 4.2019 - pod: 0.6135 - r2: 0.2270 - rmse: 1.5859 - val_cc: 0.4228 - val_csi: 0.2805 - val_far: 0.6642 - val_loss: 2.0874 - val_pod: 0.6303 - val_r2: 0.0975 - val_rmse: 1.3259 - learning_rate: 7.8125e-06
# Epoch 64/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.5118 - csi: 0.2934 - far: 0.6393 - loss: 3.4687 - pod: 0.6110 - r2: 0.2513 - rmse: 1.4577
# Epoch 64: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.5117 - csi: 0.2936 - far: 0.6391 - loss: 3.4738 - pod: 0.6111 - r2: 0.2512 - rmse: 1.4591 - val_cc: 0.4229 - val_csi: 0.2816 - val_far: 0.6618 - val_loss: 2.0803 - val_pod: 0.6272 - val_r2: 0.1010 - val_rmse: 1.3235 - learning_rate: 3.9063e-06
# Epoch 65/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4744 - csi: 0.3007 - far: 0.6288 - loss: 3.6967 - pod: 0.6129 - r2: 0.1554 - rmse: 1.5397
# Epoch 65: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4750 - csi: 0.3007 - far: 0.6288 - loss: 3.6964 - pod: 0.6129 - r2: 0.1567 - rmse: 1.5394 - val_cc: 0.4233 - val_csi: 0.2824 - val_far: 0.6601 - val_loss: 2.0745 - val_pod: 0.6251 - val_r2: 0.1040 - val_rmse: 1.3214 - learning_rate: 3.9063e-06
# Epoch 66/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4885 - csi: 0.2872 - far: 0.6482 - loss: 2.2502 - pod: 0.6096 - r2: 0.2380 - rmse: 1.2597
# Epoch 66: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4889 - csi: 0.2874 - far: 0.6479 - loss: 2.2781 - pod: 0.6097 - r2: 0.2381 - rmse: 1.2641 - val_cc: 0.4240 - val_csi: 0.2835 - val_far: 0.6584 - val_loss: 2.0735 - val_pod: 0.6249 - val_r2: 0.1035 - val_rmse: 1.3213 - learning_rate: 3.9063e-06
# Epoch 67/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.5136 - csi: 0.3139 - far: 0.6161 - loss: 4.4561 - pod: 0.6375 - r2: 0.2462 - rmse: 1.6240
# Epoch 67: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.5132 - csi: 0.3136 - far: 0.6164 - loss: 4.4404 - pod: 0.6371 - r2: 0.2457 - rmse: 1.6214 - val_cc: 0.4242 - val_csi: 0.2840 - val_far: 0.6578 - val_loss: 2.0769 - val_pod: 0.6252 - val_r2: 0.1019 - val_rmse: 1.3224 - learning_rate: 3.9063e-06
# Epoch 68/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.5580 - csi: 0.3159 - far: 0.6091 - loss: 3.6310 - pod: 0.6252 - r2: 0.3023 - rmse: 1.4910
# Epoch 68: val_loss did not improve from 1.98213
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.5571 - csi: 0.3157 - far: 0.6093 - loss: 3.6322 - pod: 0.6253 - r2: 0.3012 - rmse: 1.4913 - val_cc: 0.4238 - val_csi: 0.2831 - val_far: 0.6595 - val_loss: 2.0833 - val_pod: 0.6269 - val_r2: 0.0985 - val_rmse: 1.3248 - learning_rate: 3.9063e-06
# Epoch 69/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.5118 - csi: 0.3134 - far: 0.6141 - loss: 3.2981 - pod: 0.6243 - r2: 0.2195 - rmse: 1.4857
# Epoch 69: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 377ms/step - cc: 0.5115 - csi: 0.3132 - far: 0.6144 - loss: 3.3064 - pod: 0.6243 - r2: 0.2196 - rmse: 1.4866 - val_cc: 0.4235 - val_csi: 0.2833 - val_far: 0.6592 - val_loss: 2.0863 - val_pod: 0.6264 - val_r2: 0.0969 - val_rmse: 1.3258 - learning_rate: 1.9531e-06
# Epoch 70/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - cc: 0.4727 - csi: 0.3009 - far: 0.6314 - loss: 4.1599 - pod: 0.6178 - r2: 0.1980 - rmse: 1.5885
# Epoch 70: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 377ms/step - cc: 0.4733 - csi: 0.3009 - far: 0.6314 - loss: 4.1508 - pod: 0.6178 - r2: 0.1989 - rmse: 1.5869 - val_cc: 0.4233 - val_csi: 0.2837 - val_far: 0.6580 - val_loss: 2.0834 - val_pod: 0.6246 - val_r2: 0.0987 - val_rmse: 1.3247 - learning_rate: 1.9531e-06
# Epoch 71/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - cc: 0.4726 - csi: 0.3114 - far: 0.6184 - loss: 2.9716 - pod: 0.6236 - r2: 0.2229 - rmse: 1.4288
# Epoch 71: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - cc: 0.4730 - csi: 0.3112 - far: 0.6186 - loss: 2.9849 - pod: 0.6234 - r2: 0.2231 - rmse: 1.4304 - val_cc: 0.4233 - val_csi: 0.2842 - val_far: 0.6566 - val_loss: 2.0828 - val_pod: 0.6226 - val_r2: 0.0991 - val_rmse: 1.3244 - learning_rate: 1.9531e-06
# Epoch 72/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.4833 - csi: 0.3108 - far: 0.6210 - loss: 2.9399 - pod: 0.6338 - r2: 0.1976 - rmse: 1.3763
# Epoch 72: val_loss did not improve from 1.98213
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.4834 - csi: 0.3106 - far: 0.6212 - loss: 2.9549 - pod: 0.6335 - r2: 0.1980 - rmse: 1.3782 - val_cc: 0.4231 - val_csi: 0.2841 - val_far: 0.6569 - val_loss: 2.0861 - val_pod: 0.6229 - val_r2: 0.0971 - val_rmse: 1.3256 - learning_rate: 1.9531e-06
# Epoch 73/80
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - cc: 0.5216 - csi: 0.3020 - far: 0.6262 - loss: 3.6205 - pod: 0.6170 - r2: 0.2686 - rmse: 1.5213
# Epoch 73: val_loss did not improve from 1.98213
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 1e-06.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - cc: 0.5213 - csi: 0.3020 - far: 0.6263 - loss: 3.6221 - pod: 0.6171 - r2: 0.2682 - rmse: 1.5211 - val_cc: 0.4229 - val_csi: 0.2844 - val_far: 0.6560 - val_loss: 2.0861 - val_pod: 0.6215 - val_r2: 0.0978 - val_rmse: 1.3255 - learning_rate: 1.9531e-06
# Epoch 73: early stopping
# Restoring model weights from the end of the best epoch: 33.

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Metric valid set

# %%
best_epoch = np.argmin(history.history['val_loss'])

# Print all metrics for that epoch
print(f"Best Epoch: {best_epoch + 1}")
for metric in history.history.keys():
    print(f"{metric}: {history.history[metric][best_epoch]:.4f}")
# Out:
# Best Epoch: 33
# cc: 0.4529
# csi: 0.2805
# far: 0.6569
# loss: 4.0494
# pod: 0.6112
# r2: 0.1980
# rmse: 1.5957
# val_cc: 0.4220
# val_csi: 0.2786
# val_far: 0.6405
# val_loss: 1.9821
# val_pod: 0.5546
# val_r2: 0.1608
# val_rmse: 1.2855
# learning_rate: 0.0003

# %%
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix
from scipy.stats import pearsonr
from tensorflow.keras.models import load_model

# %% [markdown]
# ## Metric test set

# %%
best_model = load_model('/kaggle/working/best_model.keras')
y_test_pred = best_model.predict(X_test_scaled)
y_test_pred_flat = y_test_pred.flatten()
y_test_flat = y_test.flatten()

# Mask to exclude missing data 
mask = y_test_flat >= 0

# Apply mask to filter out missing data
y_test_flat_filtered = y_test_flat[mask]
y_test_pred_flat_filtered = y_test_pred_flat[mask]

mse = mean_squared_error(y_test_flat_filtered, y_test_pred_flat_filtered)
rmse = np.sqrt(mse)
cc, _ = pearsonr(y_test_flat_filtered, y_test_pred_flat_filtered)
r2 = r2_score(y_test_flat_filtered, y_test_pred_flat_filtered)

print("Test set")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"Correlation Coefficient (CC): {cc}")
print(f"R²: {r2}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 472ms/step
# Test set
# MSE: 2.0087311267852783
# RMSE: 1.417297124862671
# Correlation Coefficient (CC): 0.44055864214897156
# R²: 0.1937756932171809

# %%
from sklearn.metrics import confusion_matrix
true_class_mask = y_test_flat >= 0.5
pred_class_mask = y_test_pred_flat >= 0.5


true_class_mask = np.where(mask, true_class_mask, -1)
pred_class_mask = np.where(mask, pred_class_mask, -1)

valid_mask = (true_class_mask != -1) & (pred_class_mask != -1)
true_class_mask_filtered = true_class_mask[valid_mask]
pred_class_mask_filtered = pred_class_mask[valid_mask]
cm = confusion_matrix(true_class_mask_filtered, pred_class_mask_filtered)

# If cm is a 2x2 matrix, unpack it
if cm.shape == (2, 2):
    tn, fp, fn, tp = cm.ravel()
else:
    # Handle cases where there's no confusion matrix (only one class present)
    tn = cm[0, 0] if cm.shape[0] > 1 else 1
    fp = cm[0, 1] if cm.shape[1] > 1 else 0
    fn = cm[1, 0] if cm.shape[0] > 1 else 0
    tp = cm[1, 1] if cm.shape[1] > 1 else 1

far = fp / (tp + fp) if (tp + fp) > 0 else 0.0

# Probability of Detection (POD) = TP / (TP + FN)
pod = tp / (tp + fn) if (tp + fn) > 0 else 0.0

# Critical Success Index (CSI) = TP / (TP + FP + FN)
csi = tp / (tp + fp + fn) if (tp + fp + fn) > 0 else 0.0

# Print the metrics
print(f"FAR: {far}")
print(f"POD: {pod}")
print(f"CSI: {csi}")
# Out:
# FAR: 0.6194750412981329
# POD: 0.5979826330183393
# CSI: 0.3030084603847218

# %% [markdown]
# ## Plot

# %%
num_examples = 16  # Number of examples to visualize
plt.figure(figsize=(20, 5 * num_examples))
random_indices = np.random.choice(len(y_test), size=num_examples, replace=False)
np.random.seed(42)
for i, index in enumerate(random_indices):
    
    predicted_image = y_test_pred[index]
    radar_image = y_test[index]
    
    mask = radar_image >= 0
    predicted_image[~mask] = -np.inf
    radar_image[~mask] = -np.inf
    vmin = 0
    vmax_true = np.max(radar_image)
    vmax_pred = np.max(predicted_image)
    vmax = np.max([vmax_true, vmax_pred])

    plt.subplot(num_examples, 2, i * 2 + 1)
    im1 = plt.imshow(radar_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Actual Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im1, fraction=0.046, pad=0.04)

    # Plot predicted image
    plt.subplot(num_examples, 2, i * 2 + 2)
    im2 = plt.imshow(predicted_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Predicted Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im2, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()

# %%
num_examples = len(random_indices)
cols = 4
rows = (num_examples + cols - 1) // cols

plt.figure(figsize=(cols * 5, rows * 4))  # Adjust size as needed

for i, index in enumerate(random_indices):
    predicted_image = y_test_pred[index]
    radar_image = y_test[index]
    
    # Mask invalid values
    mask = radar_image >= 0
    predicted_image = predicted_image[mask]
    radar_image = radar_image[mask]
    
    # Scatter plot
    plt.subplot(rows, cols, i + 1)
    plt.scatter(radar_image.flatten(), predicted_image.flatten(), alpha=0.6, s=10)
    plt.title(f'Image #{index}', fontsize=10)
    plt.xlabel('Actual', fontsize=8)
    plt.ylabel('Predicted', fontsize=8)
    plt.axis('equal')
    plt.xticks(fontsize=6)
    plt.yticks(fontsize=6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot val

# %%
y_val_pred = best_model.predict(X_val_scaled)

plt.figure(figsize=(20, 5 * num_examples))
for i, index in enumerate(random_indices):
    
    predicted_image = y_val_pred[index]
    radar_image = y_val[index]
    
    mask = radar_image >= 0
    predicted_image[~mask] = -np.inf
    radar_image[~mask] = -np.inf
    vmin = 0
    vmax_true = np.max(radar_image)
    vmax_pred = np.max(predicted_image)
    vmax = np.max([vmax_true, vmax_pred])

    plt.subplot(num_examples, 2, i * 2 + 1)
    im1 = plt.imshow(radar_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Actual Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im1, fraction=0.046, pad=0.04)

    # Plot predicted image
    plt.subplot(num_examples, 2, i * 2 + 2)
    im2 = plt.imshow(predicted_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Predicted Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im2, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step

# %%
plt.figure(figsize=(20, 5 * num_examples))
for i, index in enumerate(random_indices):
    
    predicted_image = y_val_pred[index]
    radar_image = y_val[index]
    
    mask = radar_image >= 0
    radar_image[~mask] = -np.inf
    vmin = 0
    vmax_true = np.max(radar_image)
    vmax_pred = np.max(predicted_image)
    vmax = np.max([vmax_true, vmax_pred])

    plt.subplot(num_examples, 2, i * 2 + 1)
    im1 = plt.imshow(radar_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Actual Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im1, fraction=0.046, pad=0.04)

    # Plot predicted image
    plt.subplot(num_examples, 2, i * 2 + 2)
    im2 = plt.imshow(predicted_image, cmap='viridis', vmin=vmin, vmax=vmax)
    plt.title(f'Predicted Rainfall Image #{index}', fontsize=12)
    plt.axis('off')
    plt.colorbar(im2, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
